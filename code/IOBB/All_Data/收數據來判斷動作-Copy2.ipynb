# %%
import serial
import csv
import time
import pandas as pd
from datetime import datetime, timedelta
from time import sleep
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import math
from scipy import signal
from PIL import Image

np.random.seed(202205456)

data0506 = [
            "../0506data/手2022-05-06 114900-4.csv",
            "../0506data/手2022-05-06 113600-4.csv",
            "../0506data/手2022-05-06 115200-2.csv",
            "../0506data/腳2022-05-06 120000-4.csv",
            "../0506data/腳2022-05-06 120300-3.csv",
            "../0506data/腳2022-05-06 120500-4.csv",
            "../腳_1.csv"]
                                                    
data0510 = [
            "../0510data/手腳2022-05-10 104600.csv", #0
            "../0510data/手腳2022-05-10 104400.csv",#
            "../0510data/手腳2022-05-10 104800.csv",
            "../0510data/手腳2022-05-10 104000.csv",
            "../0510data/手2022-05-10 103600.csv",
            "../0510data/手2022-05-10 103800.csv",
            "../0510data/手2022-05-10 104000.csv",
            "../0510data/手2022-05-10 103600優化.csv",#7
            "../0510data/手2022-05-10 103800優化.csv",#8
            "../0510data/手2022-05-10 104000優化.csv",#9
            "../0510data/腳2022-05-10 103600優化.csv",#10
            "../0510data/腳2022-05-10 103800優化.csv",#11
            "../0510data/腳2022-05-10 104000優化.csv",#12
            "../0510data/腳2022-05-10 104000.csv"]

def RF(data):
    data = np.array(pd.read_csv(data))
    add = []
    fs_start = 8
    fs_end = len(data[:,1])-17 + 8 
    for i in range(len(data[:,1])-17):
        add.append([])
#     data = np.array(pd.read_csv(data))
    f, t, fft_gx = signal.stft(data[:,1],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    f1, t1, fft_gy = signal.stft(data[:,2],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    f2, t2, fft_gz = signal.stft(data[:,3],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    f3, t3, fft_ax = signal.stft(data[:,7],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    f4, t4, fft_ay = signal.stft(data[:,8],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    f5, t5, fft_az = signal.stft(data[:,9],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    #fft_gx
    for i in range (len(fft_gx[100,:])):
        add[i].append(math.atan2((fft_gx[100,i].real),(fft_gx[100,i].imag)))
        add[i].append(math.atan2((fft_gx[600,i].real),(fft_gx[600,i].imag)))
        add[i].append(math.atan2((fft_gx[800,i].real),(fft_gx[800,i].imag)))
        
    #fft_gy
    for i in range (len(fft_gy[100,:])):
        add[i].append(math.atan2((fft_gy[100,i].real),(fft_gy[100,i].imag)))
        add[i].append(math.atan2((fft_gy[600,i].real),(fft_gy[600,i].imag)))
        add[i].append(math.atan2((fft_gy[800,i].real),(fft_gy[800,i].imag)))
    #fft_gz
    for i in range (len(fft_gz[100,:])):
        add[i].append(math.atan2((fft_gz[100,i].real),(fft_gz[100,i].imag)))
        add[i].append(math.atan2((fft_gz[600,i].real),(fft_gz[600,i].imag)))
        add[i].append(math.atan2((fft_gz[800,i].real),(fft_gz[800,i].imag)))
    #fft_ax
    for i in range (len(fft_ax[100,:])):
        add[i].append(math.atan2((fft_ax[100,i].real),(fft_ax[100,i].imag)))
        add[i].append(math.atan2((fft_ax[600,i].real),(fft_ax[600,i].imag)))
        add[i].append(math.atan2((fft_ax[800,i].real),(fft_ax[800,i].imag)))
    #fft_ay
    for i in range (len(fft_ay[100,:])):
        add[i].append(math.atan2((fft_ay[100,i].real),(fft_ay[100,i].imag)))
        add[i].append(math.atan2((fft_ay[600,i].real),(fft_ay[600,i].imag)))
        add[i].append(math.atan2((fft_ay[800,i].real),(fft_ay[800,i].imag)))
    #fft_az
    for i in range (len(fft_az[100,:])):
        add[i].append(math.atan2((fft_az[100,i].real),(fft_az[100,i].imag)))
        add[i].append(math.atan2((fft_az[600,i].real),(fft_az[600,i].imag)))
        add[i].append(math.atan2((fft_az[800,i].real),(fft_az[800,i].imag)))
    
    data = np.append(data[fs_start:fs_end,:], add , axis=1)
    
#     pandasData={"Xg":data[:,1],"Yg":data[:,2],"Zg":data[:,3],"Xm":data[:,4],"Ym":data[:,5],"Zm":data[:,6],"Xa":data[:,7],"Ya":data[:,8],"Za":data[:,9],"Xq":data[:,10],"Yq":data[:,11],"Zq":data[:,12],"Direction":data[:,13],"SensorTime":data[:,14],"Time":data[:,15],"Label":data[:,16],"Fft_gx1":data[:,17],"Fft_gx2":data[:,18],"Fft_gx3":data[:,19],"Fft_gy1":data[:,20],"Fft_gy2":data[:,21],"Fft_gy3":data[:,22],"Fft_gz1":data[:,23],"Fft_gz2":data[:,24],"Fft_gz3":data[:,25]}
    pandasData={"Xg":data[:,1],"Yg":data[:,2],"Zg":data[:,3],"Xm":data[:,4],"Ym":data[:,5],"Zm":data[:,6],"Xa":data[:,7],"Ya":data[:,8],"Za":data[:,9],"Xq":data[:,10],"Yq":data[:,11],"Zq":data[:,12],"Direction":data[:,13],"SensorTime":data[:,14],"Time":data[:,15],"Label":data[:,16],"Fft_gx":data[:,17],"Fft_gy":data[:,20],"Fft_gz":data[:,23],"Fft_ax":data[:,26],"Fft_ay":data[:,29],"Fft_az":data[:,32]}
   
    df = pd.DataFrame(pandasData)
    df.to_csv('../Add_fft_features_data/AfterFft_fft_arctan_40_Hand'+'.csv')
# for i in range(1):
#     print("")
#     RF(data0510[i+9])
count = 2
# data0506 = [
#             "../All_Data/new_data/手2022-05-06 114900-4.csv",
#             "../All_Data/new_data/手2022-05-06 113600-4.csv",
#             "../All_Data/new_data/手2022-05-06 115200-2.csv",
#             "../All_Data/new_data/腳2022-05-06 120000-4.csv",
#             "../All_Data/new_data/腳2022-05-06 120300-3.csv",
#             "../All_Data/new_data/腳2022-05-06 120500-4.csv",
#             "./腳_2.csv"]
                                                    
data0510 = [
            "../All_Data/0510data/手2022-05-10 103600.csv",
            "../All_Data/0510data/手2022-05-10 103800.csv",
            "../All_Data/0510data/手2022-05-10 104000.csv",
            "../All_Data/0510data/腳2022-05-10 103600.csv",
            "../All_Data/0510data/腳2022-05-10 103800.csv",
            "../All_Data/0510data/腳2022-05-10 104000.csv"]


dataFft = ["../Add_fft_features_data/AfterFft_36_Foot.csv",#0
          "../Add_fft_features_data/AfterFft_38_Foot.csv",#1
          "../Add_fft_features_data/AfterFft_40_Foot.csv",#2
          "../Add_fft_features_data/AfterFft_36_Hand.csv",#3
          "../Add_fft_features_data/AfterFft_38_Hand.csv",#4
          "../Add_fft_features_data/AfterFft_40_Hand.csv",#5
          "../Add_fft_features_data/AfterFft_陀螺儀_36_Hand.csv",#6
          "../Add_fft_features_data/AfterFft_陀螺儀_38_Hand.csv",#7
          "../Add_fft_features_data/AfterFft_陀螺儀_40_Hand.csv",#8
          "../Add_fft_features_data/AfterFft_陀螺儀_36_Foot.csv",#9
          "../Add_fft_features_data/AfterFft_陀螺儀_38_Foot.csv",#10
          "../Add_fft_features_data/AfterFft_陀螺儀_40_Foot.csv",#11
           "../Add_fft_features_data/AfterFft_fft_all_36_Hand.csv",#12
          "../Add_fft_features_data/AfterFft_fft_all_38_Hand.csv",#13
          "../Add_fft_features_data/AfterFft_fft_all_40_Hand.csv",#14
          "../Add_fft_features_data/AfterFft_fft_all_36_Foot.csv",#15
          "../Add_fft_features_data/AfterFft_fft_all_38_Foot.csv",#16
           "../Add_fft_features_data/AfterFft_fft_all_40_Foot.csv",#17
           "../Add_fft_features_data/AfterFft_fft_arctan_36_Hand.csv",#18
          "../Add_fft_features_data/AfterFft_fft_arctan_38_Hand.csv",#19
          "../Add_fft_features_data/AfterFft_fft_arctan_40_Hand.csv",#20
          "../../../Add_fft_features_data/AfterFft_fft_arctan_36_Foot.csv",#21
          "../../../Add_fft_features_data/AfterFft_fft_arctan_38_Foot.csv",#22
           "../../../Add_fft_features_data/AfterFft_fft_arctan_40_Foot.csv",#23
           "../Add_fft_features_data/AfterFft_fft_sqrt_arctan_36_Hand.csv",#24
          "../Add_fft_features_data/AfterFft_fft_sqrt_arctan_38_Hand.csv",#25
          "../Add_fft_features_data/AfterFft_fft_sqrt_arctan_40_Hand.csv",#26
          "../../../Add_fft_features_data/AfterFft_fft_sqrt_arctan_36_Foot.csv",#27
          "../../../Add_fft_features_data/AfterFft_fft_sqrt_arctan_38_Foot.csv",#28
           "../../../Add_fft_features_data/AfterFft_fft_sqrt_arctan_40_Foot.csv",#29
          "./腳_fft"+".csv"#30
          ]
num = 1
num2 = 1

# add_arctan
def add_arctan(data):
    data = np.array(pd.read_csv(data))
    add = []
    global num2
    global parameter
    fs_end = len(data[:,1])-17 + 8 
    # 第一次的arctan資料
    if num2 == 1:
        fs_start = 8
        parameter = len(data[:,1])
        f, t, fft_gx = signal.stft(data[fs_start:,1],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f1, t1, fft_gy = signal.stft(data[fs_start:,2],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f2, t2, fft_gz = signal.stft(data[fs_start:,3],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f3, t3, fft_ax = signal.stft(data[fs_start:,7],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f4, t4, fft_ay = signal.stft(data[fs_start:,8],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f5, t5, fft_az = signal.stft(data[fs_start:,9],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        for i in range(len(data[:,1])-25): #-17-8???????(本來就會少17筆 + 又從DATA的第8筆開始轉 所以就25惹??)
            add.append([])
    #第二次以上的arctan 資料
    else :
        fs_start = 0
        data1 = np.array(pd.read_csv(dataFft[30]))
        parameter = len(data1[:,1])   
#         print(parameter)
        f, t, fft_gx = signal.stft(data[parameter-16:,1],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f1, t1, fft_gy = signal.stft(data[parameter-16:,2],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f2, t2, fft_gz = signal.stft(data[parameter-16:,3],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f3, t3, fft_ax = signal.stft(data[parameter-16:,7],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f4, t4, fft_ay = signal.stft(data[parameter-16:,8],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f5, t5, fft_az = signal.stft(data[parameter-16:,9],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        for i in range(len(fft_gx[100,:])):
            add.append([])
    print(len(fft_az[100,:]))#78
#         print(len(data[:,1])-len(data1[:,1]))#126
    

    
#     print(fft_az)
    
    
#     data = np.array(pd.read_csv(data))
#     print(fft_gx[100,:])
    #fft_gx
    for i in range (len(fft_gx[100,:])):
        add[i].append(math.atan2((fft_gx[100,i].real),(fft_gx[100,i].imag)))
        add[i].append(math.atan2((fft_gx[600,i].real),(fft_gx[600,i].imag)))
        add[i].append(math.atan2((fft_gx[800,i].real),(fft_gx[800,i].imag)))
        
    #fft_gy
    for i in range (len(fft_gy[100,:])):
        add[i].append(math.atan2((fft_gy[100,i].real),(fft_gy[100,i].imag)))
        add[i].append(math.atan2((fft_gy[600,i].real),(fft_gy[600,i].imag)))
        add[i].append(math.atan2((fft_gy[800,i].real),(fft_gy[800,i].imag)))
    #fft_gz
    for i in range (len(fft_gz[100,:])):
        add[i].append(math.atan2((fft_gz[100,i].real),(fft_gz[100,i].imag)))
        add[i].append(math.atan2((fft_gz[600,i].real),(fft_gz[600,i].imag)))
        add[i].append(math.atan2((fft_gz[800,i].real),(fft_gz[800,i].imag)))
    #fft_ax
    for i in range (len(fft_ax[100,:])):
        add[i].append(math.atan2((fft_ax[100,i].real),(fft_ax[100,i].imag)))
        add[i].append(math.atan2((fft_ax[600,i].real),(fft_ax[600,i].imag)))
        add[i].append(math.atan2((fft_ax[800,i].real),(fft_ax[800,i].imag)))
    #fft_ay
    for i in range (len(fft_ay[100,:])):
        add[i].append(math.atan2((fft_ay[100,i].real),(fft_ay[100,i].imag)))
        add[i].append(math.atan2((fft_ay[600,i].real),(fft_ay[600,i].imag)))
        add[i].append(math.atan2((fft_ay[800,i].real),(fft_ay[800,i].imag)))
    #fft_az
    for i in range (len(fft_az[100,:])):
        add[i].append(math.atan2((fft_az[100,i].real),(fft_az[100,i].imag)))
        add[i].append(math.atan2((fft_az[600,i].real),(fft_az[600,i].imag)))
        add[i].append(math.atan2((fft_az[800,i].real),(fft_az[800,i].imag)))
#     print(np.shape(add))
    add2 = add

#     print(np.shape(add))#(143,18)
#     add = add.T
    if num2 == 1:
        add = np.array(add)
#         pandasData={"Xg":data[:,1],"Yg":data[:,2],"Zg":data[:,3],"Xm":data[:,4],"Ym":data[:,5],"Zm":data[:,6],"Xa":data[:,7],"Ya":data[:,8],"Za":data[:,9],"Xq":data[:,10],"Yq":data[:,11],"Zq":data[:,12],"Direction":data[:,13],"SensorTime":data[:,14],"Time":data[:,15],"Label":data[:,16],"Fft_gx1":data[:,17],"Fft_gx2":data[:,18],"Fft_gx3":data[:,19],"Fft_gy1":data[:,20],"Fft_gy2":data[:,21],"Fft_gy3":data[:,22],"Fft_gz1":data[:,23],"Fft_gz2":data[:,24],"Fft_gz3":data[:,25]}
        pandasData={"Fft_gx":add[:,0],"Fft_gy":add[:,3],"Fft_gz":add[:,6],"Fft_ax":add[:,9],"Fft_ay":add[:,12],"Fft_az":add[:,15]}
#         pandasData={"Fft_gx":add[0],"Fft_gy":add[3],"Fft_gz":add[6],"Fft_ax":add[9],"Fft_ay":add[12],"Fft_az":add[15]}
        df = pd.DataFrame(pandasData)
        df
        df.to_csv("./腳_fft"+".csv")
    else :
        data1 = np.array(pd.read_csv(dataFft[30]))
#         data1 = np.row_stack((data1, add))
#         add2 = add2.T
#         print(add)
#         print("123")
#         add1 =[add2]
#         print(add1)
#         print("456")
#         add2 = np.array(add2)
#         print(add2)
#         print("789")
        add = np.array(add)
#         print(add)
#         print(add[:,0])
#         print(add[:,3])
        add_tra1 = np.array([add[:,0]]).T
        add_tra2 = np.array([add[:,3]]).T
        add_tra3 = np.array([add[:,6]]).T
        add_tra4 = np.array([add[:,9]]).T
        add_tra5 = np.array([add[:,12]]).T
        add_tra6 = np.array([add[:,15]]).T
#         temp_arr = []
#         for i in range(len(add)):
#             temp_arr.append([])
#         temp_arr = np.append(temp_arr,add[:,0],axis = 1)
#         temp_arr = np.append(temp_arr,add[:,3],axis = 1)
#         print(temp_arr)
#         temp_arr = np.append(temp_arr,add[:,6],axis = 1)
#         temp_arr = np.append(temp_arr,add[:,9],axis = 1)
#         temp_arr = np.append(temp_arr,add[:,12],axis = 1)
#         temp_arr = np.append(temp_arr,add[:,15],axis = 1)
        temp_arr = np.append(add_tra1,add_tra2,axis = 1)
#         print(temp_arr)
        temp_arr = np.append(temp_arr,add_tra3,axis = 1)
        temp_arr = np.append(temp_arr,add_tra4,axis = 1)
        temp_arr = np.append(temp_arr,add_tra5,axis = 1)
        temp_arr = np.append(temp_arr,add_tra6,axis = 1)
        data1 = np.append(data1[:,1:], temp_arr , axis=0)
        data1 = np.array(data1)
#         pandasData={"Xg":data[:,1],"Yg":data[:,2],"Zg":data[:,3],"Xm":data[:,4],"Ym":data[:,5],"Zm":data[:,6],"Xa":data[:,7],"Ya":data[:,8],"Za":data[:,9],"Xq":data[:,10],"Yq":data[:,11],"Zq":data[:,12],"Direction":data[:,13],"SensorTime":data[:,14],"Time":data[:,15],"Label":data[:,16],"Fft_gx1":data[:,17],"Fft_gx2":data[:,18],"Fft_gx3":data[:,19],"Fft_gy1":data[:,20],"Fft_gy2":data[:,21],"Fft_gy3":data[:,22],"Fft_gz1":data[:,23],"Fft_gz2":data[:,24],"Fft_gz3":data[:,25]}
        pandasData={"Fft_gx":data1[:,0],"Fft_gy":data1[:,1],"Fft_gz":data1[:,2],"Fft_ax":data1[:,3],"Fft_ay":data1[:,4],"Fft_az":data1[:,5]}
        df = pd.DataFrame(pandasData)
        
        df.to_csv("./腳_fft"+".csv")
    num2 =num2 + 1
#     return parameter

        
num1=1
def RF(data,data1,data2):
    global num1
    fft = []
    fft1 = []
    amp = 2 * np.sqrt(2)
    
    # read csv
    # data : labeled ,data1 : real-time data ,data2 :fft_arctan
    data = np.array(pd.read_csv(data))
    data1 = np.array(pd.read_csv(data1))
    data2 = np.array(pd.read_csv(data2))
    
    
    
    data_len = len(data[:,1])
    labelSeries = data[:,16]
    # 加速度 陀螺儀 fft_arctan
    dataSeries = np.append(data[:,1:4], data[:,7:10] , axis=1)
    
#     dataSeries = np.append(dataSeries, data[1:data_len-16,17:23] , axis=1)
    dataSeries = np.append(dataSeries, data[:,17:23] , axis=1)

    if num1 <= 2:
        # 8(0-7) + 1(8) + 9(9-17) = 18(nperseg=18)
        dataSeries1 = np.append(data1[8:len(data1[:,1])-8-1-8,1:4], data1[8:len(data1[:,1])-8-1-8,7:10] , axis=1)
    #     dataSeries1 = np.append(dataSeries1, data1[1:data_len1-16,17:23] , axis=1)
        dataSeries1 = np.append(dataSeries1, data2[:,1:7] , axis=1)
    else: 
        # num_fft : the num of arctan_datasets
        # -16的原因: 因為要對應上一次轉完arctan之後的下一筆繼續轉
        num_fft = parameter
        dataSeries1 = np.append(data1[num_fft-16:len(data1[:,1])-8-1-8,1:4], data1[num_fft-16:len(data1[:,1])-8-1-8,7:10] , axis=1)
    #     dataSeries1 = np.append(dataSeries1, data1[1:data_len1-16,17:23] , axis=1)
        dataSeries1 = np.append(dataSeries1, data2[num_fft:,1:7] , axis=1)
    dataSeries = np.array(dataSeries)
    dataSeries1 = np.array(dataSeries1)
#     print(dataSeries1)
#     print(dataSeries)
    num1 = num1 + 1
#     for i in range(data_len-17):
#         fft.append([])
#     for i in range(data_len1-17):
#         fft1.append([])
#     f, t, Zxx = signal.stft(data[:,3],fs=1,noverlap=17,nperseg=18,nfft=1000,return_onesided= False,padded=True,detrend=False,boundary=None)
#     f1, t1, Zxx1 = signal.stft(data1[:,3],fs=1,noverlap=17,nperseg=18,nfft=1000,return_onesided= False,padded=True,detrend=False,boundary=None)
#     for i in range (len(Zxx[100,:])):
#         fft[i].append(Zxx[100,i].real)
#         fft[i].append(Zxx[600,i].real)
#         fft[i].append(Zxx[800,i].real)
#         #add[i].append((Zxx[100,i].conjugate()*Zxx[100,i]).real)
#         #add[i].append((Zxx[600,i].conjugate()*Zxx[600,i]).real)
#         #add[i].append((Zxx[800,i].conjugate()*Zxx[800,i]).real)
#     for i in range (len(Zxx1[100,:])):
#         #add1[i].append((Zxx1[100,i].conjugate()*Zxx1[100,i]).real)
#         #add1[i].append((Zxx1[600,i].conjugate()*Zxx1[600,i]).real)
#         #add1[i].append((Zxx1[800,i].conjugate()*Zxx1[800,i]).real)
#         fft1[i].append(Zxx1[100,i].real)
#         fft1[i].append(Zxx1[600,i].real)
#         fft1[i].append(Zxx1[800,i].real)
#     dataSeries = np.append(dataSeries, fft , axis=1)
#     dataSeries1 = np.append(dataSeries1,fft1, axis=1)
    randomForestModel = RandomForestClassifier(
        random_state=1111,
        oob_score= True,
        n_estimators=100,
        max_depth=3,
        min_samples_split=5,
        min_samples_leaf = 50,
        criterion = 'entropy',
        max_features = 0.2,
        )
    randomForestModel.fit(dataSeries, labelSeries)
    predict = randomForestModel.predict(dataSeries1)
    return predict

def RFF(data,data1):
    
    data = np.array(pd.read_csv(data))
    labelSeries = data[:,16]
    dataSeries = data[:,1:3]+data[:,7:9] #加速度儀和陀螺儀
    #x_train, x_test, y_train, y_test = train_test_split(dataSeries, labelSeries,test_size=0.2, random_state=222)
#     data1 = np.array(pd.read_csv(data1))
    dataSeries1 = data1[:,1:3]+data1[:,7:9] #加速度儀和陀螺儀
    #x_train1, x_test1, y_train1, y_test1 = train_test_split(dataSeries1, labelSeries1,test_size=0.2, random_state=222)

    randomForestModel = RandomForestClassifier(random_state=1,n_estimators=60 , max_depth=1 ,min_samples_split=70)
    # 使用訓練資料訓練模型
    #x_train=x_train.astype('int')
    #y_train=y_train.astype('str')
    #x_test=x_test.astype('int')
    #y_test=y_test.astype('str')
    randomForestModel.fit(dataSeries, labelSeries)
    # 使用訓練資料預測
    predict = randomForestModel.predict(dataSeries1)
#     RF_score = randomForestModel.score(dataSeries1,labelSeries1)
#     print(classification_report(labelSeries1,predict))
    return predict

serialPort = serial.Serial(port='COM4', baudrate=38400, timeout=2, parity=serial.PARITY_EVEN, stopbits=1)#HC-05-1
# serialPort = serial.Serial(port='COM4', baudrate=38400,timeout=2)#HC-05-1
#serialPort2 = serial.Serial(port='COM70', baudrate=38400, timeout=2, parity=serial.PARITY_EVEN, stopbits=1)#HC-05-2
#115200 esp32

while(1):
    global num
    count = datetime.now().strftime('%Y-%m-%d %H%M%S')
    data0506 = [
            "../All_Data/new_data/手2022-05-06 114900-4.csv",
            "../All_Data/new_data/手2022-05-06 113600-4.csv",
            "../All_Data/new_data/手2022-05-06 115200-2.csv",
            "../All_Data/new_data/腳2022-05-06 120000-4.csv",
            "../All_Data/new_data/腳2022-05-06 120300-3.csv",
            "../All_Data/new_data/腳2022-05-06 120500-4.csv",
            "../../../Add_fft_features_data/AfterFft_fft_arctan_36_Foot.csv",#21
            "../../../Add_fft_features_data/AfterFft_fft_arctan_38_Foot.csv",#22
            "../../../Add_fft_features_data/AfterFft_fft_arctan_40_Foot.csv",#23
            "./腳_"+".csv",
            "./腳_fft"+".csv"]#10
    
    print("hello")
    #/dev/cu.name
    size = 1024
    xg,yg,zg,mx,my,mz,xa,ya,za,xq,yq,zq,direc,mytime =[],[],[],[],[],[],[],[],[],[],[],[],[],[]
    #xg2,yg2,zg2,mx2,my2,mz2,xa2,ya2,za2,xq2,yq2,zq2,direc2,mytime2 =[],[],[],[],[],[],[],[],[],[],[],[],[],[]
    Ttime=str(datetime.now())
    print(Ttime)
    print(Ttime[17::])
    tt=0
    TT=5
    while(tt<=TT):
        
        data = serialPort.readline().decode('utf-8', 'ignore')
    #     data2 = serialPort2.readline().decode('utf-8')
        print(data)
    #     print(data2)
        data=data.split(',')
#         print(data)
    #     tempData = data
    #     tempData = pd.DataFrame(tempData)
    #     print(len(tempData))
#         if len(data)==16:
#             print("Hello")
#             print("Hand:",RFF(data0506[0],data))

    #     data2=data2.split(',')
    #     print(len(data),len(data2))
    #     print(float(str(datetime.now())[17::]))
        if (float(str(datetime.now())[17::])< float(Ttime[17::])):      
            tt = float(Ttime[17::])+60-float(str(datetime.now())[17::] )
            if tt>=TT:
                break
        else:
            tt = -float(Ttime[17::])+float(str(datetime.now())[17::] )
            if tt>=TT:
                break
        if len(data)==16:
            xg.append(data[1])
            yg.append(data[2])
            zg.append(data[3])
            mx.append(data[4])
            my.append(data[5])
            mz.append(data[6])
            xa.append(data[7])
            ya.append(data[8])
            za.append(data[9])
            xq.append(data[10])
            yq.append(data[11])
            zq.append(data[12])
            direc.append(data[13])
            mytime.append(data[14])
    #         pandasData1={"Xg":data[1],"Yg":data[2],"Zg":data[3],"Xm":data[4],"Ym":data[5],"Zm":data[6],"Xa":data[7],"Ya":data[8],"Za":data[9],"Xq":data[10],"Yq":data[11],"Zq":data[12],"Direction":data[13],"Time":data[14]}
    #         df1 = pd.DataFrame(pandasData1)
    #         df1.to_csv('腳_2'+'.csv')
    #         print("Hand:",RF(data0506[3],data0506[6]))
    #     if len(data2)==16:
    #         xg2.append(data2[1])
    #         yg2.append(data2[2])
    #         zg2.append(data2[3])
    #         mx2.append(data2[4])
    #         my2.append(data2[5])
    #         mz2.append(data2[6])
    #         xa2.append(data2[7])
    #         ya2.append(data2[8])
    #         za2.append(data2[9])
    #         xq2.append(data2[10])
    #         yq2.append(data2[11])
    #         zq2.append(data2[12])
    #         direc2.append(data2[13])
    #         mytime2.append(data2[14])
    if num == 1:
        
        pandasData={"Xg":xg,"Yg":yg,"Zg":zg,"Xm":mx,"Ym":my,"Zm":mz,"Xa":xa,"Ya":ya,"Za":za,"Xq":xq,"Yq":yq,"Zq":zq,"Direction":direc,"Time":mytime}
        # pandasData1={xg,yg,zg,mx,my,mz,xa,ya,za,xq,yq,zq,direc,mytime}
        # pandasData2={"Xg":xg2,"Yg":yg2,"Zg":zg2,"Xm":mx2,"Ym":my2,"Zm":mz2,"Xa":xa2,"Ya":ya2,"Za":za2,"Xq":xq2,"Yq":yq2,"Zq":zq2,"Direction":direc2,"Time":mytime2}
        df = pd.DataFrame(pandasData)
        #df2= pd.DataFrame(pandasData2)
        print(df)
        #print(df2)
        transform_fftArctan = 0
        df.to_csv('腳_'+'.csv')
    else:
        data1 = np.array(pd.read_csv(data0506[9]))
        xg = [xg]
        yg = [yg]
        zg = [zg]
        mx = [mx]
        my = [my]
        mz = [mz]
        xa = [xa]
        ya = [ya]
        za = [za]
        xq = [xq]
        yq = [yq]
        zq = [zq]
        direc = [direc]
        mytime = [mytime]
        
        temp1 = np.append(xg,yg,axis=0)
        temp1 = np.append(temp1,zg,axis=0)
        temp1 = np.append(temp1,mx,axis=0)
        temp1 = np.append(temp1,my,axis=0)
        temp1 = np.append(temp1,mz,axis=0)
        temp1 = np.append(temp1,xa,axis=0)
        temp1 = np.append(temp1,ya,axis=0)
        temp1 = np.append(temp1,za,axis=0)
        temp1 = np.append(temp1,xq,axis=0)
        temp1 = np.append(temp1,yq,axis=0)
        temp1 = np.append(temp1,zq,axis=0)
        temp1 = np.append(temp1,direc,axis=0)
        temp1 = np.append(temp1,mytime,axis=0).T
        
#         print(temp1)
        data1 = np.append(data1[:,1:15], temp1[:,0:14] , axis=0)
#         data1 = np.row_stack((data1[:,1:15], data[:,1:15] ))
#         pandasData={"Xg":data1[:,1],"Yg":data1[:,2],"Zg":data1[:,3],"Xm":data1[:,4],"Ym":data1[:,5],"Zm":data1[:,6],"Xa":data1[:,7],"Ya":data1[:,8],"Za":data1[:,9],"Xq":data1[:,10],"Yq":data1[:,11],"Zq":data1[:,12],"Direction":data1[:,13],"SensorTime":data1[:,14]}
        pandasData={"Xg":data1[:,0],"Yg":data1[:,1],"Zg":data1[:,2],"Xm":data1[:,3],"Ym":data1[:,4],"Zm":data1[:,5],"Xa":data1[:,6],"Ya":data1[:,7],"Za":data1[:,8],"Xq":data1[:,9],"Yq":data1[:,10],"Zq":data1[:,11],"Direction":data1[:,12],"SensorTime":data1[:,13]}
#         pandasData={"Fft_gx":data1[:,1],"Fft_gy":data1[:,2],"Fft_gz":data1[:,3],"Fft_ax":data1[:,4],"Fft_ay":data1[:,5],"Fft_az":data1[:,6]}
        df = pd.DataFrame(pandasData)
        df.to_csv("腳_"+".csv")
        
    num = num + 1
    #df2.to_csv('手'+datetime.now().strftime('%Y-%m-%d %H%M%S')+'.csv')
    print("--------------------------------\nRandomForest\n-------------------------------")
    #for i in range(len(data0506)//2):
    add_arctan(data0506[9])
    for i in range(1):
        print("Hand:",RF(data0506[6],data0506[9],data0506[10]))
        print("")
        dff = pd.DataFrame(RF(data0506[6],data0506[9],data0506[10]))
    #     print("Foot:",RF(data0506[i+2],data0506[i+3]))
    #     print("________________________________________________________")
    dff.to_csv('label_'+count+'.csv')
    
serialPort.close()
#serialPort2.close()
# Out:
# hello
# 2022-08-06 17:32:12.840805
# 12.840805
# 0.45,0.09,0.87,8156,
#
# ,0.11,0.35,0.06,0.56,-10.94,-13.31,-8.16,4.81,2.07,0.17,0.45,0.09,0.87,8195,
#
# ,0.11,0.35,0.06,0.56,-10.94,-13.31,-7.93,4.85,1.68,0.17,0.45,0.09,0.87,8231,
#
# ,0.12,0.36,-0.02,0.56,-10.94,-13.31,-7.93,4.85,1.68,0.17,0.45,0.09,0.87,8270,
#
# ,0.09,0.25,0.04,0.56,-10.94,-13.31,-7.93,4.85,1.68,0.17,0.45,0.09,0.87,8308,
#
# ,0.09,0.25,0.04,0.56,-10.94,-13.31,-8.24,5.08,1.76,0.17,0.45,0.09,0.87,8347,
#
# ,0.09,0.25,0.04,0.56,-10.94,-13.31,-8.24,5.08,1.61,0.17,0.45,0.09,0.87,8384,
#
# ,0.02,0.13,0.03,0.56,-10.94,-13.31,-8.24,5.08,1.61,0.17,0.45,0.09,0.87,8421,
#
# ,0.02,0.13,0.03,0.56,-10.94,-13.31,-8.20,5.08,1.53,0.17,0.45,0.09,0.87,8460,
#
# ,0.01,0.08,-0.00,0.56,-10.94,-13.31,-8.20,5.08,1.53,0.17,0.45,0.09,0.87,8498,
#
# ,0.01,0.08,-0.00,0.56,-10.94,-13.31,-8.20,5.08,1.49,0.17,0.45,0.09,0.87,8535,
#
# ,0.02,0.12,0.02,0.56,-10.94,-13.31,-8.20,5.08,1.49,0.17,0.45,0.09,0.87,8573,
#
# ,0.02,0.12,0.02,0.56,-10.94,-13.31,-8.27,5.12,1.49,0.17,0.45,0.09,0.87,8613,
#
# ,0.02,0.24,0.01,0.56,-10.94,-13.31,-8.27,5.12,1.49,0.17,0.45,0.09,0.87,8651,
#
# ,0.02,0.24,0.01,0.56,-10.94,-13.31,-8.24,5.08,1.30,0.17,0.45,0.09,0.87,8689,
#
# ,0.02,0.24,0.01,2.31,-11.75,-10.00,-8.24,5.08,1.30,0.17,0.45,0.09,0.87,8726,
#
# ,-0.01,0.14,-0.00,2.31,-11.75,-10.00,-8.24,5.08,1.30,0.17,0.45,0.09,0.87,8764,
#
# ,-0.01,0.14,-0.00,2.31,-11.75,-10.00,-8.27,5.12,1.07,0.17,0.45,0.09,0.87,8804,
#
# ,-0.01,0.14,-0.00,2.31,-11.75,-10.00,-8.27,5.12,1.07,0.17,0.45,0.09,0.87,8844,
#
# ,-0.01,0.14,-0.00,2.31,-11.75,-10.00,-8.27,5.08,1.11,0.17,0.45,0.09,0.87,8881,
#
# ,0.00,-0.05,0.00,2.31,-11.75,-10.00,-8.27,5.08,1.11,0.17,0.45,0.09,0.87,8920,
#
# ,0.00,-0.05,0.00,2.31,-11.75,-10.00,-8.27,5.12,1.14,0.17,0.45,0.09,0.87,8957,
#
# ,0.00,-0.05,0.00,2.31,-11.75,-10.00,-8.27,5.12,1.14,0.17,0.45,0.09,0.87,8997,
#
# ,0.00,-0.05,0.00,2.31,-11.75,-10.00,-8.24,5.12,1.18,0.17,0.45,0.09,0.87,9034,
#
# ,-0.00,-0.03,0.01,2.31,-11.75,-10.00,-8.24,5.12,1.18,0.17,0.45,0.09,0.87,9073,
#
# ,-0.00,-0.03,0.01,2.31,-11.75,-10.00,-8.24,5.12,1.22,0.17,0.45,0.09,0.87,9111,
#
# ,-0.00,-0.03,0.01,2.31,-11.75,-10.00,-8.24,5.12,1.18,0.17,0.45,0.09,0.87,9150,
#
# ,-0.00,-0.03,0.01,2.31,-11.75,-10.00,-8.24,5.12,1.22,0.17,0.45,0.09,0.87,9189,
#
# ,-0.00,-0.03,0.01,2.13,-13.31,-10.06,-8.24,5.12,1.22,0.17,0.45,0.09,0.87,9226,
#
# ,0.00,-0.01,0.01,2.13,-13.31,-10.06,-8.24,5.12,1.22,0.17,0.45,0.09,0.87,9266,
#
# ,0.00,-0.01,0.01,2.13,-13.31,-10.06,-8.24,5.12,1.18,0.17,0.45,0.09,0.87,9306,
#
# ,0.00,-0.01,0.01,2.13,-13.31,-10.06,-8.24,5.12,1.22,0.17,0.45,0.09,0.87,9345,
#
# ,0.00,-0.01,0.01,2.13,-13.31,-10.06,-8.24,5.12,1.22,0.17,0.45,0.09,0.87,9381,
#
# ,-0.00,0.01,0.00,2.13,-13.31,-10.06,-8.24,5.12,1.22,0.17,0.45,0.09,0.87,9420,
#
# ,-0.00,0.01,0.00,2.13,-13.31,-10.06,-8.24,5.12,1.22,0.17,0.45,0.09,0.87,9459,
#
# ,-0.00,0.01,0.00,2.13,-13.31,-10.06,-8.24,5.12,1.18,0.17,0.45,0.09,0.87,9499,
#
# ,-0.00,0.01,0.00,2.13,-13.31,-10.06,-8.24,5.12,1.18,0.17,0.45,0.09,0.87,9536,
#
# ,0.00,0.03,0.00,2.13,-13.31,-10.06,-8.24,5.12,1.18,0.17,0.45,0.09,0.87,9575,
#
# ,0.00,0.03,0.00,2.13,-13.31,-10.06,-8.24,5.12,1.18,0.17,0.45,0.09,0.87,9615,
#
# ,0.00,0.03,0.00,2.13,-13.31,-10.06,-8.24,5.12,1.18,0.17,0.45,0.09,0.87,9653,
#
# ,0.00,0.03,0.00,2.13,-13.31,-10.06,-8.24,5.12,1.14,0.17,0.45,0.09,0.87,9691,
#
# ,0.00,0.03,0.00,2.13,-13.31,-10.06,-8.24,5.12,1.14,0.17,0.45,0.09,0.87,9728,
#
# ,0.00,0.02,0.00,2.13,-13.31,-10.06,-8.24,5.12,1.14,0.17,0.45,0.09,0.87,9766,
#
# ,0.00,0.02,0.00,2.13,-13.31,-10.06,-8.24,5.12,1.14,0.17,0.45,0.09,0.87,9805,
#
# ,0.00,0.02,0.00,2.13,-13.31,-10.06,-8.24,5.12,1.14,0.17,0.45,0.09,0.87,9844,
#
# ,0.00,0.02,0.00,2.13,-13.31,-10.06,-8.24,5.12,1.11,0.17,0.45,0.09,0.87,9881,
#
# ,0.00,0.02,-0.00,2.13,-13.31,-10.06,-8.24,5.12,1.11,0.17,0.45,0.09,0.87,9919,
#
# ,0.00,0.02,-0.00,2.13,-13.31,-10.06,-8.24,5.12,1.11,0.17,0.45,0.09,0.87,9957,
#
# ,0.00,0.02,-0.00,2.13,-13.31,-10.06,-8.27,5.12,1.11,0.17,0.45,0.09,0.87,9997,
#
# ,0.00,0.02,-0.00,2.13,-13.31,-10.06,-8.24,5.12,1.11,0.17,0.45,0.09,0.87,10034,
#
# ,0.00,0.01,0.00,2.13,-13.31,-10.06,-8.24,5.12,1.11,0.17,0.45,0.09,0.87,10073,
#
# ,0.00,0.01,0.00,2.13,-13.31,-10.06,-7.16,4.35,0.95,0.17,0.45,0.09,0.87,10112,
#
# ,0.00,0.01,0.00,2.13,-13.31,-10.06,-9.65,6.15,1.64,0.17,0.45,0.09,0.87,10150,
#
# ,0.00,0.01,0.00,2.13,-13.31,-10.06,-8.12,5.16,1.34,0.17,0.45,0.09,0.87,10188,
#
# ,0.00,0.01,0.00,2.38,-13.00,-10.06,-8.12,5.16,1.34,0.17,0.45,0.09,0.87,10226,
#
# ,0.01,0.03,0.00,2.38,-13.00,-10.06,-8.12,5.16,1.34,0.17,0.45,0.09,0.87,10265,
#
# ,0.01,0.03,0.00,2.38,-13.00,-10.06,-8.16,5.20,1.26,0.17,0.45,0.09,0.87,10305,
#
# ,0.01,0.03,0.00,2.38,-13.00,-10.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,10344,
#
# ,0.01,0.03,0.00,2.38,-13.00,-10.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,10381,
#
# ,0.01,-0.01,-0.00,2.38,-13.00,-10.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,10419,
#
# ,0.01,-0.01,-0.00,2.38,-13.00,-10.06,-8.16,5.20,1.30,0.17,0.45,0.09,0.87,10459,
#
# ,0.01,-0.01,-0.00,2.38,-13.00,-10.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,10499,
#
# ,0.01,-0.01,-0.00,2.38,-13.00,-10.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,10536,
#
# ,0.00,0.00,-0.00,2.38,-13.00,-10.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,10575,
#
# ,0.00,0.00,-0.00,2.38,-13.00,-10.06,-8.16,5.20,1.34,0.17,0.45,0.09,0.87,10615,
#
# ,0.00,-0.01,-0.00,2.38,-13.00,-10.06,-8.16,5.20,1.34,0.17,0.45,0.09,0.87,10655,
#
# ,0.00,-0.01,-0.00,2.38,-13.00,-10.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,10695,
#
# ,0.00,-0.01,-0.00,2.38,-13.00,-10.06,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,10732,
#
# ,0.01,-0.02,0.00,2.38,-13.00,-10.06,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,10773,
#
# ,-0.01,-0.01,0.00,2.38,-13.00,-10.06,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,10812,
#
# ,-0.01,-0.01,0.00,2.38,-13.00,-10.06,-8.20,5.20,1.34,0.17,0.45,0.09,0.87,10851,
#
# ,-0.01,-0.01,0.00,2.38,-13.00,-10.06,-8.20,5.20,1.34,0.17,0.45,0.09,0.87,10890,
#
# ,-0.01,-0.01,0.00,1.19,-12.38,-10.38,-8.20,5.20,1.34,0.17,0.45,0.09,0.87,10928,
#
# ,-0.01,-0.01,0.00,1.19,-12.38,-10.38,-8.16,5.20,1.34,0.17,0.45,0.09,0.87,10968,
#
# ,0.00,0.01,-0.00,1.19,-12.38,-10.38,-8.16,5.20,1.34,0.17,0.45,0.09,0.87,11008,
#
# ,0.00,0.01,-0.00,1.19,-12.38,-10.38,-8.20,5.20,1.34,0.17,0.45,0.09,0.87,11046,
#
# ,0.00,0.01,-0.00,1.19,-12.38,-10.38,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,11084,
#
# ,-0.00,0.01,-0.00,1.19,-12.38,-10.38,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,11123,
#
# ,0.00,0.01,0.00,1.19,-12.38,-10.38,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,11163,
#
# ,0.00,0.01,0.00,1.19,-12.38,-10.38,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,11201,
#
# ,0.00,0.01,0.00,1.19,-12.38,-10.38,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,11240,
#
# ,0.00,0.01,0.00,1.19,-12.38,-10.38,-8.16,5.20,1.34,0.17,0.45,0.09,0.87,11277,
#
# ,0.00,0.00,0.00,1.19,-12.38,-10.38,-8.16,5.20,1.34,0.17,0.45,0.09,0.87,11317,
#
# ,0.00,0.00,0.00,1.19,-12.38,-10.38,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,11356,
#
# ,0.00,0.00,0.00,1.19,-12.38,-10.38,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,11395,
#
# ,0.00,0.00,0.00,1.19,-12.38,-10.38,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,11431,
#
# ,0.00,0.00,0.00,1.19,-12.38,-10.38,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,11469,
#
# ,-0.00,0.00,-0.00,1.19,-12.38,-10.38,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,11508,
#
# ,-0.00,0.00,-0.00,1.19,-12.38,-10.38,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,11547,
#
# ,-0.00,0.00,-0.00,1.19,-12.38,-10.38,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,11585,
#
# ,0.00,0.01,0.00,1.19,-12.38,-10.38,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,11625,
#
# ,0.00,0.01,-0.00,1.19,-12.38,-10.38,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,11664,
#
# ,0.00,0.01,-0.00,1.19,-12.38,-10.38,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,11703,
#
# ,0.00,0.01,-0.00,1.19,-12.38,-10.38,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,11743,
#
# ,0.00,0.01,-0.00,1.19,-12.38,-10.38,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,11780,
#
# ,-0.00,0.00,0.00,1.19,-12.38,-10.38,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,11819,
#
# ,-0.00,0.00,0.00,1.19,-12.38,-10.38,-8.20,5.20,1.34,0.17,0.45,0.09,0.87,11857,
#
# ,-0.00,0.00,0.00,1.19,-12.38,-10.38,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,11896,
#
# ,-0.00,0.00,0.00,1.19,-12.38,-10.38,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,11934,
#
# ,0.00,0.00,0.00,1.19,-12.38,-10.38,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,11973,
#
# ,0.00,0.00,-0.00,1.19,-12.38,-10.38,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,12013,
#
# ,0.00,0.00,-0.00,1.19,-12.38,-10.38,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,12051,
#
# ,0.00,0.00,-0.00,1.19,-12.38,-10.38,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,12090,
#
# ,0.00,0.00,-0.00,1.19,-12.38,-10.38,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,12127,
#
# ,0.00,0.01,-0.00,1.19,-12.38,-10.38,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,12167,
#
# ,0.00,0.01,-0.00,1.19,-12.38,-10.38,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,12206,
#
# ,0.00,0.01,-0.00,1.19,-12.38,-10.38,-8.16,5.20,1.30,0.17,0.45,0.09,0.87,12246,
#        Xg    Yg     Zg    Xm      Ym      Zm     Xa    Ya    Za    Xq    Yq  \
# 0    0.11  0.35   0.06  0.56  -10.94  -13.31  -8.16  4.81  2.07  0.17  0.45
# 1    0.11  0.35   0.06  0.56  -10.94  -13.31  -7.93  4.85  1.68  0.17  0.45
# 2    0.12  0.36  -0.02  0.56  -10.94  -13.31  -7.93  4.85  1.68  0.17  0.45
# 3    0.09  0.25   0.04  0.56  -10.94  -13.31  -7.93  4.85  1.68  0.17  0.45
# 4    0.09  0.25   0.04  0.56  -10.94  -13.31  -8.24  5.08  1.76  0.17  0.45
# ..    ...   ...    ...   ...     ...     ...    ...   ...   ...   ...   ...
# 100  0.00  0.00  -0.00  1.19  -12.38  -10.38  -8.20  5.20  1.30  0.17  0.45
# 101  0.00  0.00  -0.00  1.19  -12.38  -10.38  -8.20  5.16  1.30  0.17  0.45
# 102  0.00  0.00  -0.00  1.19  -12.38  -10.38  -8.20  5.16  1.34  0.17  0.45
# 103  0.00  0.01  -0.00  1.19  -12.38  -10.38  -8.20  5.16  1.34  0.17  0.45
# 104  0.00  0.01  -0.00  1.19  -12.38  -10.38  -8.20  5.16  1.30  0.17  0.45
#
#        Zq Direction   Time
# 0    0.09      0.87   8195
# 1    0.09      0.87   8231
# 2    0.09      0.87   8270
# 3    0.09      0.87   8308
# 4    0.09      0.87   8347
# ..    ...       ...    ...
# 100  0.09      0.87  12051
# 101  0.09      0.87  12090
# 102  0.09      0.87  12127
# 103  0.09      0.87  12167
# 104  0.09      0.87  12206
#
# [105 rows x 14 columns]
# --------------------------------
# RandomForest
# -------------------------------
# 80
# Hand: ['W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W']
#
# hello
# 2022-08-06 17:32:18.256067
# 18.256067
# ,0.00,0.01,-0.00,1.19,-12.38,-10.38,-8.16,5.20,1.30,0.17,0.45,0.09,0.87,12283,
#
# ,0.00,0.01,0.00,1.19,-12.38,-10.38,-8.16,5.20,1.30,0.17,0.45,0.09,0.87,12322,
#
# ,0.00,0.01,0.00,1.19,-12.38,-10.38,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,12360,
#
# ,0.00,0.01,0.00,1.19,-12.38,-10.38,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,12399,
#
# ,0.00,0.01,0.00,1.19,-12.38,-10.38,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,12438,
#
# ,0.00,0.01,0.00,1.69,-12.00,-9.44,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,12475,
#
# ,-0.00,0.00,0.00,1.69,-12.00,-9.44,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,12514,
#
# ,-0.00,0.00,0.00,1.69,-12.00,-9.44,-8.20,5.20,1.34,0.17,0.45,0.09,0.87,12552,
#
# ,-0.00,0.00,0.00,1.69,-12.00,-9.44,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,12592,
#
# ,-0.00,0.00,0.00,1.69,-12.00,-9.44,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,12628,
#
# ,-0.00,0.01,-0.00,1.69,-12.00,-9.44,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,12667,
#
# ,-0.00,0.01,-0.00,1.69,-12.00,-9.44,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,12706,
#
# ,-0.00,0.01,-0.00,1.69,-12.00,-9.44,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,12746,
#
# ,-0.00,0.01,-0.00,1.69,-12.00,-9.44,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,12783,
#
# ,0.00,-0.00,-0.00,1.69,-12.00,-9.44,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,12822,
#
# ,0.00,-0.00,-0.00,1.69,-12.00,-9.44,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,12861,
#
# ,0.00,-0.00,-0.00,1.69,-12.00,-9.44,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,12900,
#
# ,0.00,-0.00,-0.00,1.69,-12.00,-9.44,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,12938,
#
# ,0.00,-0.00,-0.00,1.88,-12.44,-11.50,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,12976,
#
# ,-0.00,0.00,0.00,1.88,-12.44,-11.50,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,13015,
#
# ,-0.00,0.00,0.00,1.88,-12.44,-11.50,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,13056,
#
# ,-0.00,0.00,0.00,1.88,-12.44,-11.50,-8.16,5.20,1.30,0.17,0.45,0.09,0.87,13094,
#
# ,-0.00,0.00,0.00,1.88,-12.44,-11.50,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,13131,
#
# ,0.00,0.00,0.00,1.88,-12.44,-11.50,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,13171,
#
# ,0.00,0.00,0.00,1.88,-12.44,-11.50,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,13209,
#
# ,0.00,0.00,0.00,1.88,-12.44,-11.50,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,13248,
#
# ,0.00,0.00,0.00,1.88,-12.44,-11.50,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,13286,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,13324,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.20,5.20,1.34,0.17,0.45,0.09,0.87,13363,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,13402,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,13440,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.16,5.16,1.30,0.17,0.45,0.09,0.87,13475,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.16,5.16,1.30,0.17,0.45,0.09,0.87,13514,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,13553,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,13592,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,13629,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,13667,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,13705,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,13745,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,13782,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,13819,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,13857,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,13896,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,13933,
#
# ,-0.00,0.00,0.00,1.75,-11.75,-9.94,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,13971,
#
# ,0.00,0.01,0.00,1.75,-11.75,-9.94,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,14009,
#
# ,0.00,0.01,0.00,1.75,-11.75,-9.94,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,14048,
#
# ,0.00,0.01,0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,14085,
#
# ,0.00,0.00,-0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,14125,
#
# ,0.00,0.00,-0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,14163,
#
# ,0.00,0.00,-0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,14201,
#
# ,0.00,0.00,-0.00,1.75,-11.75,-9.94,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,14239,
#
# ,0.00,0.00,-0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,14277,
#
# ,0.00,-0.00,0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,14316,
#
# ,-0.00,-0.00,0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,14355,
#
# ,-0.00,-0.00,0.00,1.75,-11.75,-9.94,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,14393,
#
# ,-0.00,-0.00,0.00,1.75,-11.75,-9.94,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,14431,
#
# ,0.00,0.01,0.00,1.75,-11.75,-9.94,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,14470,
#
# ,0.00,0.01,0.00,1.75,-11.75,-9.94,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,14508,
#
# ,0.00,0.01,0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,14546,
#
# ,0.00,0.01,0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,14583,
#
# ,0.00,0.00,0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,14622,
#
# ,0.00,-0.01,0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,14661,
#
# ,0.00,-0.01,0.00,1.75,-11.75,-9.94,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,14699,
#
# ,0.00,-0.01,0.00,1.75,-11.75,-9.94,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,14736,
#
# ,0.00,-0.01,0.00,2.19,-12.75,-11.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,14775,
#
# ,0.00,0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,14814,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,14854,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,14893,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,14930,
#
# ,-0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,14968,
#
# ,0.00,0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15007,
#
# ,0.00,0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15046,
#
# ,0.00,0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15084,
#
# ,-0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15124,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15163,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15202,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.20,1.26,0.17,0.45,0.09,0.87,15241,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15278,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15315,
#
# ,0.00,0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15355,
#
# ,0.00,0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15393,
# ,0.00,0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15431,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15470,
#
# ,-0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15509,
#
# ,-0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15548,
#
# ,-0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15585,
#
# ,0.00,0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15626,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15665,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15704,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15745,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15781,
#
# ,-0.00,0.01,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15820,
#
# ,0.00,0.01,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15859,
#
# ,0.00,0.01,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15897,
#
# ,0.00,0.01,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15935,
#
# ,0.00,-0.01,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,15974,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,16013,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,16052,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,16093,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,16130,
#
# ,-0.00,0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,16168,
#
# ,-0.00,0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,16207,
#
# ,-0.00,0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,16247,
#
# ,-0.00,0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,16285,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,16324,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,16363,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,16403,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,16443,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,16480,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,16519,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,16557,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,16596,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,16633,
#
# ,0.00,-0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,16672,
#
# ,0.00,-0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,16712,
#
# ,0.00,-0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,16752,
#
# ,0.00,-0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,16792,
#
# ,0.00,-0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,16830,
#
# ,0.00,-0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,16870,
#
# ,-0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,16909,
#
# ,-0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,16947,
#
# ,-0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,16985,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17024,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17063,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17102,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17142,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,17178,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17217,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17256,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17295,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17332,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17373,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17412,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17449,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,17488,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17525,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17565,
#
# ,0.00,0.01,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17604,
#
# ,0.00,0.01,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17643,
#
# --------------------------------
# RandomForest
# -------------------------------
# 163
# Hand: ['W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W']
#
# hello
# 2022-08-06 17:32:23.702770
# 23.702770
# ,0.00,0.01,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17681,
#
# ,-0.00,0.01,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17720,
#
# ,-0.00,0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17758,
#
# ,-0.00,0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17797,
#
# ,-0.00,0.00,-0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17835,
#
# ,0.00,-0.01,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17875,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17915,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17954,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,17993,
#
# ,0.00,-0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,18031,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,18071,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,18109,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,18148,
#
# ,0.00,0.00,0.00,2.19,-12.75,-11.06,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,18187,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,18224,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,18263,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,18300,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,18339,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,18375,
#
# ,-0.00,-0.00,0.00,1.75,-10.81,-9.88,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,18414,
#
# ,-0.00,-0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,18453,
#
# ,-0.00,-0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,18492,
#
# ,-0.00,-0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,18530,
#
# ,-0.00,0.00,-0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,18569,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,18607,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,18646,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,18682,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,18721,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,18759,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,18797,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,18834,
#
# ,0.00,0.01,-0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,18873,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,18912,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,18951,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,18988,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,19024,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,19064,
#
# ,-0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,19102,
# ,-0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,19141,
#
# ,-0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,19178,
#
# ,-0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,19217,
#
# ,0.00,-0.00,-0.00,1.75,-10.81,-9.88,-8.20,5.20,1.30,0.17,0.45,0.09,0.87,19255,
#
# ,0.00,-0.00,-0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,19295,
#
# ,0.00,-0.00,-0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,19332,
#
# ,0.00,-0.00,-0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,19373,
#
# ,0.00,0.00,-0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,19411,
#
# ,0.00,0.00,-0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,19449,
#
# ,0.00,0.00,-0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,19487,
#
# ,0.00,0.00,-0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,19524,
#
# ,0.00,0.00,-0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,19564,
#
# ,0.00,0.01,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,19603,
#
# ,0.00,0.01,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,19641,
#
# ,0.00,0.01,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,19678,
#
# ,0.00,0.01,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,19717,
#
# ,0.00,-0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,19755,
#
# ,0.00,-0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,19793,
#
# ,0.00,-0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,19830,
#
# ,-0.00,-0.01,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,19869,
#
# ,-0.00,-0.01,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,19908,
#
# ,-0.00,-0.01,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,19946,
#
# ,-0.00,-0.01,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,19984,
#
# ,-0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,20023,
#
# ,-0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,20063,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,20102,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,20141,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,20177,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,20215,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,20254,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.24,5.16,1.30,0.17,0.45,0.09,0.87,20293,
#
# ,0.00,0.00,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,20329,
#
# ,-0.00,-0.01,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,20367,
#
# ,-0.00,-0.01,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,20407,
#
# ,0.00,0.04,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,20445,
#
# ,0.00,0.04,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,20482,
#
# ,-0.00,0.08,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,20520,
#
# ,-0.00,0.08,0.00,1.75,-10.81,-9.88,-8.20,5.16,1.22,0.17,0.45,0.09,0.87,20560,
#
# ,0.00,-0.00,-0.00,1.75,-10.81,-9.88,-8.20,5.16,1.22,0.17,0.45,0.09,0.87,20598,
#
# ,0.00,-0.00,-0.00,1.75,-10.81,-9.88,-8.24,5.16,1.22,0.17,0.45,0.09,0.87,20636,
#
# ,0.00,-0.00,-0.00,2.75,-13.06,-11.19,-8.24,5.16,1.22,0.17,0.45,0.09,0.87,20674,
#
# ,0.00,-0.04,0.00,2.75,-13.06,-11.19,-8.24,5.16,1.22,0.17,0.45,0.09,0.87,20713,
#
# ,0.00,-0.04,0.00,2.75,-13.06,-11.19,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,20754,
#
# ,0.00,-0.04,0.00,2.75,-13.06,-11.19,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,20793,
#
# ,0.00,-0.04,0.00,2.75,-13.06,-11.19,-8.20,5.20,1.26,0.17,0.45,0.09,0.87,20831,
#
# ,0.01,-0.02,0.00,2.75,-13.06,-11.19,-8.20,5.20,1.26,0.17,0.45,0.09,0.87,20870,
#
# ,0.01,-0.02,0.00,2.75,-13.06,-11.19,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,20910,
#
# ,-0.00,-0.04,-0.00,2.75,-13.06,-11.19,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,20947,
#
# ,-0.00,-0.04,-0.00,2.75,-13.06,-11.19,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,20987,
#
# ,-0.00,-0.04,-0.00,2.44,-12.44,-11.13,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,21025,
#
# ,-0.00,-0.04,-0.00,2.44,-12.44,-11.13,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,21066,
#
# ,0.00,-0.01,-0.00,2.44,-12.44,-11.13,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,21106,
#
# ,0.00,-0.01,-0.00,2.44,-12.44,-11.13,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,21146,
#
# ,0.00,-0.01,-0.00,2.44,-12.44,-11.13,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,21184,
#
# ,0.01,-0.01,-0.02,2.44,-12.44,-11.13,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,21224,
#
# ,-0.01,-0.05,0.00,2.44,-12.44,-11.13,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,21264,
#
# ,-0.01,-0.05,0.00,2.44,-12.44,-11.13,-8.20,5.16,1.38,0.17,0.45,0.09,0.87,21304,
#
# ,-0.01,-0.05,0.00,2.44,-12.44,-11.13,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,21344,
#
# ,-0.01,-0.05,0.00,2.44,-12.44,-11.13,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,21382,
#
# ,-0.01,-0.05,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,21422,
#
# ,0.00,-0.07,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,21460,
#
# ,0.00,-0.07,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.41,0.17,0.45,0.09,0.87,21499,
#
# ,0.00,-0.07,0.00,1.38,-10.50,-9.31,-8.16,5.16,1.45,0.17,0.45,0.09,0.87,21537,
#
# ,0.00,-0.07,0.00,1.38,-10.50,-9.31,-8.16,5.16,1.49,0.17,0.45,0.09,0.87,21574,
#
# ,0.00,0.01,-0.00,1.38,-10.50,-9.31,-8.16,5.16,1.49,0.17,0.45,0.09,0.87,21613,
#
# ,0.00,0.01,-0.00,1.38,-10.50,-9.31,-8.16,5.16,1.45,0.17,0.45,0.09,0.87,21652,
#
# ,0.00,0.01,-0.00,1.38,-10.50,-9.31,-8.16,5.16,1.49,0.17,0.45,0.09,0.87,21692,
#
# ,0.00,0.01,-0.00,1.38,-10.50,-9.31,-8.20,5.16,1.41,0.17,0.45,0.09,0.87,21729,
#
# ,-0.00,0.04,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.41,0.17,0.45,0.09,0.87,21767,
#
# ,-0.00,0.04,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.41,0.17,0.45,0.09,0.87,21806,
#
# ,-0.00,0.04,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.38,0.17,0.45,0.09,0.87,21844,
#
# ,-0.00,0.04,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.38,0.17,0.45,0.09,0.87,21881,
#
# ,0.00,0.04,-0.00,1.38,-10.50,-9.31,-8.20,5.16,1.38,0.17,0.45,0.09,0.87,21920,
#
# ,-0.00,0.01,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.38,0.17,0.45,0.09,0.87,21960,
#
# ,-0.00,0.01,0.00,1.38,-10.50,-9.31,-8.16,5.16,1.38,0.17,0.45,0.09,0.87,21999,
#
# ,-0.00,0.01,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.38,0.17,0.45,0.09,0.87,22037,
#
# ,-0.00,0.01,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,22074,
#
# ,0.00,-0.04,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,22113,
#
# ,0.00,-0.04,0.00,1.38,-10.50,-9.31,-8.16,5.16,1.38,0.17,0.45,0.09,0.87,22152,
#
# ,0.00,-0.04,0.00,1.38,-10.50,-9.31,-8.16,5.16,1.41,0.17,0.45,0.09,0.87,22192,
#
# ,0.00,-0.04,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.38,0.17,0.45,0.09,0.87,22228,
#
# ,0.00,0.02,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.38,0.17,0.45,0.09,0.87,22266,
#
# ,0.00,0.02,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.41,0.17,0.45,0.09,0.87,22304,
#
# ,0.00,0.02,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.38,0.17,0.45,0.09,0.87,22343,
#
# ,0.00,0.02,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,22380,
#
# ,-0.00,0.07,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,22418,
#
# ,0.00,0.05,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.34,0.17,0.45,0.09,0.87,22457,
#
# ,0.00,0.05,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,22495,
#
# ,0.00,0.05,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,22532,
#
# ,-0.00,0.02,0.00,1.38,-10.50,-9.31,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,22571,
#
# ,0.00,0.02,-0.00,1.38,-10.50,-9.31,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,22608,
#
# ,0.00,0.02,-0.00,1.38,-10.50,-9.31,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,22646,
#
# ,0.00,0.02,-0.00,1.38,-10.50,-9.31,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,22685,
#
# ,0.00,0.02,-0.00,1.94,-11.25,-12.50,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,22723,
#
# ,0.00,-0.01,0.00,1.94,-11.25,-12.50,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,22763,
#
# ,0.00,-0.01,0.00,1.94,-11.25,-12.50,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,22802,
#
# ,0.00,-0.01,0.00,1.94,-11.25,-12.50,-8.20,5.16,1.30,0.17,0.45,0.09,0.87,22841,
#
# ,0.00,-0.01,0.00,1.94,-11.25,-12.50,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,22879,
#
# ,0.00,0.00,0.00,1.94,-11.25,-12.50,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,22918,
#
# ,0.00,0.01,-0.00,1.94,-11.25,-12.50,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,22957,
#
# ,0.00,0.01,-0.00,1.94,-11.25,-12.50,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,22995,
#
# ,0.00,0.01,-0.00,1.94,-11.25,-12.50,-8.20,5.16,1.26,0.17,0.45,0.09,0.87,23033,
#
# --------------------------------
# RandomForest
# -------------------------------
# 139
# Hand: ['W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 397>()
#     538     print("Hand:",RF(data0506[6],data0506[9],data0506[10]))
#     539     print("")
# --> 540     dff = pd.DataFrame(RF(data0506[6],data0506[9],data0506[10]))
#     541 #     print("Foot:",RF(data0506[i+2],data0506[i+3]))
#     542 #     print("________________________________________________________")
#     543 dff.to_csv('label_'+count+'.csv')
#
# Input In [1], in RF(data, data1, data2)
#     331 #     for i in range(data_len-17):
#     332 #         fft.append([])
#     333 #     for i in range(data_len1-17):
#    (...)
#     351 #     dataSeries = np.append(dataSeries, fft , axis=1)
#     352 #     dataSeries1 = np.append(dataSeries1,fft1, axis=1)
#     353     randomForestModel = RandomForestClassifier(
#     354         random_state=1111,
#     355         oob_score= True,
#    (...)
#     361         max_features = 0.2,
#     362         )
# --> 363     randomForestModel.fit(dataSeries, labelSeries)
#     364     predict = randomForestModel.predict(dataSeries1)
#     365     return predict
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:450, in BaseForest.fit(self, X, y, sample_weight)
#     439 trees = [
#     440     self._make_estimator(append=False, random_state=random_state)
#     441     for i in range(n_more_estimators)
#     442 ]
#     444 # Parallel loop: we prefer the threading backend as the Cython code
#     445 # for fitting the trees is internally releasing the Python GIL
#     446 # making threading more efficient than multiprocessing in
#     447 # that case. However, for joblib 0.12+ we respect any
#     448 # parallel_backend contexts set at a higher level,
#     449 # since correctness does not rely on using threads.
# --> 450 trees = Parallel(
#     451     n_jobs=self.n_jobs,
#     452     verbose=self.verbose,
#     453     **_joblib_parallel_args(prefer="threads"),
#     454 )(
#     455     delayed(_parallel_build_trees)(
#     456         t,
#     457         self,
#     458         X,
#     459         y,
#     460         sample_weight,
#     461         i,
#     462         len(trees),
#     463         verbose=self.verbose,
#     464         class_weight=self.class_weight,
#     465         n_samples_bootstrap=n_samples_bootstrap,
#     466     )
#     467     for i, t in enumerate(trees)
#     468 )
#     470 # Collect newly grown trees
#     471 self.estimators_.extend(trees)
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:185, in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     182     elif class_weight == "balanced_subsample":
#     183         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 185     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     186 else:
#     187     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:937, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     899 def fit(
#     900     self, X, y, sample_weight=None, check_input=True, X_idx_sorted="deprecated"
#     901 ):
#     902     """Build a decision tree classifier from the training set (X, y).
#     903
#     904     Parameters
#    (...)
#     934         Fitted estimator.
#     935     """
# --> 937     super().fit(
#     938         X,
#     939         y,
#     940         sample_weight=sample_weight,
#     941         check_input=check_input,
#     942         X_idx_sorted=X_idx_sorted,
#     943     )
#     944     return self
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:420, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     409 else:
#     410     builder = BestFirstTreeBuilder(
#     411         splitter,
#     412         min_samples_split,
#    (...)
#     417         self.min_impurity_decrease,
#     418     )
# --> 420 builder.build(self.tree_, X, y, sample_weight)
#     422 if self.n_outputs_ == 1 and is_classifier(self):
#     423     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
pip install pyserial
