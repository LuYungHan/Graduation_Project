# %%
import serial
import csv
import time
import pandas as pd
from datetime import datetime, timedelta
from time import sleep
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import math
from scipy import signal
from PIL import Image

np.random.seed(202205456)

data0506 = [
            "../0506data/手2022-05-06 114900-4.csv",
            "../0506data/手2022-05-06 113600-4.csv",
            "../0506data/手2022-05-06 115200-2.csv",
            "../0506data/腳2022-05-06 120000-4.csv",
            "../0506data/腳2022-05-06 120300-3.csv",
            "../0506data/腳2022-05-06 120500-4.csv",
            "../腳_1.csv"]
                                                    
data0510 = [
            "../0510data/手腳2022-05-10 104600.csv", #0
            "../0510data/手腳2022-05-10 104400.csv",#
            "../0510data/手腳2022-05-10 104800.csv",
            "../0510data/手腳2022-05-10 104000.csv",
            "../0510data/手2022-05-10 103600.csv",
            "../0510data/手2022-05-10 103800.csv",
            "../0510data/手2022-05-10 104000.csv",
            "../0510data/手2022-05-10 103600優化.csv",#7
            "../0510data/手2022-05-10 103800優化.csv",#8
            "../0510data/手2022-05-10 104000優化.csv",#9
            "../0510data/腳2022-05-10 103600優化.csv",#10
            "../0510data/腳2022-05-10 103800優化.csv",#11
            "../0510data/腳2022-05-10 104000優化.csv",#12
            "../0510data/腳2022-05-10 104000.csv"]

def RF(data):
    data = np.array(pd.read_csv(data))
    add = []
    fs_start = 8
    fs_end = len(data[:,1])-17 + 8 
    for i in range(len(data[:,1])-17):
        add.append([])
#     data = np.array(pd.read_csv(data))
    f, t, fft_gx = signal.stft(data[:,1],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    f1, t1, fft_gy = signal.stft(data[:,2],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    f2, t2, fft_gz = signal.stft(data[:,3],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    f3, t3, fft_ax = signal.stft(data[:,7],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    f4, t4, fft_ay = signal.stft(data[:,8],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    f5, t5, fft_az = signal.stft(data[:,9],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    #fft_gx
    for i in range (len(fft_gx[100,:])):
        add[i].append(math.atan2((fft_gx[100,i].real),(fft_gx[100,i].imag)))
        add[i].append(math.atan2((fft_gx[600,i].real),(fft_gx[600,i].imag)))
        add[i].append(math.atan2((fft_gx[800,i].real),(fft_gx[800,i].imag)))
        
    #fft_gy
    for i in range (len(fft_gy[100,:])):
        add[i].append(math.atan2((fft_gy[100,i].real),(fft_gy[100,i].imag)))
        add[i].append(math.atan2((fft_gy[600,i].real),(fft_gy[600,i].imag)))
        add[i].append(math.atan2((fft_gy[800,i].real),(fft_gy[800,i].imag)))
    #fft_gz
    for i in range (len(fft_gz[100,:])):
        add[i].append(math.atan2((fft_gz[100,i].real),(fft_gz[100,i].imag)))
        add[i].append(math.atan2((fft_gz[600,i].real),(fft_gz[600,i].imag)))
        add[i].append(math.atan2((fft_gz[800,i].real),(fft_gz[800,i].imag)))
    #fft_ax
    for i in range (len(fft_ax[100,:])):
        add[i].append(math.atan2((fft_ax[100,i].real),(fft_ax[100,i].imag)))
        add[i].append(math.atan2((fft_ax[600,i].real),(fft_ax[600,i].imag)))
        add[i].append(math.atan2((fft_ax[800,i].real),(fft_ax[800,i].imag)))
    #fft_ay
    for i in range (len(fft_ay[100,:])):
        add[i].append(math.atan2((fft_ay[100,i].real),(fft_ay[100,i].imag)))
        add[i].append(math.atan2((fft_ay[600,i].real),(fft_ay[600,i].imag)))
        add[i].append(math.atan2((fft_ay[800,i].real),(fft_ay[800,i].imag)))
    #fft_az
    for i in range (len(fft_az[100,:])):
        add[i].append(math.atan2((fft_az[100,i].real),(fft_az[100,i].imag)))
        add[i].append(math.atan2((fft_az[600,i].real),(fft_az[600,i].imag)))
        add[i].append(math.atan2((fft_az[800,i].real),(fft_az[800,i].imag)))
    
    data = np.append(data[fs_start:fs_end,:], add , axis=1)
    
#     pandasData={"Xg":data[:,1],"Yg":data[:,2],"Zg":data[:,3],"Xm":data[:,4],"Ym":data[:,5],"Zm":data[:,6],"Xa":data[:,7],"Ya":data[:,8],"Za":data[:,9],"Xq":data[:,10],"Yq":data[:,11],"Zq":data[:,12],"Direction":data[:,13],"SensorTime":data[:,14],"Time":data[:,15],"Label":data[:,16],"Fft_gx1":data[:,17],"Fft_gx2":data[:,18],"Fft_gx3":data[:,19],"Fft_gy1":data[:,20],"Fft_gy2":data[:,21],"Fft_gy3":data[:,22],"Fft_gz1":data[:,23],"Fft_gz2":data[:,24],"Fft_gz3":data[:,25]}
    pandasData={"Xg":data[:,1],"Yg":data[:,2],"Zg":data[:,3],"Xm":data[:,4],"Ym":data[:,5],"Zm":data[:,6],"Xa":data[:,7],"Ya":data[:,8],"Za":data[:,9],"Xq":data[:,10],"Yq":data[:,11],"Zq":data[:,12],"Direction":data[:,13],"SensorTime":data[:,14],"Time":data[:,15],"Label":data[:,16],"Fft_gx":data[:,17],"Fft_gy":data[:,20],"Fft_gz":data[:,23],"Fft_ax":data[:,26],"Fft_ay":data[:,29],"Fft_az":data[:,32]}
   
    df = pd.DataFrame(pandasData)
    df.to_csv('../Add_fft_features_data/AfterFft_fft_arctan_40_Hand'+'.csv')
# for i in range(1):
#     print("")
#     RF(data0510[i+9])
count = 2
# data0506 = [
#             "../All_Data/new_data/手2022-05-06 114900-4.csv",
#             "../All_Data/new_data/手2022-05-06 113600-4.csv",
#             "../All_Data/new_data/手2022-05-06 115200-2.csv",
#             "../All_Data/new_data/腳2022-05-06 120000-4.csv",
#             "../All_Data/new_data/腳2022-05-06 120300-3.csv",
#             "../All_Data/new_data/腳2022-05-06 120500-4.csv",
#             "./腳_2.csv"]
                                                    
data0510 = [
            "../All_Data/0510data/手2022-05-10 103600.csv",
            "../All_Data/0510data/手2022-05-10 103800.csv",
            "../All_Data/0510data/手2022-05-10 104000.csv",
            "../All_Data/0510data/腳2022-05-10 103600.csv",
            "../All_Data/0510data/腳2022-05-10 103800.csv",
            "../All_Data/0510data/腳2022-05-10 104000.csv"]


dataFft = ["../Add_fft_features_data/AfterFft_36_Foot.csv",#0
          "../Add_fft_features_data/AfterFft_38_Foot.csv",#1
          "../Add_fft_features_data/AfterFft_40_Foot.csv",#2
          "../Add_fft_features_data/AfterFft_36_Hand.csv",#3
          "../Add_fft_features_data/AfterFft_38_Hand.csv",#4
          "../Add_fft_features_data/AfterFft_40_Hand.csv",#5
          "../Add_fft_features_data/AfterFft_陀螺儀_36_Hand.csv",#6
          "../Add_fft_features_data/AfterFft_陀螺儀_38_Hand.csv",#7
          "../Add_fft_features_data/AfterFft_陀螺儀_40_Hand.csv",#8
          "../Add_fft_features_data/AfterFft_陀螺儀_36_Foot.csv",#9
          "../Add_fft_features_data/AfterFft_陀螺儀_38_Foot.csv",#10
          "../Add_fft_features_data/AfterFft_陀螺儀_40_Foot.csv",#11
           "../Add_fft_features_data/AfterFft_fft_all_36_Hand.csv",#12
          "../Add_fft_features_data/AfterFft_fft_all_38_Hand.csv",#13
          "../Add_fft_features_data/AfterFft_fft_all_40_Hand.csv",#14
          "../Add_fft_features_data/AfterFft_fft_all_36_Foot.csv",#15
          "../Add_fft_features_data/AfterFft_fft_all_38_Foot.csv",#16
           "../Add_fft_features_data/AfterFft_fft_all_40_Foot.csv",#17
           "../Add_fft_features_data/AfterFft_fft_arctan_36_Hand.csv",#18
          "../Add_fft_features_data/AfterFft_fft_arctan_38_Hand.csv",#19
          "../Add_fft_features_data/AfterFft_fft_arctan_40_Hand.csv",#20
          "../../../Add_fft_features_data/AfterFft_fft_arctan_36_Foot.csv",#21
          "../../../Add_fft_features_data/AfterFft_fft_arctan_38_Foot.csv",#22
           "../../../Add_fft_features_data/AfterFft_fft_arctan_40_Foot.csv",#23
           "../Add_fft_features_data/AfterFft_fft_sqrt_arctan_36_Hand.csv",#24
          "../Add_fft_features_data/AfterFft_fft_sqrt_arctan_38_Hand.csv",#25
          "../Add_fft_features_data/AfterFft_fft_sqrt_arctan_40_Hand.csv",#26
          "../../../Add_fft_features_data/AfterFft_fft_sqrt_arctan_36_Foot.csv",#27
          "../../../Add_fft_features_data/AfterFft_fft_sqrt_arctan_38_Foot.csv",#28
           "../../../Add_fft_features_data/AfterFft_fft_sqrt_arctan_40_Foot.csv",#29
          "./腳_fft"+".csv"#30
          ]
num = 1
num2 = 1

# add_arctan
def add_arctan(data):
    data = np.array(pd.read_csv(data))
    add = []
    global num2
    global parameter
    if num2 == 1:
        fs_start = 8
        parameter = len(data[:,1])
        f, t, fft_gx = signal.stft(data[:,1],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f1, t1, fft_gy = signal.stft(data[:,2],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f2, t2, fft_gz = signal.stft(data[:,3],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f3, t3, fft_ax = signal.stft(data[:,7],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f4, t4, fft_ay = signal.stft(data[:,8],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f5, t5, fft_az = signal.stft(data[:,9],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        for i in range(len(data[:,1])-17):
            add.append([])
    else :
        fs_start = 0
        data1 = np.array(pd.read_csv(dataFft[30]))
        parameter = len(data1[:,1])   
#         print(parameter)
        f, t, fft_gx = signal.stft(data[parameter-17:,1],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f1, t1, fft_gy = signal.stft(data[parameter-17:,2],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f2, t2, fft_gz = signal.stft(data[parameter-17:,3],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f3, t3, fft_ax = signal.stft(data[parameter-17:,7],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f4, t4, fft_ay = signal.stft(data[parameter-17:,8],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f5, t5, fft_az = signal.stft(data[parameter-17:,9],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        for i in range(len(data[:,1])-len(data1[:,1])):
            add.append([])
#         print(len(fft_az[100,:]))#143
#         print(len(data[:,1])-len(data1[:,1]))#126
    

    fs_end = len(data[:,1])-17 + 8 
#     print(fft_az)
    
    
#     data = np.array(pd.read_csv(data))
#     print(fft_gx[100,:])
    #fft_gx
    for i in range (len(fft_gx[100,:])):
        add[i].append(math.atan2((fft_gx[100,i].real),(fft_gx[100,i].imag)))
        add[i].append(math.atan2((fft_gx[600,i].real),(fft_gx[600,i].imag)))
        add[i].append(math.atan2((fft_gx[800,i].real),(fft_gx[800,i].imag)))
        
    #fft_gy
    for i in range (len(fft_gy[100,:])):
        add[i].append(math.atan2((fft_gy[100,i].real),(fft_gy[100,i].imag)))
        add[i].append(math.atan2((fft_gy[600,i].real),(fft_gy[600,i].imag)))
        add[i].append(math.atan2((fft_gy[800,i].real),(fft_gy[800,i].imag)))
    #fft_gz
    for i in range (len(fft_gz[100,:])):
        add[i].append(math.atan2((fft_gz[100,i].real),(fft_gz[100,i].imag)))
        add[i].append(math.atan2((fft_gz[600,i].real),(fft_gz[600,i].imag)))
        add[i].append(math.atan2((fft_gz[800,i].real),(fft_gz[800,i].imag)))
    #fft_ax
    for i in range (len(fft_ax[100,:])):
        add[i].append(math.atan2((fft_ax[100,i].real),(fft_ax[100,i].imag)))
        add[i].append(math.atan2((fft_ax[600,i].real),(fft_ax[600,i].imag)))
        add[i].append(math.atan2((fft_ax[800,i].real),(fft_ax[800,i].imag)))
    #fft_ay
    for i in range (len(fft_ay[100,:])):
        add[i].append(math.atan2((fft_ay[100,i].real),(fft_ay[100,i].imag)))
        add[i].append(math.atan2((fft_ay[600,i].real),(fft_ay[600,i].imag)))
        add[i].append(math.atan2((fft_ay[800,i].real),(fft_ay[800,i].imag)))
    #fft_az
    for i in range (len(fft_az[100,:])):
        add[i].append(math.atan2((fft_az[100,i].real),(fft_az[100,i].imag)))
        add[i].append(math.atan2((fft_az[600,i].real),(fft_az[600,i].imag)))
        add[i].append(math.atan2((fft_az[800,i].real),(fft_az[800,i].imag)))
#     print(np.shape(add))
    add2 = add
    add = np.array(add)
#     print(np.shape(add))#(143,18)
#     add = add.T
    if num2 == 1:
#         pandasData={"Xg":data[:,1],"Yg":data[:,2],"Zg":data[:,3],"Xm":data[:,4],"Ym":data[:,5],"Zm":data[:,6],"Xa":data[:,7],"Ya":data[:,8],"Za":data[:,9],"Xq":data[:,10],"Yq":data[:,11],"Zq":data[:,12],"Direction":data[:,13],"SensorTime":data[:,14],"Time":data[:,15],"Label":data[:,16],"Fft_gx1":data[:,17],"Fft_gx2":data[:,18],"Fft_gx3":data[:,19],"Fft_gy1":data[:,20],"Fft_gy2":data[:,21],"Fft_gy3":data[:,22],"Fft_gz1":data[:,23],"Fft_gz2":data[:,24],"Fft_gz3":data[:,25]}
        pandasData={"Fft_gx":add[:,0],"Fft_gy":add[:,3],"Fft_gz":add[:,6],"Fft_ax":add[:,9],"Fft_ay":add[:,12],"Fft_az":add[:,15]}
#         pandasData={"Fft_gx":add[0],"Fft_gy":add[3],"Fft_gz":add[6],"Fft_ax":add[9],"Fft_ay":add[12],"Fft_az":add[15]}
        df = pd.DataFrame(pandasData)
        df
        df.to_csv("./腳_fft"+".csv")
    else :
        data1 = np.array(pd.read_csv(dataFft[30]))
#         data1 = np.row_stack((data1, add))
#         add2 = add2.T
#         print(add2)
#         print("123")
#         add1 =[add2]
#         print(add1)
#         print("456")
#         add2 = np.array(add2)
#         print(add2)
#         print("789")
#         print(add[:,0])
#         print(add[:,3])
        add_tra1 = np.array([add[:,0]]).T
        add_tra2 = np.array([add[:,3]]).T
        add_tra3 = np.array([add[:,6]]).T
        add_tra4 = np.array([add[:,9]]).T
        add_tra5 = np.array([add[:,12]]).T
        add_tra6 = np.array([add[:,15]]).T
#         temp_arr = []
#         for i in range(len(add)):
#             temp_arr.append([])
#         temp_arr = np.append(temp_arr,add[:,0],axis = 1)
#         temp_arr = np.append(temp_arr,add[:,3],axis = 1)
#         print(temp_arr)
#         temp_arr = np.append(temp_arr,add[:,6],axis = 1)
#         temp_arr = np.append(temp_arr,add[:,9],axis = 1)
#         temp_arr = np.append(temp_arr,add[:,12],axis = 1)
#         temp_arr = np.append(temp_arr,add[:,15],axis = 1)
        temp_arr = np.append(add_tra1,add_tra2,axis = 1)
#         print(temp_arr)
        temp_arr = np.append(temp_arr,add_tra3,axis = 1)
        temp_arr = np.append(temp_arr,add_tra4,axis = 1)
        temp_arr = np.append(temp_arr,add_tra5,axis = 1)
        temp_arr = np.append(temp_arr,add_tra6,axis = 1)
        data1 = np.append(data1[:,1:], temp_arr , axis=0)
        data1 = np.array(data1)
#         pandasData={"Xg":data[:,1],"Yg":data[:,2],"Zg":data[:,3],"Xm":data[:,4],"Ym":data[:,5],"Zm":data[:,6],"Xa":data[:,7],"Ya":data[:,8],"Za":data[:,9],"Xq":data[:,10],"Yq":data[:,11],"Zq":data[:,12],"Direction":data[:,13],"SensorTime":data[:,14],"Time":data[:,15],"Label":data[:,16],"Fft_gx1":data[:,17],"Fft_gx2":data[:,18],"Fft_gx3":data[:,19],"Fft_gy1":data[:,20],"Fft_gy2":data[:,21],"Fft_gy3":data[:,22],"Fft_gz1":data[:,23],"Fft_gz2":data[:,24],"Fft_gz3":data[:,25]}
        pandasData={"Fft_gx":data1[:,0],"Fft_gy":data1[:,1],"Fft_gz":data1[:,2],"Fft_ax":data1[:,3],"Fft_ay":data1[:,4],"Fft_az":data1[:,5]}
        df = pd.DataFrame(pandasData)
        
        df.to_csv("./腳_fft"+".csv")
    num2 =num2 + 1
#     return parameter

        
num1=1
def RF(data,data1,data2):
    global num1
    fft = []
    fft1 = []
    amp = 2 * np.sqrt(2)
    
    # read csv
    # data : labeled ,data1 : real-time data ,data2 :fft_arctan
    data = np.array(pd.read_csv(data))
    data1 = np.array(pd.read_csv(data1))
    data2 = np.array(pd.read_csv(data2))
    
    
    
    data_len = len(data[:,1])
    labelSeries = data[:,16]
    # 加速度 陀螺儀 fft_arctan
    dataSeries = np.append(data[:,1:4], data[:,7:10] , axis=1)
    
#     dataSeries = np.append(dataSeries, data[1:data_len-16,17:23] , axis=1)
    dataSeries = np.append(dataSeries, data[:,17:23] , axis=1)

    if num1 <= 2:
        
        dataSeries1 = np.append(data1[17:,1:4], data1[17:,7:10] , axis=1)
    #     dataSeries1 = np.append(dataSeries1, data1[1:data_len1-16,17:23] , axis=1)
        dataSeries1 = np.append(dataSeries1, data2[:,1:7] , axis=1)
    else: 
        num_fft = parameter
        dataSeries1 = np.append(data1[num_fft:,1:4], data1[num_fft:,7:10] , axis=1)
    #     dataSeries1 = np.append(dataSeries1, data1[1:data_len1-16,17:23] , axis=1)
        dataSeries1 = np.append(dataSeries1, data2[num_fft:,1:7] , axis=1)
    dataSeries = np.array(dataSeries)
    dataSeries1 = np.array(dataSeries1)
#     print(dataSeries1)
#     print(dataSeries)
    num1 = num1 + 1
#     for i in range(data_len-17):
#         fft.append([])
#     for i in range(data_len1-17):
#         fft1.append([])
#     f, t, Zxx = signal.stft(data[:,3],fs=1,noverlap=17,nperseg=18,nfft=1000,return_onesided= False,padded=True,detrend=False,boundary=None)
#     f1, t1, Zxx1 = signal.stft(data1[:,3],fs=1,noverlap=17,nperseg=18,nfft=1000,return_onesided= False,padded=True,detrend=False,boundary=None)
#     for i in range (len(Zxx[100,:])):
#         fft[i].append(Zxx[100,i].real)
#         fft[i].append(Zxx[600,i].real)
#         fft[i].append(Zxx[800,i].real)
#         #add[i].append((Zxx[100,i].conjugate()*Zxx[100,i]).real)
#         #add[i].append((Zxx[600,i].conjugate()*Zxx[600,i]).real)
#         #add[i].append((Zxx[800,i].conjugate()*Zxx[800,i]).real)
#     for i in range (len(Zxx1[100,:])):
#         #add1[i].append((Zxx1[100,i].conjugate()*Zxx1[100,i]).real)
#         #add1[i].append((Zxx1[600,i].conjugate()*Zxx1[600,i]).real)
#         #add1[i].append((Zxx1[800,i].conjugate()*Zxx1[800,i]).real)
#         fft1[i].append(Zxx1[100,i].real)
#         fft1[i].append(Zxx1[600,i].real)
#         fft1[i].append(Zxx1[800,i].real)
#     dataSeries = np.append(dataSeries, fft , axis=1)
#     dataSeries1 = np.append(dataSeries1,fft1, axis=1)
    randomForestModel = RandomForestClassifier(
        random_state=1111,
        oob_score= True,
        n_estimators=100,
        max_depth=3,
        min_samples_split=5,
        min_samples_leaf = 50,
        criterion = 'entropy',
        max_features = 0.2,
        )
    randomForestModel.fit(dataSeries, labelSeries)
    predict = randomForestModel.predict(dataSeries1)
    return predict

def RFF(data,data1):
    
    data = np.array(pd.read_csv(data))
    labelSeries = data[:,16]
    dataSeries = data[:,1:3]+data[:,7:9] #加速度儀和陀螺儀
    #x_train, x_test, y_train, y_test = train_test_split(dataSeries, labelSeries,test_size=0.2, random_state=222)
#     data1 = np.array(pd.read_csv(data1))
    dataSeries1 = data1[:,1:3]+data1[:,7:9] #加速度儀和陀螺儀
    #x_train1, x_test1, y_train1, y_test1 = train_test_split(dataSeries1, labelSeries1,test_size=0.2, random_state=222)

    randomForestModel = RandomForestClassifier(random_state=1,n_estimators=60 , max_depth=1 ,min_samples_split=70)
    # 使用訓練資料訓練模型
    #x_train=x_train.astype('int')
    #y_train=y_train.astype('str')
    #x_test=x_test.astype('int')
    #y_test=y_test.astype('str')
    randomForestModel.fit(dataSeries, labelSeries)
    # 使用訓練資料預測
    predict = randomForestModel.predict(dataSeries1)
#     RF_score = randomForestModel.score(dataSeries1,labelSeries1)
#     print(classification_report(labelSeries1,predict))
    return predict

serialPort = serial.Serial(port='COM3', baudrate=38400, timeout=2, parity=serial.PARITY_EVEN, stopbits=1)#HC-05-1
#serialPort2 = serial.Serial(port='COM70', baudrate=38400, timeout=2, parity=serial.PARITY_EVEN, stopbits=1)#HC-05-2
#115200 esp32

while(1):
    global num
    count = datetime.now().strftime('%Y-%m-%d %H%M%S')
    data0506 = [
            "../All_Data/new_data/手2022-05-06 114900-4.csv",
            "../All_Data/new_data/手2022-05-06 113600-4.csv",
            "../All_Data/new_data/手2022-05-06 115200-2.csv",
            "../All_Data/new_data/腳2022-05-06 120000-4.csv",
            "../All_Data/new_data/腳2022-05-06 120300-3.csv",
            "../All_Data/new_data/腳2022-05-06 120500-4.csv",
            "../../../Add_fft_features_data/AfterFft_fft_arctan_36_Foot.csv",#21
            "../../../Add_fft_features_data/AfterFft_fft_arctan_38_Foot.csv",#22
            "../../../Add_fft_features_data/AfterFft_fft_arctan_40_Foot.csv",#23
            "./腳_"+".csv",
            "./腳_fft"+".csv"]#10
    
    print("hello")
    #/dev/cu.name
    size = 1024
    xg,yg,zg,mx,my,mz,xa,ya,za,xq,yq,zq,direc,mytime =[],[],[],[],[],[],[],[],[],[],[],[],[],[]
    #xg2,yg2,zg2,mx2,my2,mz2,xa2,ya2,za2,xq2,yq2,zq2,direc2,mytime2 =[],[],[],[],[],[],[],[],[],[],[],[],[],[]
    Ttime=str(datetime.now())
    print(Ttime)
    print(Ttime[17::])
    tt=0
    TT=5
    while(tt<=TT):
        data = serialPort.readline().decode('utf-8', 'ignore')
    #     data2 = serialPort2.readline().decode('utf-8')
#         print(data)
    #     print(data2)
        data=data.split(',')
        print(data)
    #     tempData = data
    #     tempData = pd.DataFrame(tempData)
    #     print(len(tempData))
#         if len(data)==16:
#             print("Hello")
#             print("Hand:",RFF(data0506[0],data))

    #     data2=data2.split(',')
    #     print(len(data),len(data2))
    #     print(float(str(datetime.now())[17::]))
        if (float(str(datetime.now())[17::])< float(Ttime[17::])):      
            tt = float(Ttime[17::])+60-float(str(datetime.now())[17::] )
            if tt>=TT:
                break
        else:
            tt = -float(Ttime[17::])+float(str(datetime.now())[17::] )
            if tt>=TT:
                break
        if len(data)==16:
            xg.append(data[1])
            yg.append(data[2])
            zg.append(data[3])
            mx.append(data[4])
            my.append(data[5])
            mz.append(data[6])
            xa.append(data[7])
            ya.append(data[8])
            za.append(data[9])
            xq.append(data[10])
            yq.append(data[11])
            zq.append(data[12])
            direc.append(data[13])
            mytime.append(data[14])
    #         pandasData1={"Xg":data[1],"Yg":data[2],"Zg":data[3],"Xm":data[4],"Ym":data[5],"Zm":data[6],"Xa":data[7],"Ya":data[8],"Za":data[9],"Xq":data[10],"Yq":data[11],"Zq":data[12],"Direction":data[13],"Time":data[14]}
    #         df1 = pd.DataFrame(pandasData1)
    #         df1.to_csv('腳_2'+'.csv')
    #         print("Hand:",RF(data0506[3],data0506[6]))
    #     if len(data2)==16:
    #         xg2.append(data2[1])
    #         yg2.append(data2[2])
    #         zg2.append(data2[3])
    #         mx2.append(data2[4])
    #         my2.append(data2[5])
    #         mz2.append(data2[6])
    #         xa2.append(data2[7])
    #         ya2.append(data2[8])
    #         za2.append(data2[9])
    #         xq2.append(data2[10])
    #         yq2.append(data2[11])
    #         zq2.append(data2[12])
    #         direc2.append(data2[13])
    #         mytime2.append(data2[14])
    if num == 1:
        
        pandasData={"Xg":xg,"Yg":yg,"Zg":zg,"Xm":mx,"Ym":my,"Zm":mz,"Xa":xa,"Ya":ya,"Za":za,"Xq":xq,"Yq":yq,"Zq":zq,"Direction":direc,"Time":mytime}
        # pandasData1={xg,yg,zg,mx,my,mz,xa,ya,za,xq,yq,zq,direc,mytime}
        # pandasData2={"Xg":xg2,"Yg":yg2,"Zg":zg2,"Xm":mx2,"Ym":my2,"Zm":mz2,"Xa":xa2,"Ya":ya2,"Za":za2,"Xq":xq2,"Yq":yq2,"Zq":zq2,"Direction":direc2,"Time":mytime2}
        df = pd.DataFrame(pandasData)
        #df2= pd.DataFrame(pandasData2)
        print(df)
        #print(df2)
        transform_fftArctan = 0
        df.to_csv('腳_'+'.csv')
    else:
        data1 = np.array(pd.read_csv(data0506[9]))
        xg = [xg]
        yg = [yg]
        zg = [zg]
        mx = [mx]
        my = [my]
        mz = [mz]
        xa = [xa]
        ya = [ya]
        za = [za]
        xq = [xq]
        yq = [yq]
        zq = [zq]
        direc = [direc]
        mytime = [mytime]
        
        temp1 = np.append(xg,yg,axis=0)
        temp1 = np.append(temp1,zg,axis=0)
        temp1 = np.append(temp1,mx,axis=0)
        temp1 = np.append(temp1,my,axis=0)
        temp1 = np.append(temp1,mz,axis=0)
        temp1 = np.append(temp1,xa,axis=0)
        temp1 = np.append(temp1,ya,axis=0)
        temp1 = np.append(temp1,za,axis=0)
        temp1 = np.append(temp1,xq,axis=0)
        temp1 = np.append(temp1,yq,axis=0)
        temp1 = np.append(temp1,zq,axis=0)
        temp1 = np.append(temp1,direc,axis=0)
        temp1 = np.append(temp1,mytime,axis=0).T
        
#         print(temp1)
        data1 = np.append(data1[:,1:15], temp1[:,0:14] , axis=0)
#         data1 = np.row_stack((data1[:,1:15], data[:,1:15] ))
#         pandasData={"Xg":data1[:,1],"Yg":data1[:,2],"Zg":data1[:,3],"Xm":data1[:,4],"Ym":data1[:,5],"Zm":data1[:,6],"Xa":data1[:,7],"Ya":data1[:,8],"Za":data1[:,9],"Xq":data1[:,10],"Yq":data1[:,11],"Zq":data1[:,12],"Direction":data1[:,13],"SensorTime":data1[:,14]}
        pandasData={"Xg":data1[:,0],"Yg":data1[:,1],"Zg":data1[:,2],"Xm":data1[:,3],"Ym":data1[:,4],"Zm":data1[:,5],"Xa":data1[:,6],"Ya":data1[:,7],"Za":data1[:,8],"Xq":data1[:,9],"Yq":data1[:,10],"Zq":data1[:,11],"Direction":data1[:,12],"SensorTime":data1[:,13]}
#         pandasData={"Fft_gx":data1[:,1],"Fft_gy":data1[:,2],"Fft_gz":data1[:,3],"Fft_ax":data1[:,4],"Fft_ay":data1[:,5],"Fft_az":data1[:,6]}
        df = pd.DataFrame(pandasData)
        df.to_csv("腳_"+".csv")
        
    num = num + 1
    #df2.to_csv('手'+datetime.now().strftime('%Y-%m-%d %H%M%S')+'.csv')
    print("--------------------------------\nRandomForest\n-------------------------------")
    #for i in range(len(data0506)//2):
    add_arctan(data0506[9])
    for i in range(1):
        print("Hand:",RF(data0506[6],data0506[9],data0506[10]))
        print("")
        dff = pd.DataFrame(RF(data0506[6],data0506[9],data0506[10]))
    #     print("Foot:",RF(data0506[i+2],data0506[i+3]))
    #     print("________________________________________________________")
    dff.to_csv('label_'+count+'.csv')
    
serialPort.close()
#serialPort2.close()
# Out:
# hello
# 2022-08-04 21:52:45.781516
# 45.781516
# ['', '-0.02', '-0.03', '0.02', '9.50', '-44.81', '-1.63', '1.28', '9.71', '-2.10', '0.38', '0.61', '0.63', '0.29', '99044', '\r\n']
# ['', '-0.02', '-0.03', '0.02', '9.50', '-44.81', '-1.63', '1.28', '9.67', '-2.25', '0.38', '0.61', '0.63', '0.29', '99083', '\r\n']
# ['', '-0.02', '-0.03', '0.02', '9.50', '-44.81', '-1.63', '1.32', '9.67', '-1.91', '0.38', '0.61', '0.63', '0.29', '99122', '\r\n']
# ['', '-0.02', '-0.03', '0.02', '9.50', '-44.81', '-1.63', '1.32', '9.71', '-1.98', '0.38', '0.61', '0.63', '0.29', '99160', '\r\n']
# ['', '-0.06', '-0.12', '0.07', '9.50', '-44.81', '-1.63', '1.32', '9.71', '-1.98', '0.38', '0.61', '0.63', '0.29', '99198', '\r\n']
# ['', '-0.06', '-0.12', '0.07', '9.50', '-44.81', '-1.63', '1.51', '9.67', '-2.18', '0.38', '0.61', '0.63', '0.29', '99238', '\r\n']
# ['', '-0.05', '-0.18', '0.06', '9.50', '-44.81', '-1.63', '1.51', '9.67', '-2.18', '0.38', '0.61', '0.63', '0.29', '99277', '\r\n']
# ['', '-0.05', '-0.18', '0.06', '9.50', '-44.81', '-1.63', '1.59', '9.59', '-2.18', '0.38', '0.61', '0.63', '0.29', '99316', '\r\n']
# ['', '-0.05', '-0.18', '0.06', '9.50', '-44.81', '-1.63', '1.47', '9.63', '-2.10', '0.38', '0.61', '0.63', '0.29', '99353', '\r\n']
# ['', '-0.05', '-0.18', '0.06', '9.50', '-44.81', '-1.63', '1.43', '9.71', '-1.87', '0.38', '0.61', '0.63', '0.29', '99392', '\r\n']
# ['', '-0.05', '-0.18', '0.06', '9.50', '-44.81', '-1.63', '1.51', '9.71', '-2.18', '0.38', '0.61', '0.63', '0.29', '99432', '\r\n']
# ['', '-0.05', '-0.18', '0.06', '9.50', '-44.81', '-1.63', '1.47', '9.67', '-1.98', '0.38', '0.61', '0.63', '0.29', '99471', '\r\n']
# ['', '-0.05', '-0.18', '0.06', '9.50', '-44.81', '-1.63', '1.59', '9.63', '-2.14', '0.38', '0.61', '0.63', '0.29', '99509', '\r\n']
# ['', '-0.04', '-0.09', '0.11', '9.50', '-44.81', '-1.63', '1.59', '9.63', '-2.14', '0.38', '0.61', '0.63', '0.29', '99549', '\r\n']
# ['', '-0.04', '-0.08', '0.11', '9.50', '-44.81', '-1.63', '1.59', '9.63', '-2.14', '0.38', '0.61', '0.63', '0.29', '99588', '\r\n']
# ['', '-0.04', '-0.08', '0.11', '9.50', '-44.81', '-1.63', '1.74', '9.63', '-2.10', '0.38', '0.61', '0.63', '0.29', '99627', '\r\n']
# ['', '-0.04', '-0.08', '0.11', '9.50', '-44.81', '-1.63', '1.78', '9.63', '-1.95', '0.38', '0.61', '0.63', '0.29', '99665', '\r\n']
# ['', '-0.04', '-0.08', '0.11', '9.50', '-44.81', '-1.63', '1.66', '9.63', '-2.02', '0.38', '0.61', '0.63', '0.29', '99702', '\r\n']
# ['', '0.01', '0.04', '0.04', '9.50', '-44.81', '-1.63', '1.66', '9.63', '-2.02', '0.38', '0.61', '0.63', '0.29', '99741', '\r\n']
# ['', '0.05', '-0.01', '0.04', '9.50', '-44.81', '-1.63', '1.66', '9.63', '-2.02', '0.38', '0.61', '0.63', '0.29', '99780', '\r\n']
# ['', '0.05', '-0.01', '0.04', '9.50', '-44.81', '-1.63', '1.74', '9.55', '-2.02', '0.38', '0.61', '0.63', '0.29', '99819', '\r\n']
# ['', '0.05', '-0.01', '0.04', '9.50', '-44.81', '-1.63', '1.86', '9.63', '-2.06', '0.38', '0.61', '0.63', '0.29', '99856', '\r\n']
# ['', '0.05', '-0.01', '0.04', '9.50', '-44.81', '-1.63', '1.82', '9.63', '-2.06', '0.38', '0.61', '0.63', '0.29', '99895', '\r\n']
# ['', '-0.12', '0.00', '0.12', '9.50', '-44.81', '-1.63', '1.82', '9.63', '-2.06', '0.38', '0.61', '0.63', '0.29', '99933', '\r\n']
# ['', '-0.12', '0.00', '0.12', '9.50', '-44.81', '-1.63', '2.01', '9.36', '-1.83', '0.38', '0.61', '0.63', '0.29', '99972', '\r\n']
# ['', '-0.12', '0.00', '0.12', '9.50', '-44.81', '-1.63', '2.28', '9.67', '-1.79', '0.38', '0.61', '0.63', '0.29', '100008', '\r\n']
# ['', '0.21', '0.11', '-0.03', '9.50', '-44.81', '-1.63', '2.28', '9.67', '-1.79', '0.38', '0.61', '0.63', '0.29', '100049', '\r\n']
# ['', '0.01', '-0.18', '-0.06', '9.50', '-44.81', '-1.63', '2.28', '9.67', '-1.79', '0.38', '0.61', '0.63', '0.29', '100088', '\r\n']
# ['', '0.01', '-0.18', '-0.06', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.33', '0.38', '0.61', '0.63', '0.29', '100128', '\r\n']
# ['', '0.01', '-0.18', '-0.06', '9.50', '-44.81', '-1.63', '1.66', '9.63', '-1.91', '0.38', '0.61', '0.63', '0.29', '100167', '\r\n']
# ['', '0.01', '-0.18', '-0.06', '9.50', '-44.81', '-1.63', '1.86', '9.59', '-2.18', '0.38', '0.61', '0.63', '0.29', '100206', '\r\n']
# ['', '0.08', '0.10', '0.07', '9.50', '-44.81', '-1.63', '1.86', '9.59', '-2.18', '0.38', '0.61', '0.63', '0.29', '100245', '\r\n']
# ['', '-0.06', '-0.09', '0.04', '9.50', '-44.81', '-1.63', '1.86', '9.59', '-2.18', '0.38', '0.61', '0.63', '0.29', '100283', '\r\n']
# ['', '-0.06', '-0.09', '0.04', '9.50', '-44.81', '-1.63', '2.05', '9.55', '-2.33', '0.38', '0.61', '0.63', '0.29', '100323', '\r\n']
# ['', '-0.06', '-0.09', '0.04', '9.50', '-44.81', '-1.63', '1.86', '9.59', '-2.18', '0.38', '0.61', '0.63', '0.29', '100361', '\r\n']
# ['', '0.02', '-0.02', '0.01', '9.50', '-44.81', '-1.63', '1.86', '9.59', '-2.18', '0.38', '0.61', '0.63', '0.29', '100401', '\r\n']
# ['', '0.09', '0.05', '0.02', '9.50', '-44.81', '-1.63', '1.86', '9.59', '-2.18', '0.38', '0.61', '0.63', '0.29', '100441', '\r\n']
# ['', '0.09', '0.05', '0.02', '9.50', '-44.81', '-1.63', '1.89', '9.52', '-2.02', '0.38', '0.61', '0.63', '0.29', '100480', '\r\n']
# ['', '0.09', '0.05', '0.02', '9.50', '-44.81', '-1.63', '2.01', '9.59', '-2.06', '0.38', '0.61', '0.63', '0.29', '100519', '\r\n']
# ['', '0.09', '0.05', '0.02', '9.50', '-44.81', '-1.63', '2.09', '9.55', '-1.95', '0.38', '0.61', '0.63', '0.29', '100556', '\r\n']
# ['', '-0.06', '-0.06', '0.00', '9.50', '-44.81', '-1.63', '2.09', '9.55', '-1.95', '0.38', '0.61', '0.63', '0.29', '100594', '\r\n']
# ['', '0.13', '0.14', '-0.01', '9.50', '-44.81', '-1.63', '2.09', '9.55', '-1.95', '0.38', '0.61', '0.63', '0.29', '100633', '\r\n']
# ['', '0.13', '0.14', '-0.01', '9.50', '-44.81', '-1.63', '2.05', '9.55', '-2.02', '0.38', '0.61', '0.63', '0.29', '100672', '\r\n']
# ['', '0.13', '0.14', '-0.01', '9.50', '-44.81', '-1.63', '1.89', '9.48', '-2.02', '0.38', '0.61', '0.63', '0.29', '100710', '\r\n']
# ['', '-0.02', '0.01', '-0.01', '9.50', '-44.81', '-1.63', '1.89', '9.48', '-2.02', '0.38', '0.61', '0.63', '0.29', '100749', '\r\n']
# ['', '0.04', '0.04', '0.00', '9.50', '-44.81', '-1.63', '1.89', '9.48', '-2.02', '0.38', '0.61', '0.63', '0.29', '100789', '\r\n']
# ['', '0.04', '0.04', '0.00', '9.50', '-44.81', '-1.63', '2.01', '9.48', '-2.41', '0.38', '0.61', '0.63', '0.29', '100828', '\r\n']
# ['', '0.04', '0.04', '0.00', '9.50', '-44.81', '-1.63', '2.05', '9.55', '-2.71', '0.38', '0.61', '0.63', '0.29', '100868', '\r\n']
# ['', '0.04', '0.04', '0.00', '9.50', '-44.81', '-1.63', '2.01', '9.52', '-2.29', '0.38', '0.61', '0.63', '0.29', '100903', '\r\n']
# ['', '-0.04', '-0.03', '0.00', '9.50', '-44.81', '-1.63', '2.01', '9.52', '-2.29', '0.38', '0.61', '0.63', '0.29', '100942', '\r\n']
# ['', '-0.04', '-0.03', '0.00', '9.50', '-44.81', '-1.63', '2.12', '9.48', '-2.33', '0.38', '0.61', '0.63', '0.29', '100982', '\r\n']
# ['', '-0.04', '-0.03', '0.00', '9.50', '-44.81', '-1.63', '1.97', '9.52', '-2.21', '0.38', '0.61', '0.63', '0.29', '101022', '\r\n']
# ['', '-0.04', '-0.03', '0.00', '9.50', '-44.81', '-1.63', '2.09', '9.52', '-2.45', '0.38', '0.61', '0.63', '0.29', '101060', '\r\n']
# ['', '0.01', '0.09', '0.02', '9.50', '-44.81', '-1.63', '2.09', '9.52', '-2.45', '0.38', '0.61', '0.63', '0.29', '101100', '\r\n']
# ['', '-0.02', '-0.03', '0.00', '9.50', '-44.81', '-1.63', '2.09', '9.52', '-2.45', '0.38', '0.61', '0.63', '0.29', '101139', '\r\n']
# ['', '-0.02', '-0.03', '0.00', '9.50', '-44.81', '-1.63', '2.05', '9.55', '-2.29', '0.38', '0.61', '0.63', '0.29', '101180', '\r\n']
# ['', '-0.02', '-0.03', '0.00', '9.50', '-44.81', '-1.63', '2.05', '9.52', '-2.25', '0.38', '0.61', '0.63', '0.29', '101220', '\r\n']
# ['', '-0.02', '-0.03', '0.00', '9.50', '-44.81', '-1.63', '1.93', '9.59', '-2.21', '0.38', '0.61', '0.63', '0.29', '101258', '\r\n']
# ['', '-0.03', '-0.01', '0.01', '9.50', '-44.81', '-1.63', '1.93', '9.59', '-2.21', '0.38', '0.61', '0.63', '0.29', '101297', '\r\n']
# ['', '-0.03', '-0.01', '0.01', '9.50', '-44.81', '-1.63', '2.09', '9.48', '-2.21', '0.38', '0.61', '0.63', '0.29', '101338', '\r\n']
# ['', '-0.04', '0.01', '0.02', '9.50', '-44.81', '-1.63', '2.09', '9.48', '-2.21', '0.38', '0.61', '0.63', '0.29', '101378', '\r\n']
# ['', '-0.04', '0.01', '0.02', '9.50', '-44.81', '-1.63', '2.09', '9.52', '-2.18', '0.38', '0.61', '0.63', '0.29', '101417', '\r\n']
# ['', '-0.04', '0.01', '0.02', '9.50', '-44.81', '-1.63', '2.09', '9.52', '-1.91', '0.38', '0.61', '0.63', '0.29', '101455', '\r\n']
# ['', '0.01', '0.05', '0.00', '9.50', '-44.81', '-1.63', '2.09', '9.52', '-1.91', '0.38', '0.61', '0.63', '0.29', '101493', '\r\n']
# ['', '-0.03', '0.01', '-0.00', '9.50', '-44.81', '-1.63', '2.09', '9.52', '-1.91', '0.38', '0.61', '0.63', '0.29', '101532', '\r\n']
# ['', '-0.03', '0.01', '-0.00', '9.50', '-44.81', '-1.63', '2.16', '9.52', '-2.25', '0.38', '0.61', '0.63', '0.29', '101571', '\r\n']
# ['', '-0.03', '0.01', '-0.00', '9.50', '-44.81', '-1.63', '2.16', '9.52', '-2.41', '0.38', '0.61', '0.63', '0.29', '101609', '\r\n']
# ['', '0.00', '0.01', '-0.00', '9.50', '-44.81', '-1.63', '2.16', '9.52', '-2.41', '0.38', '0.61', '0.63', '0.29', '101650', '\r\n']
# ['', '0.01', '-0.02', '0.01', '9.50', '-44.81', '-1.63', '2.16', '9.52', '-2.41', '0.38', '0.61', '0.63', '0.29', '101690', '\r\n']
# ['', '0.01', '-0.02', '0.01', '9.50', '-44.81', '-1.63', '2.12', '9.48', '-2.29', '0.38', '0.61', '0.63', '0.29', '101729', '\r\n']
# ['', '0.01', '-0.02', '0.01', '9.50', '-44.81', '-1.63', '2.16', '9.52', '-2.25', '0.38', '0.61', '0.63', '0.29', '101770', '\r\n']
# ['', '0.01', '-0.02', '0.01', '9.50', '-44.81', '-1.63', '2.20', '9.52', '-2.21', '0.38', '0.61', '0.63', '0.29', '101807', '\r\n']
# ['', '-0.00', '0.01', '0.02', '9.50', '-44.81', '-1.63', '2.20', '9.52', '-2.21', '0.38', '0.61', '0.63', '0.29', '101847', '\r\n']
# ['', '0.04', '-0.04', '-0.00', '9.50', '-44.81', '-1.63', '2.20', '9.52', '-2.21', '0.38', '0.61', '0.63', '0.29', '101885', '\r\n']
# ['', '0.04', '-0.04', '-0.00', '9.50', '-44.81', '-1.63', '2.16', '9.52', '-2.25', '0.38', '0.61', '0.63', '0.29', '101924', '\r\n']
# ['', '0.04', '-0.04', '-0.00', '9.50', '-44.81', '-1.63', '2.12', '9.52', '-2.06', '0.38', '0.61', '0.63', '0.29', '101963', '\r\n']
# ['', '0.04', '-0.04', '-0.00', '9.50', '-44.81', '-1.63', '2.16', '9.52', '-2.29', '0.38', '0.61', '0.63', '0.29', '102001', '\r\n']
# ['', '0.05', '0.02', '0.01', '9.50', '-44.81', '-1.63', '2.16', '9.52', '-2.29', '0.38', '0.61', '0.63', '0.29', '102041', '\r\n']
# ['', '0.05', '0.02', '0.01', '9.50', '-44.81', '-1.63', '2.09', '9.52', '-2.02', '0.38', '0.61', '0.63', '0.29', '102080', '\r\n']
# ['', '0.05', '0.02', '0.01', '9.50', '-44.81', '-1.63', '2.20', '9.44', '-2.29', '0.38', '0.61', '0.63', '0.29', '102120', '\r\n']
# ['', '0.05', '0.02', '0.01', '9.50', '-44.81', '-1.63', '2.05', '9.52', '-2.02', '0.38', '0.61', '0.63', '0.29', '102157', '\r\n']
# ['', '-0.05', '-0.09', '-0.03', '9.50', '-44.81', '-1.63', '2.05', '9.52', '-2.02', '0.38', '0.61', '0.63', '0.29', '102197', '\r\n']
# ['', '-0.05', '-0.09', '-0.03', '9.50', '-44.81', '-1.63', '2.09', '9.55', '-2.41', '0.38', '0.61', '0.63', '0.29', '102237', '\r\n']
# ['', '-0.05', '-0.09', '-0.03', '9.50', '-44.81', '-1.63', '2.09', '9.52', '-2.21', '0.38', '0.61', '0.63', '0.29', '102279', '\r\n']
# ['', '-0.05', '-0.09', '-0.03', '9.50', '-44.81', '-1.63', '2.05', '9.55', '-2.29', '0.38', '0.61', '0.63', '0.29', '102319', '\r\n']
# ['', '-0.05', '-0.09', '-0.03', '9.50', '-44.81', '-1.63', '2.01', '9.55', '-2.33', '0.38', '0.61', '0.63', '0.29', '102358', '\r\n']
# ['', '0.01', '-0.02', '-0.04', '9.50', '-44.81', '-1.63', '2.01', '9.55', '-2.33', '0.38', '0.61', '0.63', '0.29', '102398', '\r\n']
# ['', '-0.05', '-0.09', '-0.02', '9.50', '-44.81', '-1.63', '2.01', '9.55', '-2.33', '0.38', '0.61', '0.63', '0.29', '102438', '\r\n']
# ['', '-0.05', '-0.09', '-0.02', '9.50', '-44.81', '-1.63', '2.01', '9.52', '-2.37', '0.38', '0.61', '0.63', '0.29', '102479', '\r\n']
# ['', '-0.05', '-0.09', '-0.02', '9.50', '-44.81', '-1.63', '1.93', '9.52', '-2.25', '0.38', '0.61', '0.63', '0.29', '102519', '\r\n']
# ['', '-0.05', '-0.09', '-0.02', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.29', '0.38', '0.61', '0.63', '0.29', '102558', '\r\n']
# ['', '-0.02', '-0.03', '-0.01', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.29', '0.38', '0.61', '0.63', '0.29', '102598', '\r\n']
# ['', '-0.00', '0.03', '0.02', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.29', '0.38', '0.61', '0.63', '0.29', '102638', '\r\n']
# ['', '-0.00', '0.03', '0.02', '9.50', '-44.81', '-1.63', '1.86', '9.55', '-2.21', '0.38', '0.61', '0.63', '0.29', '102679', '\r\n']
# ['', '-0.00', '0.03', '0.02', '9.50', '-44.81', '-1.63', '2.01', '9.52', '-2.41', '0.38', '0.61', '0.63', '0.29', '102718', '\r\n']
# ['', '-0.00', '0.03', '0.02', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.21', '0.38', '0.61', '0.63', '0.29', '102756', '\r\n']
# ['', '-0.05', '-0.07', '0.00', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.21', '0.38', '0.61', '0.63', '0.29', '102794', '\r\n']
# ['', '-0.05', '-0.07', '0.00', '9.50', '-44.81', '-1.63', '2.01', '9.52', '-2.41', '0.38', '0.61', '0.63', '0.29', '102833', '\r\n']
# ['', '-0.05', '-0.07', '0.00', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.21', '0.38', '0.61', '0.63', '0.29', '102873', '\r\n']
# ['', '-0.05', '-0.07', '0.00', '9.50', '-44.81', '-1.63', '2.05', '9.52', '-2.33', '0.38', '0.61', '0.63', '0.29', '102912', '\r\n']
# ['', '-0.05', '-0.07', '0.00', '9.50', '-44.81', '-1.63', '2.05', '9.52', '-2.33', '0.44', '0.64', '0.57', '0.24', '102950', '\r\n']
# ['', '-0.05', '-0.07', '0.00', '9.50', '-44.81', '-1.63', '1.89', '9.59', '-2.18', '0.44', '0.64', '0.57', '0.24', '102991', '\r\n']
# ['', '0.02', '0.05', '-0.01', '9.50', '-44.81', '-1.63', '1.89', '9.59', '-2.18', '0.44', '0.64', '0.57', '0.24', '103031', '\r\n']
# ['', '0.02', '0.05', '-0.01', '9.50', '-44.81', '-1.63', '1.89', '9.55', '-2.14', '0.44', '0.64', '0.57', '0.24', '103070', '\r\n']
#         Xg     Yg     Zg    Xm      Ym     Zm    Xa    Ya     Za    Xq    Yq  \
# 0    -0.02  -0.03   0.02  9.50  -44.81  -1.63  1.28  9.71  -2.10  0.38  0.61
# 1    -0.02  -0.03   0.02  9.50  -44.81  -1.63  1.28  9.67  -2.25  0.38  0.61
# 2    -0.02  -0.03   0.02  9.50  -44.81  -1.63  1.32  9.67  -1.91  0.38  0.61
# 3    -0.02  -0.03   0.02  9.50  -44.81  -1.63  1.32  9.71  -1.98  0.38  0.61
# 4    -0.06  -0.12   0.07  9.50  -44.81  -1.63  1.32  9.71  -1.98  0.38  0.61
# ..     ...    ...    ...   ...     ...    ...   ...   ...    ...   ...   ...
# 98   -0.05  -0.07   0.00  9.50  -44.81  -1.63  1.93  9.55  -2.21  0.38  0.61
# 99   -0.05  -0.07   0.00  9.50  -44.81  -1.63  2.05  9.52  -2.33  0.38  0.61
# 100  -0.05  -0.07   0.00  9.50  -44.81  -1.63  2.05  9.52  -2.33  0.44  0.64
# 101  -0.05  -0.07   0.00  9.50  -44.81  -1.63  1.89  9.59  -2.18  0.44  0.64
# 102   0.02   0.05  -0.01  9.50  -44.81  -1.63  1.89  9.59  -2.18  0.44  0.64
#
#        Zq Direction    Time
# 0    0.63      0.29   99044
# 1    0.63      0.29   99083
# 2    0.63      0.29   99122
# 3    0.63      0.29   99160
# 4    0.63      0.29   99198
# ..    ...       ...     ...
# 98   0.63      0.29  102873
# 99   0.63      0.29  102912
# 100  0.57      0.24  102950
# 101  0.57      0.24  102991
# 102  0.57      0.24  103031
#
# [103 rows x 14 columns]
# --------------------------------
# RandomForest
# -------------------------------
# Hand: ['W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W']
#
# hello
# 2022-08-04 21:52:51.162995
# 51.162995
# ['', '0.02', '0.05', '-0.01', '9.50', '-44.81', '-1.63', '1.97', '9.55', '-2.29', '0.44', '0.64', '0.57', '0.24', '103107', '\r\n']
# ['', '0.02', '0.06', '-0.01', '9.50', '-44.81', '-1.63', '1.97', '9.55', '-2.29', '0.44', '0.64', '0.57', '0.24', '103148', '\r\n']
# ['', '-0.02', '0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.97', '9.55', '-2.29', '0.44', '0.64', '0.57', '0.24', '103187', '\r\n']
# ['', '-0.02', '0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.97', '9.55', '-2.21', '0.44', '0.64', '0.57', '0.24', '103227', '\r\n']
# ['', '-0.02', '0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.97', '9.55', '-2.18', '0.44', '0.64', '0.57', '0.24', '103267', '\r\n']
# ['', '-0.02', '0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.97', '9.55', '-2.18', '0.44', '0.64', '0.57', '0.24', '103305', '\r\n']
# ['', '-0.01', '0.02', '-0.03', '9.50', '-44.81', '-1.63', '1.97', '9.55', '-2.18', '0.44', '0.64', '0.57', '0.24', '103345', '\r\n']
# ['', '0.00', '0.02', '-0.02', '9.50', '-44.81', '-1.63', '1.97', '9.55', '-2.18', '0.44', '0.64', '0.57', '0.24', '103384', '\r\n']
# ['', '0.00', '0.02', '-0.02', '9.50', '-44.81', '-1.63', '1.89', '9.55', '-2.21', '0.44', '0.64', '0.57', '0.24', '103422', '\r\n']
# ['', '0.00', '0.02', '-0.02', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.29', '0.44', '0.64', '0.57', '0.24', '103459', '\r\n']
# ['', '-0.01', '0.00', '-0.03', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.29', '0.44', '0.64', '0.57', '0.24', '103499', '\r\n']
# ['', '0.01', '0.02', '0.00', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.29', '0.44', '0.64', '0.57', '0.24', '103539', '\r\n']
# ['', '0.01', '0.02', '0.00', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.21', '0.44', '0.64', '0.57', '0.24', '103578', '\r\n']
# ['', '0.01', '0.02', '0.00', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.33', '0.44', '0.64', '0.57', '0.24', '103618', '\r\n']
# ['', '0.01', '0.02', '0.00', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.29', '0.44', '0.64', '0.57', '0.24', '103655', '\r\n']
# ['', '0.00', '0.00', '0.00', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.29', '0.44', '0.64', '0.57', '0.24', '103693', '\r\n']
# ['', '0.00', '0.00', '0.00', '9.50', '-44.81', '-1.63', '1.89', '9.55', '-2.14', '0.44', '0.64', '0.57', '0.24', '103732', '\r\n']
# ['', '0.00', '0.00', '0.00', '9.50', '-44.81', '-1.63', '1.89', '9.55', '-2.25', '0.44', '0.64', '0.57', '0.24', '103771', '\r\n']
# ['', '0.00', '0.00', '0.00', '9.50', '-44.81', '-1.63', '1.89', '9.55', '-2.14', '0.44', '0.64', '0.57', '0.24', '103809', '\r\n']
# ['', '0.00', '-0.02', '-0.00', '9.50', '-44.81', '-1.63', '1.89', '9.55', '-2.14', '0.44', '0.64', '0.57', '0.24', '103847', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '9.50', '-44.81', '-1.63', '1.89', '9.55', '-2.14', '0.44', '0.64', '0.57', '0.24', '103887', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '9.50', '-44.81', '-1.63', '1.89', '9.55', '-2.25', '0.44', '0.64', '0.57', '0.24', '103928', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.25', '0.44', '0.64', '0.57', '0.24', '103968', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.25', '0.44', '0.64', '0.57', '0.24', '104007', '\r\n']
# ['', '0.02', '0.01', '-0.00', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.25', '0.44', '0.64', '0.57', '0.24', '104047', '\r\n']
# ['', '0.02', '0.01', '-0.00', '9.50', '-44.81', '-1.63', '1.89', '9.55', '-2.18', '0.44', '0.64', '0.57', '0.24', '104088', '\r\n']
# ['', '0.01', '0.00', '-0.02', '9.50', '-44.81', '-1.63', '1.89', '9.55', '-2.18', '0.44', '0.64', '0.57', '0.24', '104127', '\r\n']
# ['', '0.01', '0.00', '-0.02', '9.50', '-44.81', '-1.63', '1.86', '9.55', '-2.25', '0.44', '0.64', '0.57', '0.24', '104166', '\r\n']
# ['', '0.01', '0.00', '-0.02', '9.50', '-44.81', '-1.63', '1.86', '9.59', '-2.25', '0.44', '0.64', '0.57', '0.24', '104204', '\r\n']
# ['', '0.01', '0.00', '-0.02', '9.50', '-44.81', '-1.63', '1.93', '9.59', '-2.18', '0.44', '0.64', '0.57', '0.24', '104243', '\r\n']
# ['', '-0.01', '-0.00', '-0.02', '9.50', '-44.81', '-1.63', '1.93', '9.59', '-2.18', '0.44', '0.64', '0.57', '0.24', '104282', '\r\n']
# ['', '-0.01', '-0.00', '-0.02', '9.50', '-44.81', '-1.63', '1.93', '9.55', '-2.25', '0.44', '0.64', '0.57', '0.24', '104322', '\r\n']
# ['', '-0.01', '-0.00', '-0.02', '9.50', '-44.81', '-1.63', '1.78', '9.59', '-2.21', '0.44', '0.64', '0.57', '0.24', '104360', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '9.50', '-44.81', '-1.63', '1.78', '9.59', '-2.21', '0.44', '0.64', '0.57', '0.24', '104400', '\r\n']
# ['', '-0.00', '0.04', '-0.01', '9.50', '-44.81', '-1.63', '1.78', '9.59', '-2.21', '0.44', '0.64', '0.57', '0.24', '104440', '\r\n']
# ['', '-0.00', '0.04', '-0.01', '9.50', '-44.81', '-1.63', '1.86', '9.55', '-2.14', '0.44', '0.64', '0.57', '0.24', '104480', '\r\n']
# ['', '-0.00', '0.04', '-0.01', '9.50', '-44.81', '-1.63', '1.86', '9.55', '-2.21', '0.44', '0.64', '0.57', '0.24', '104520', '\r\n']
# ['', '-0.00', '0.04', '-0.01', '9.50', '-44.81', '-1.63', '1.86', '9.59', '-2.21', '0.44', '0.64', '0.57', '0.24', '104558', '\r\n']
# ['', '-0.00', '0.00', '-0.01', '9.50', '-44.81', '-1.63', '1.86', '9.59', '-2.21', '0.44', '0.64', '0.57', '0.24', '104598', '\r\n']
# ['', '0.01', '0.00', '-0.02', '9.50', '-44.81', '-1.63', '1.86', '9.59', '-2.21', '0.44', '0.64', '0.57', '0.24', '104637', '\r\n']
# ['', '0.01', '0.00', '-0.02', '9.50', '-44.81', '-1.63', '1.82', '9.59', '-2.21', '0.44', '0.64', '0.57', '0.24', '104678', '\r\n']
# ['', '0.01', '0.00', '-0.02', '9.50', '-44.81', '-1.63', '1.82', '9.55', '-2.18', '0.44', '0.64', '0.57', '0.24', '104717', '\r\n']
# ['', '0.01', '0.00', '-0.02', '9.50', '-44.81', '-1.63', '1.86', '9.55', '-2.21', '0.44', '0.64', '0.57', '0.24', '104755', '\r\n']
# ['', '0.01', '0.04', '0.00', '9.50', '-44.81', '-1.63', '1.86', '9.55', '-2.21', '0.44', '0.64', '0.57', '0.24', '104793', '\r\n']
# ['', '0.01', '0.04', '0.00', '9.50', '-44.81', '-1.63', '1.86', '9.55', '-2.14', '0.44', '0.64', '0.57', '0.24', '104832', '\r\n']
# ['', '0.01', '0.04', '0.00', '9.50', '-44.81', '-1.63', '1.82', '9.59', '-2.21', '0.44', '0.64', '0.57', '0.24', '104870', '\r\n']
# ['', '0.01', '0.04', '0.00', '9.50', '-44.81', '-1.63', '1.86', '9.59', '-2.18', '0.44', '0.64', '0.57', '0.24', '104908', '\r\n']
# ['', '-0.01', '0.02', '-0.01', '9.50', '-44.81', '-1.63', '1.86', '9.59', '-2.18', '0.44', '0.64', '0.57', '0.24', '104947', '\r\n']
# ['', '-0.01', '0.02', '-0.01', '9.50', '-44.81', '-1.63', '1.82', '9.59', '-2.10', '0.44', '0.64', '0.57', '0.24', '104987', '\r\n']
# ['', '-0.01', '0.02', '-0.01', '9.50', '-44.81', '-1.63', '1.82', '9.59', '-2.14', '0.44', '0.64', '0.57', '0.24', '105028', '\r\n']
# ['', '-0.01', '0.02', '-0.01', '9.50', '-44.81', '-1.63', '1.82', '9.59', '-2.06', '0.44', '0.64', '0.57', '0.24', '105068', '\r\n']
# ['', '-0.01', '0.02', '-0.01', '9.50', '-44.81', '-1.63', '1.82', '9.59', '-2.10', '0.44', '0.64', '0.57', '0.24', '105106', '\r\n']
# ['', '-0.02', '-0.01', '-0.01', '9.50', '-44.81', '-1.63', '1.82', '9.59', '-2.10', '0.44', '0.64', '0.57', '0.24', '105145', '\r\n']
# ['', '-0.02', '-0.01', '-0.01', '9.50', '-44.81', '-1.63', '1.86', '9.59', '-2.14', '0.44', '0.64', '0.57', '0.24', '105186', '\r\n']
# ['', '-0.02', '-0.01', '-0.01', '9.50', '-44.81', '-1.63', '1.78', '9.59', '-2.06', '0.44', '0.64', '0.57', '0.24', '105227', '\r\n']
# ['', '-0.02', '-0.01', '-0.01', '9.50', '-44.81', '-1.63', '1.82', '9.63', '-2.14', '0.44', '0.64', '0.57', '0.24', '105267', '\r\n']
# ['', '-0.02', '-0.01', '-0.01', '9.50', '-44.81', '-1.63', '1.82', '9.59', '-2.02', '0.44', '0.64', '0.57', '0.24', '105306', '\r\n']
# ['', '-0.02', '-0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.82', '9.59', '-2.02', '0.44', '0.64', '0.57', '0.24', '105346', '\r\n']
# ['', '0.01', '0.04', '-0.01', '9.50', '-44.81', '-1.63', '1.82', '9.59', '-2.02', '0.44', '0.64', '0.57', '0.24', '105387', '\r\n']
# ['', '0.01', '0.04', '-0.01', '9.50', '-44.81', '-1.63', '1.78', '9.59', '-1.98', '0.44', '0.64', '0.57', '0.24', '105425', '\r\n']
# ['', '0.01', '0.04', '-0.01', '9.50', '-44.81', '-1.63', '1.78', '9.59', '-2.06', '0.44', '0.64', '0.57', '0.24', '105465', '\r\n']
# ['', '0.01', '0.04', '-0.01', '9.50', '-44.81', '-1.63', '1.78', '9.63', '-1.95', '0.44', '0.64', '0.57', '0.24', '105502', '\r\n']
# ['', '-0.04', '-0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.78', '9.63', '-1.95', '0.44', '0.64', '0.57', '0.24', '105541', '\r\n']
# ['', '-0.04', '-0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.74', '9.63', '-2.06', '0.44', '0.64', '0.57', '0.24', '105581', '\r\n']
# ['', '-0.04', '-0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.78', '9.63', '-1.98', '0.44', '0.64', '0.57', '0.24', '105622', '\r\n']
# ['', '-0.04', '-0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.74', '9.63', '-2.02', '0.44', '0.64', '0.57', '0.24', '105660', '\r\n']
# ['', '-0.04', '-0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.74', '9.63', '-2.02', '0.43', '0.65', '0.58', '0.25', '105700', '\r\n']
# ['', '-0.04', '-0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.74', '9.63', '-1.91', '0.43', '0.65', '0.58', '0.25', '105740', '\r\n']
# ['', '-0.04', '-0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.74', '9.63', '-1.98', '0.43', '0.65', '0.58', '0.25', '105781', '\r\n']
# ['', '-0.04', '-0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.74', '9.63', '-1.95', '0.43', '0.65', '0.58', '0.25', '105821', '\r\n']
# ['', '-0.04', '-0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.74', '9.63', '-1.95', '0.43', '0.65', '0.58', '0.25', '105860', '\r\n']
# ['', '-0.02', '0.03', '-0.01', '9.50', '-44.81', '-1.63', '1.74', '9.63', '-1.95', '0.43', '0.65', '0.58', '0.25', '105901', '\r\n']
# ['', '-0.03', '0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.74', '9.63', '-1.95', '0.43', '0.65', '0.58', '0.25', '105939', '\r\n']
# ['', '-0.03', '0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.70', '9.63', '-1.83', '0.43', '0.65', '0.58', '0.25', '105979', '\r\n']
# ['', '-0.03', '0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.70', '9.67', '-1.83', '0.43', '0.65', '0.58', '0.25', '106019', '\r\n']
# ['', '-0.03', '0.01', '-0.02', '9.50', '-44.81', '-1.63', '1.70', '9.67', '-1.91', '0.43', '0.65', '0.58', '0.25', '106058', '\r\n']
# ['', '-0.06', '0.06', '-0.03', '9.50', '-44.81', '-1.63', '1.70', '9.67', '-1.91', '0.43', '0.65', '0.58', '0.25', '106097', '\r\n']
# ['', '-0.07', '0.04', '-0.03', '9.50', '-44.81', '-1.63', '1.70', '9.67', '-1.91', '0.43', '0.65', '0.58', '0.25', '106137', '\r\n']
# ['', '-0.07', '0.04', '-0.03', '9.50', '-44.81', '-1.63', '1.74', '9.67', '-1.76', '0.43', '0.65', '0.58', '0.25', '106177', '\r\n']
# ['', '-0.07', '0.04', '-0.03', '9.50', '-44.81', '-1.63', '1.66', '9.67', '-1.76', '0.43', '0.65', '0.58', '0.25', '106218', '\r\n']
# ['', '-0.07', '0.04', '-0.03', '9.50', '-44.81', '-1.63', '1.74', '9.67', '-1.76', '0.43', '0.65', '0.58', '0.25', '106256', '\r\n']
# ['', '-0.07', '0.03', '-0.07', '9.50', '-44.81', '-1.63', '1.74', '9.67', '-1.76', '0.43', '0.65', '0.58', '0.25', '106296', '\r\n']
# ['', '-0.07', '0.03', '-0.07', '9.50', '-44.81', '-1.63', '1.59', '9.71', '-1.64', '0.43', '0.65', '0.58', '0.25', '106337', '\r\n']
# ['', '-0.00', '-0.00', '-0.09', '9.50', '-44.81', '-1.63', '1.59', '9.71', '-1.64', '0.43', '0.65', '0.58', '0.25', '106377', '\r\n']
# ['', '-0.00', '-0.00', '-0.09', '9.50', '-44.81', '-1.63', '1.51', '9.71', '-1.64', '0.43', '0.65', '0.58', '0.25', '106417', '\r\n']
# ['', '-0.00', '-0.00', '-0.09', '9.50', '-44.81', '-1.63', '1.47', '9.75', '-1.72', '0.43', '0.65', '0.58', '0.25', '106456', '\r\n']
# ['', '-0.00', '-0.00', '-0.09', '9.50', '-44.81', '-1.63', '1.39', '9.79', '-1.60', '0.43', '0.65', '0.58', '0.25', '106497', '\r\n']
# ['', '0.04', '0.05', '0.00', '9.50', '-44.81', '-1.63', '1.39', '9.79', '-1.60', '0.43', '0.65', '0.58', '0.25', '106537', '\r\n']
# ['', '0.04', '0.05', '0.00', '9.50', '-44.81', '-1.63', '1.39', '9.71', '-1.53', '0.43', '0.65', '0.58', '0.25', '106576', '\r\n']
# ['', '0.04', '0.05', '0.00', '9.50', '-44.81', '-1.63', '1.39', '9.75', '-1.56', '0.43', '0.65', '0.58', '0.25', '106616', '\r\n']
# ['', '0.04', '0.05', '0.00', '9.50', '-44.81', '-1.63', '1.51', '9.71', '-1.60', '0.43', '0.65', '0.58', '0.25', '106653', '\r\n']
# ['', '0.09', '0.06', '-0.02', '9.50', '-44.81', '-1.63', '1.51', '9.71', '-1.60', '0.43', '0.65', '0.58', '0.25', '106692', '\r\n']
# ['', '0.06', '-0.11', '-0.03', '9.50', '-44.81', '-1.63', '1.51', '9.71', '-1.60', '0.43', '0.65', '0.58', '0.25', '106731', '\r\n']
# ['', '0.06', '-0.11', '-0.03', '9.50', '-44.81', '-1.63', '1.51', '9.63', '-1.98', '0.43', '0.65', '0.58', '0.25', '106771', '\r\n']
# ['', '0.06', '-0.11', '-0.03', '9.50', '-44.81', '-1.63', '1.43', '9.75', '-1.95', '0.43', '0.65', '0.58', '0.25', '106809', '\r\n']
# ['', '0.00', '-0.16', '-0.04', '9.50', '-44.81', '-1.63', '1.43', '9.75', '-1.95', '0.43', '0.65', '0.58', '0.25', '106849', '\r\n']
# ['', '0.16', '0.06', '0.03', '9.50', '-44.81', '-1.63', '1.43', '9.75', '-1.95', '0.43', '0.65', '0.58', '0.25', '106889', '\r\n']
# ['', '0.16', '0.06', '0.03', '9.50', '-44.81', '-1.63', '1.39', '9.75', '-1.76', '0.43', '0.65', '0.58', '0.25', '106928', '\r\n']
# ['', '0.16', '0.06', '0.03', '9.50', '-44.81', '-1.63', '1.59', '9.63', '-2.25', '0.43', '0.65', '0.58', '0.25', '106968', '\r\n']
# ['', '0.16', '0.06', '0.03', '9.50', '-44.81', '-1.63', '1.24', '9.75', '-1.68', '0.43', '0.65', '0.58', '0.25', '107004', '\r\n']
# ['', '-0.09', '-0.27', '-0.01', '9.50', '-44.81', '-1.63', '1.24', '9.75', '-1.68', '0.43', '0.65', '0.58', '0.25', '107043', '\r\n']
# ['', '-0.09', '-0.27', '-0.01', '9.50', '-44.81', '-1.63', '1.51', '9.63', '-2.41', '0.43', '0.65', '0.58', '0.25', '107083', '\r\n']
# ['', '-0.09', '-0.27', '-0.01', '9.50', '-44.81', '-1.63', '1.24', '9.71', '-1.98', '0.43', '0.65', '0.58', '0.25', '107124', '\r\n']
# ['', '-0.09', '-0.27', '-0.01', '9.50', '-44.81', '-1.63', '1.59', '9.63', '-2.60', '0.43', '0.65', '0.58', '0.25', '107164', '\r\n']
# ['', '-0.09', '-0.27', '-0.01', '9.50', '-44.81', '-1.63', '1.36', '9.71', '-1.98', '0.43', '0.65', '0.58', '0.25', '107202', '\r\n']
# ['', '-0.15', '-0.31', '0.03', '9.50', '-44.81', '-1.63', '1.36', '9.71', '-1.98', '0.43', '0.65', '0.58', '0.25', '107242', '\r\n']
# ['', '-0.15', '-0.31', '0.03', '9.50', '-44.81', '-1.63', '1.59', '9.59', '-2.60', '0.43', '0.65', '0.58', '0.25', '107281', '\r\n']
# ['', '-0.15', '-0.31', '0.03', '9.50', '-44.81', '-1.63', '1.51', '9.67', '-2.02', '0.43', '0.65', '0.58', '0.25', '107321', '\r\n']
# ['', '-0.15', '-0.31', '0.03', '9.50', '-44.81', '-1.63', '1.55', '9.63', '-2.33', '0.43', '0.65', '0.58', '0.25', '107359', '\r\n']
# ['', '0.03', '-0.04', '0.04', '9.50', '-44.81', '-1.63', '1.55', '9.63', '-2.33', '0.43', '0.65', '0.58', '0.25', '107399', '\r\n']
# ['', '-0.01', '-0.01', '0.03', '9.50', '-44.81', '-1.63', '1.55', '9.63', '-2.33', '0.43', '0.65', '0.58', '0.25', '107439', '\r\n']
# ['', '-0.06', '0.01', '0.04', '9.50', '-44.81', '-1.63', '1.55', '9.63', '-2.33', '0.43', '0.65', '0.58', '0.25', '107479', '\r\n']
# ['', '-0.06', '0.01', '0.04', '9.50', '-44.81', '-1.63', '1.55', '9.63', '-2.10', '0.43', '0.65', '0.58', '0.25', '107517', '\r\n']
# ['', '-0.06', '0.01', '0.04', '9.50', '-44.81', '-1.63', '1.55', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '107554', '\r\n']
# ['', '-0.03', '-0.03', '0.02', '9.50', '-44.81', '-1.63', '1.55', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '107593', '\r\n']
# ['', '-0.01', '-0.03', '0.02', '9.50', '-44.81', '-1.63', '1.55', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '107632', '\r\n']
# ['', '-0.01', '-0.03', '0.02', '9.50', '-44.81', '-1.63', '1.63', '9.59', '-2.21', '0.43', '0.65', '0.58', '0.25', '107672', '\r\n']
# ['', '-0.01', '-0.03', '0.02', '9.50', '-44.81', '-1.63', '1.55', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '107711', '\r\n']
# ['', '-0.01', '-0.03', '0.02', '7.81', '-45.81', '-3.88', '1.55', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '107749', '\r\n']
# ['', '0.07', '0.04', '0.01', '7.81', '-45.81', '-3.88', '1.55', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '107789', '\r\n']
# ['', '0.07', '0.04', '0.01', '7.81', '-45.81', '-3.88', '1.55', '9.63', '-2.10', '0.43', '0.65', '0.58', '0.25', '107829', '\r\n']
# ['', '0.07', '0.04', '0.01', '7.81', '-45.81', '-3.88', '1.63', '9.59', '-2.33', '0.43', '0.65', '0.58', '0.25', '107869', '\r\n']
# ['', '0.07', '0.04', '0.01', '7.81', '-45.81', '-3.88', '1.51', '9.59', '-2.14', '0.43', '0.65', '0.58', '0.25', '107906', '\r\n']
# ['', '-0.03', '-0.09', '0.01', '7.81', '-45.81', '-3.88', '1.51', '9.59', '-2.14', '0.43', '0.65', '0.58', '0.25', '107944', '\r\n']
# ['', '0.06', '0.02', '0.04', '7.81', '-45.81', '-3.88', '1.51', '9.59', '-2.14', '0.43', '0.65', '0.58', '0.25', '107984', '\r\n']
# ['', '0.06', '0.02', '0.04', '7.81', '-45.81', '-3.88', '1.51', '9.63', '-2.10', '0.43', '0.65', '0.58', '0.25', '108024', '\r\n']
# ['', '0.06', '0.02', '0.04', '7.81', '-45.81', '-3.88', '1.66', '9.59', '-2.41', '0.43', '0.65', '0.58', '0.25', '108062', '\r\n']
# ['', '0.06', '0.02', '0.04', '7.81', '-45.81', '-3.88', '1.59', '9.63', '-2.10', '0.43', '0.65', '0.58', '0.25', '108099', '\r\n']
# ['', '-0.02', '-0.02', '0.04', '7.81', '-45.81', '-3.88', '1.59', '9.63', '-2.10', '0.43', '0.65', '0.58', '0.25', '108138', '\r\n']
# ['', '-0.02', '-0.02', '0.04', '7.81', '-45.81', '-3.88', '1.63', '9.59', '-2.25', '0.43', '0.65', '0.58', '0.25', '108178', '\r\n']
# ['', '-0.02', '-0.02', '0.04', '7.81', '-45.81', '-3.88', '1.63', '9.59', '-2.14', '0.43', '0.65', '0.58', '0.25', '108218', '\r\n']
# ['', '-0.02', '-0.02', '0.04', '7.81', '-45.81', '-3.88', '1.66', '9.59', '-2.18', '0.43', '0.65', '0.58', '0.25', '108256', '\r\n']
# ['', '-0.01', '0.00', '0.00', '7.81', '-45.81', '-3.88', '1.66', '9.59', '-2.18', '0.43', '0.65', '0.58', '0.25', '108296', '\r\n']
# ['', '-0.01', '0.00', '0.00', '7.81', '-45.81', '-3.88', '1.66', '9.59', '-2.21', '0.43', '0.65', '0.58', '0.25', '108337', '\r\n']
# ['', '-0.01', '-0.01', '-0.02', '7.81', '-45.81', '-3.88', '1.66', '9.59', '-2.21', '0.43', '0.65', '0.58', '0.25', '108376', '\r\n']
# ['', '-0.01', '-0.01', '-0.02', '7.81', '-45.81', '-3.88', '1.66', '9.59', '-2.21', '0.43', '0.65', '0.58', '0.25', '108417', '\r\n']
# --------------------------------
# RandomForest
# -------------------------------
# Hand: ['W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W']
#
# hello
# 2022-08-04 21:52:56.530910
# 56.530910
# ['', '-0.01', '-0.01', '-0.02', '7.81', '-45.81', '-3.88', '1.63', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '108454', '\r\n']
# ['', '-0.01', '-0.02', '-0.02', '7.81', '-45.81', '-3.88', '1.63', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '108496', '\r\n']
# ['', '-0.00', '-0.00', '-0.02', '7.81', '-45.81', '-3.88', '1.63', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '108536', '\r\n']
# ['', '-0.00', '-0.00', '-0.02', '7.81', '-45.81', '-3.88', '1.59', '9.59', '-2.18', '0.43', '0.65', '0.58', '0.25', '108576', '\r\n']
# ['', '-0.00', '-0.00', '-0.02', '7.81', '-45.81', '-3.88', '1.63', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '108617', '\r\n']
# ['', '-0.00', '-0.00', '-0.02', '7.81', '-45.81', '-3.88', '1.55', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '108656', '\r\n']
# ['', '-0.01', '-0.04', '-0.01', '7.81', '-45.81', '-3.88', '1.55', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '108696', '\r\n']
# ['', '0.01', '-0.02', '0.00', '7.81', '-45.81', '-3.88', '1.55', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '108736', '\r\n']
# ['', '0.01', '-0.02', '0.00', '7.81', '-45.81', '-3.88', '1.59', '9.63', '-2.25', '0.43', '0.65', '0.58', '0.25', '108777', '\r\n']
# ['', '0.01', '-0.02', '0.00', '7.81', '-45.81', '-3.88', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '108816', '\r\n']
# ['', '0.01', '-0.02', '0.00', '7.81', '-45.81', '-3.88', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '108854', '\r\n']
# ['', '0.01', '0.01', '-0.01', '7.81', '-45.81', '-3.88', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '108892', '\r\n']
# ['', '0.01', '0.01', '-0.01', '7.81', '-45.81', '-3.88', '1.55', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '108931', '\r\n']
# ['', '0.01', '0.01', '-0.01', '7.81', '-45.81', '-3.88', '1.55', '9.59', '-2.21', '0.43', '0.65', '0.58', '0.25', '108969', '\r\n']
# ['', '0.01', '0.01', '-0.01', '7.81', '-45.81', '-3.88', '1.59', '9.59', '-2.21', '0.43', '0.65', '0.58', '0.25', '109007', '\r\n']
# ['', '-0.01', '0.00', '0.00', '7.81', '-45.81', '-3.88', '1.59', '9.59', '-2.21', '0.43', '0.65', '0.58', '0.25', '109046', '\r\n']
# ['', '-0.01', '0.00', '0.00', '7.81', '-45.81', '-3.88', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '109085', '\r\n']
# ['', '-0.01', '0.00', '0.00', '7.81', '-45.81', '-3.88', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '109126', '\r\n']
# ['', '-0.01', '0.00', '0.00', '7.81', '-45.81', '-3.88', '1.55', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '109165', '\r\n']
# ['', '-0.01', '0.00', '0.00', '7.81', '-45.81', '-3.88', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '109203', '\r\n']
# ['', '0.00', '0.01', '-0.00', '7.81', '-45.81', '-3.88', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '109242', '\r\n']
# ['', '-0.01', '-0.02', '-0.00', '7.81', '-45.81', '-3.88', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '109281', '\r\n']
# ['', '-0.01', '-0.02', '-0.00', '7.81', '-45.81', '-3.88', '1.55', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '109321', '\r\n']
# ['', '-0.01', '-0.02', '-0.00', '7.81', '-45.81', '-3.88', '1.55', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '109359', '\r\n']
# ['', '0.01', '0.01', '-0.00', '7.81', '-45.81', '-3.88', '1.55', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '109399', '\r\n']
# ['', '0.01', '0.01', '-0.00', '7.81', '-45.81', '-3.88', '1.55', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '109438', '\r\n']
# ['', '0.02', '0.01', '-0.00', '7.81', '-45.81', '-3.88', '1.55', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '109477', '\r\n']
# ['', '0.02', '0.01', '-0.00', '7.81', '-45.81', '-3.88', '1.55', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '109517', '\r\n']
# ['', '0.02', '0.01', '-0.00', '7.81', '-45.81', '-3.88', '1.59', '9.63', '-2.21', '0.43', '0.65', '0.58', '0.25', '109555', '\r\n']
# ['', '0.01', '0.00', '-0.00', '7.81', '-45.81', '-3.88', '1.59', '9.63', '-2.21', '0.43', '0.65', '0.58', '0.25', '109594', '\r\n']
# ['', '0.01', '0.00', '0.00', '7.81', '-45.81', '-3.88', '1.59', '9.63', '-2.21', '0.43', '0.65', '0.58', '0.25', '109633', '\r\n']
# ['', '0.01', '0.00', '0.00', '7.81', '-45.81', '-3.88', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '109671', '\r\n']
# ['', '0.01', '0.00', '0.00', '7.81', '-45.81', '-3.88', '1.55', '9.59', '-2.21', '0.43', '0.65', '0.58', '0.25', '109710', '\r\n']
# ['', '0.01', '0.00', '0.00', '7.00', '-47.50', '-2.69', '1.55', '9.59', '-2.21', '0.43', '0.65', '0.58', '0.25', '109749', '\r\n']
# ['', '0.00', '-0.00', '0.00', '7.00', '-47.50', '-2.69', '1.55', '9.59', '-2.21', '0.43', '0.65', '0.58', '0.25', '109788', '\r\n']
# ['', '0.00', '-0.00', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.59', '-2.18', '0.43', '0.65', '0.58', '0.25', '109827', '\r\n']
# ['', '0.00', '-0.00', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.59', '-2.25', '0.43', '0.65', '0.58', '0.25', '109865', '\r\n']
# ['', '0.00', '-0.00', '0.00', '7.00', '-47.50', '-2.69', '1.55', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '109903', '\r\n']
# ['', '-0.01', '-0.02', '0.00', '7.00', '-47.50', '-2.69', '1.55', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '109942', '\r\n']
# ['', '0.02', '0.02', '-0.00', '7.00', '-47.50', '-2.69', '1.55', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '109981', '\r\n']
# ['', '0.02', '0.02', '-0.00', '7.00', '-47.50', '-2.69', '1.55', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '110020', '\r\n']
# ['', '0.02', '0.02', '-0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '110058', '\r\n']
# ['', '0.00', '0.01', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '110097', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '110136', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '110177', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '7.00', '-47.50', '-2.69', '1.55', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '110218', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.21', '0.43', '0.65', '0.58', '0.25', '110257', '\r\n']
# ['', '0.00', '0.01', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.21', '0.43', '0.65', '0.58', '0.25', '110297', '\r\n']
# ['', '0.00', '0.01', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '110336', '\r\n']
# ['', '0.00', '0.01', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '110375', '\r\n']
# ['', '0.00', '0.01', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '110414', '\r\n']
# ['', '0.00', '0.01', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '110451', '\r\n']
# ['', '-0.00', '-0.01', '-0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '110490', '\r\n']
# ['', '-0.00', '-0.01', '-0.00', '7.00', '-47.50', '-2.69', '1.59', '9.59', '-2.21', '0.43', '0.65', '0.58', '0.25', '110530', '\r\n']
# ['', '-0.00', '-0.01', '-0.00', '7.00', '-47.50', '-2.69', '1.55', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '110570', '\r\n']
# ['', '-0.00', '-0.01', '-0.00', '7.00', '-47.50', '-2.69', '1.59', '9.59', '-2.21', '0.43', '0.65', '0.58', '0.25', '110609', '\r\n']
# ['', '0.01', '0.01', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.59', '-2.21', '0.43', '0.65', '0.58', '0.25', '110648', '\r\n']
# ['', '0.01', '0.01', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '110688', '\r\n']
# ['', '-0.00', '0.01', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '110727', '\r\n']
# ['', '-0.00', '0.01', '0.00', '7.00', '-47.50', '-2.69', '1.55', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '110766', '\r\n']
# ['', '-0.00', '0.01', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '110803', '\r\n']
# ['', '-0.00', '0.01', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.21', '0.43', '0.65', '0.58', '0.25', '110842', '\r\n']
# ['', '0.00', '0.00', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.21', '0.43', '0.65', '0.58', '0.25', '110881', '\r\n']
# ['', '0.00', '0.00', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.59', '-2.14', '0.43', '0.65', '0.58', '0.25', '110920', '\r\n']
# ['', '0.00', '0.00', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.21', '0.43', '0.65', '0.58', '0.25', '110957', '\r\n']
# ['', '0.01', '0.00', '0.01', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.21', '0.43', '0.65', '0.58', '0.25', '110997', '\r\n']
# ['', '0.01', '0.00', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.21', '0.43', '0.65', '0.58', '0.25', '111036', '\r\n']
# ['', '0.01', '0.00', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '111075', '\r\n']
# ['', '0.01', '0.00', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.59', '-2.25', '0.43', '0.65', '0.58', '0.25', '111114', '\r\n']
# ['', '0.01', '0.00', '0.00', '7.00', '-47.50', '-2.69', '1.59', '9.59', '-2.18', '0.43', '0.65', '0.58', '0.25', '111151', '\r\n']
# ['', '-0.02', '-0.01', '0.01', '7.00', '-47.50', '-2.69', '1.59', '9.59', '-2.18', '0.43', '0.65', '0.58', '0.25', '111190', '\r\n']
# ['', '0.00', '0.01', '0.01', '7.00', '-47.50', '-2.69', '1.59', '9.59', '-2.18', '0.43', '0.65', '0.58', '0.25', '111228', '\r\n']
# ['', '0.00', '0.01', '0.01', '7.00', '-47.50', '-2.69', '1.59', '9.59', '-2.18', '0.43', '0.65', '0.58', '0.25', '111267', '\r\n']
# ['', '0.00', '0.01', '0.01', '7.00', '-47.50', '-2.69', '1.63', '9.59', '-2.21', '0.43', '0.65', '0.58', '0.25', '111304', '\r\n']
# ['', '0.00', '0.01', '0.01', '7.00', '-47.50', '-2.69', '1.63', '9.59', '-2.21', '0.43', '0.65', '0.58', '0.25', '111343', '\r\n']
# ['', '-0.01', '-0.01', '0.01', '7.00', '-47.50', '-2.69', '1.63', '9.59', '-2.21', '0.43', '0.65', '0.58', '0.25', '111381', '\r\n']
# ['', '-0.01', '-0.01', '0.01', '7.00', '-47.50', '-2.69', '1.63', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '111420', '\r\n']
# ['', '-0.01', '-0.01', '0.01', '7.00', '-47.50', '-2.69', '1.63', '9.59', '-2.14', '0.43', '0.65', '0.58', '0.25', '111458', '\r\n']
# ['', '0.00', '0.00', '0.00', '7.00', '-47.50', '-2.69', '1.63', '9.59', '-2.14', '0.43', '0.65', '0.58', '0.25', '111499', '\r\n']
# ['', '-0.00', '0.02', '-0.00', '7.00', '-47.50', '-2.69', '1.63', '9.59', '-2.14', '0.43', '0.65', '0.58', '0.25', '111538', '\r\n']
# ['', '-0.00', '0.02', '-0.00', '7.00', '-47.50', '-2.69', '1.63', '9.63', '-2.21', '0.43', '0.65', '0.58', '0.25', '111578', '\r\n']
# ['', '-0.00', '0.02', '-0.00', '7.00', '-47.50', '-2.69', '1.59', '9.59', '-2.18', '0.43', '0.65', '0.58', '0.25', '111618', '\r\n']
# ['', '-0.00', '0.02', '-0.00', '7.00', '-47.50', '-2.69', '1.66', '9.63', '-2.21', '0.43', '0.65', '0.58', '0.25', '111655', '\r\n']
# ['', '-0.01', '0.00', '0.01', '7.00', '-47.50', '-2.69', '1.66', '9.63', '-2.21', '0.43', '0.65', '0.58', '0.25', '111695', '\r\n']
# ['', '0.01', '0.04', '0.00', '7.00', '-47.50', '-2.69', '1.66', '9.63', '-2.21', '0.43', '0.65', '0.58', '0.25', '111734', '\r\n']
# ['', '0.01', '0.04', '0.00', '7.00', '-47.50', '-2.69', '1.66', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '111773', '\r\n']
# ['', '0.01', '0.04', '0.00', '7.00', '-47.50', '-2.69', '1.63', '9.59', '-2.14', '0.43', '0.65', '0.58', '0.25', '111812', '\r\n']
# ['', '0.01', '0.04', '0.00', '7.00', '-47.50', '-2.69', '1.66', '9.59', '-2.14', '0.43', '0.65', '0.58', '0.25', '111849', '\r\n']
# ['', '-0.01', '0.00', '0.00', '7.00', '-47.50', '-2.69', '1.66', '9.59', '-2.14', '0.43', '0.65', '0.58', '0.25', '111888', '\r\n']
# ['', '-0.01', '0.00', '0.00', '7.00', '-47.50', '-2.69', '1.66', '9.63', '-2.14', '0.43', '0.65', '0.58', '0.25', '111927', '\r\n']
# ['', '-0.01', '0.00', '0.00', '7.00', '-47.50', '-2.69', '1.66', '9.59', '-2.14', '0.43', '0.65', '0.58', '0.25', '111968', '\r\n']
# ['', '-0.01', '0.00', '0.00', '7.00', '-47.50', '-2.69', '1.70', '9.63', '-2.10', '0.43', '0.65', '0.58', '0.25', '112005', '\r\n']
# ['', '-0.01', '0.01', '0.03', '7.00', '-47.50', '-2.69', '1.70', '9.63', '-2.10', '0.43', '0.65', '0.58', '0.25', '112045', '\r\n']
# ['', '-0.01', '0.01', '0.03', '7.00', '-47.50', '-2.69', '1.74', '9.63', '-2.10', '0.43', '0.65', '0.58', '0.25', '112083', '\r\n']
# ['', '-0.01', '0.01', '0.03', '7.00', '-47.50', '-2.69', '1.74', '9.63', '-2.18', '0.43', '0.65', '0.58', '0.25', '112122', '\r\n']
# ['', '-0.01', '0.01', '0.03', '7.00', '-47.50', '-2.69', '1.74', '9.63', '-2.10', '0.43', '0.65', '0.58', '0.25', '112161', '\r\n']
# ['', '-0.01', '0.01', '0.03', '7.00', '-47.50', '-2.69', '1.78', '9.59', '-2.10', '0.43', '0.65', '0.58', '0.25', '112198', '\r\n']
# ['', '-0.01', '-0.02', '0.01', '7.00', '-47.50', '-2.69', '1.78', '9.59', '-2.10', '0.43', '0.65', '0.58', '0.25', '112237', '\r\n']
# ['', '-0.01', '-0.02', '0.01', '7.00', '-47.50', '-2.69', '1.74', '9.63', '-2.02', '0.43', '0.65', '0.58', '0.25', '112277', '\r\n']
# ['', '-0.01', '-0.02', '0.01', '7.00', '-47.50', '-2.69', '1.74', '9.59', '-2.06', '0.43', '0.65', '0.58', '0.25', '112317', '\r\n']
# --------------------------------
# RandomForest
# -------------------------------
# Hand: ['W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
# ...
# ['', '-0.01', '-0.00', '0.00', '10.31', '-45.94', '-0.44', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '215351', '\r\n']
# ['', '-0.01', '-0.00', '0.00', '10.31', '-45.94', '-0.44', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '215391', '\r\n']
# ['', '-0.01', '-0.00', '0.00', '10.31', '-45.94', '-0.44', '1.55', '9.59', '-2.29', '0.38', '0.68', '0.59', '0.21', '215430', '\r\n']
# ['', '-0.01', '-0.00', '0.00', '9.31', '-46.50', '-0.44', '1.55', '9.59', '-2.29', '0.38', '0.68', '0.59', '0.21', '215469', '\r\n']
# ['', '0.02', '0.03', '0.01', '9.31', '-46.50', '-0.44', '1.55', '9.59', '-2.29', '0.38', '0.68', '0.59', '0.21', '215508', '\r\n']
# ['', '0.02', '0.03', '0.01', '9.31', '-46.50', '-0.44', '1.55', '9.59', '-2.18', '0.38', '0.68', '0.59', '0.21', '215548', '\r\n']
# ['', '0.02', '0.03', '0.01', '9.31', '-46.50', '-0.44', '1.63', '9.59', '-2.29', '0.38', '0.68', '0.59', '0.21', '215587', '\r\n']
# --------------------------------
# RandomForest
# -------------------------------
# Hand: ['W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W']
#
# hello
# 2022-08-04 21:54:43.853723
# 43.853723
# ['', '0.02', '0.03', '0.01', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.18', '0.38', '0.68', '0.59', '0.21', '215624', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.18', '0.38', '0.68', '0.59', '0.21', '215663', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '215704', '\r\n']
# ['', '0.01', '0.02', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '215744', '\r\n']
# ['', '0.01', '0.02', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.18', '0.38', '0.68', '0.59', '0.21', '215782', '\r\n']
# ['', '0.01', '0.02', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '215820', '\r\n']
# ['', '0.01', '0.02', '0.00', '9.31', '-46.50', '-0.44', '1.63', '9.59', '-2.29', '0.38', '0.68', '0.59', '0.21', '215859', '\r\n']
# ['', '0.00', '-0.00', '0.00', '9.31', '-46.50', '-0.44', '1.63', '9.59', '-2.29', '0.38', '0.68', '0.59', '0.21', '215898', '\r\n']
# ['', '0.00', '-0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '215937', '\r\n']
# ['', '0.00', '-0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '215974', '\r\n']
# ['', '-0.00', '0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '216015', '\r\n']
# ['', '0.00', '-0.00', '-0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '216054', '\r\n']
# ['', '0.00', '-0.00', '-0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '216093', '\r\n']
# ['', '0.00', '-0.00', '-0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '216133', '\r\n']
# ['', '0.00', '-0.00', '-0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '216171', '\r\n']
# ['', '0.00', '-0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '216210', '\r\n']
# ['', '0.00', '-0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '216248', '\r\n']
# ['', '0.00', '-0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '216288', '\r\n']
# ['', '0.00', '-0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '216326', '\r\n']
# ['', '-0.01', '-0.01', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '216365', '\r\n']
# ['', '-0.00', '0.01', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '216404', '\r\n']
# ['', '-0.00', '0.01', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '216442', '\r\n']
# ['', '-0.00', '0.01', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '216482', '\r\n']
# ['', '-0.00', '0.01', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '216519', '\r\n']
# ['', '-0.01', '-0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '216558', '\r\n']
# ['', '-0.01', '-0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '216598', '\r\n']
# ['', '-0.01', '-0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '216639', '\r\n']
# ['', '-0.01', '-0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '216677', '\r\n']
# ['', '0.01', '0.01', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '216717', '\r\n']
# ['', '0.00', '0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '216756', '\r\n']
# ['', '0.00', '0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '216796', '\r\n']
# ['', '0.00', '0.00', '0.00', '9.31', '-46.50', '-0.44', '1.55', '9.59', '-2.18', '0.38', '0.68', '0.59', '0.21', '216835', '\r\n']
# ['', '0.00', '0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.29', '0.38', '0.68', '0.59', '0.21', '216871', '\r\n']
# ['', '0.01', '0.02', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.29', '0.38', '0.68', '0.59', '0.21', '216910', '\r\n']
# ['', '0.01', '0.02', '0.00', '9.31', '-46.50', '-0.44', '1.55', '9.63', '-2.21', '0.38', '0.68', '0.59', '0.21', '216949', '\r\n']
# ['', '0.01', '0.02', '0.00', '9.31', '-46.50', '-0.44', '1.63', '9.59', '-2.29', '0.38', '0.68', '0.59', '0.21', '216988', '\r\n']
# ['', '0.01', '0.02', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '217025', '\r\n']
# ['', '0.00', '0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '217065', '\r\n']
# ['', '0.00', '0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '217104', '\r\n']
# ['', '0.00', '0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '217143', '\r\n']
# ['', '0.00', '0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '217181', '\r\n']
# ['', '0.00', '0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.29', '0.38', '0.68', '0.59', '0.21', '217218', '\r\n']
# ['', '-0.00', '0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.29', '0.38', '0.68', '0.59', '0.21', '217256', '\r\n']
# ['', '-0.00', '0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '217297', '\r\n']
# ['', '-0.00', '0.00', '0.00', '9.31', '-46.50', '-0.44', '1.63', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '217336', '\r\n']
# ['', '-0.00', '0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '217374', '\r\n']
# ['', '0.00', '0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '217413', '\r\n']
# ['', '0.00', '0.00', '0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '217452', '\r\n']
# ['', '0.00', '-0.00', '-0.00', '9.31', '-46.50', '-0.44', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '217490', '\r\n']
# ['', '0.00', '-0.00', '-0.00', '9.31', '-46.50', '-0.44', '1.63', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '217529', '\r\n']
# ['', '0.00', '-0.00', '-0.00', '9.38', '-46.06', '-1.25', '1.63', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '217568', '\r\n']
# ['', '0.00', '-0.00', '-0.00', '9.38', '-46.06', '-1.25', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '217608', '\r\n']
# ['', '0.01', '0.01', '0.00', '9.38', '-46.06', '-1.25', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '217648', '\r\n']
# ['', '0.01', '0.01', '0.00', '9.38', '-46.06', '-1.25', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '217687', '\r\n']
# ['', '0.01', '0.01', '0.00', '9.38', '-46.06', '-1.25', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '217724', '\r\n']
# ['', '-0.00', '-0.00', '0.00', '9.38', '-46.06', '-1.25', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '217764', '\r\n']
# ['', '-0.00', '0.01', '0.00', '9.38', '-46.06', '-1.25', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '217804', '\r\n']
# ['', '-0.00', '0.01', '0.00', '9.38', '-46.06', '-1.25', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '217843', '\r\n']
# ['', '-0.00', '0.01', '0.00', '9.38', '-46.06', '-1.25', '1.63', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '217881', '\r\n']
# ['', '-0.00', '0.01', '0.00', '9.38', '-46.06', '-1.25', '1.63', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '217919', '\r\n']
# ['', '-0.00', '-0.00', '0.00', '9.38', '-46.06', '-1.25', '1.63', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '217958', '\r\n']
# ['', '-0.00', '0.00', '0.00', '9.38', '-46.06', '-1.25', '1.63', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '217998', '\r\n']
# ['', '-0.00', '0.00', '0.00', '9.38', '-46.06', '-1.25', '1.63', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '218037', '\r\n']
# ['', '-0.00', '0.00', '0.00', '9.38', '-46.06', '-1.25', '1.59', '9.59', '-2.18', '0.38', '0.68', '0.59', '0.21', '218075', '\r\n']
# ['', '0.00', '-0.00', '0.00', '9.38', '-46.06', '-1.25', '1.59', '9.59', '-2.18', '0.38', '0.68', '0.59', '0.21', '218114', '\r\n']
# ['', '-0.00', '-0.01', '0.00', '9.38', '-46.06', '-1.25', '1.59', '9.59', '-2.18', '0.38', '0.68', '0.59', '0.21', '218153', '\r\n']
# ['', '-0.00', '-0.01', '0.00', '9.38', '-46.06', '-1.25', '1.63', '9.59', '-2.29', '0.38', '0.68', '0.59', '0.21', '218192', '\r\n']
# ['', '-0.00', '-0.01', '0.00', '9.38', '-46.06', '-1.25', '1.63', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '218232', '\r\n']
# ['', '-0.00', '-0.01', '0.00', '9.38', '-46.06', '-1.25', '1.63', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '218269', '\r\n']
# ['', '0.01', '0.03', '0.01', '9.38', '-46.06', '-1.25', '1.63', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '218309', '\r\n']
# ['', '0.01', '0.03', '0.01', '9.38', '-46.06', '-1.25', '1.63', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '218347', '\r\n']
# ['', '0.01', '0.03', '0.01', '9.38', '-46.06', '-1.25', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '218386', '\r\n']
# ['', '0.01', '0.03', '0.01', '9.38', '-46.06', '-1.25', '1.59', '9.59', '-2.18', '0.38', '0.68', '0.59', '0.21', '218424', '\r\n']
# ['', '0.01', '0.01', '0.00', '9.38', '-46.06', '-1.25', '1.59', '9.59', '-2.18', '0.38', '0.68', '0.59', '0.21', '218463', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '9.38', '-46.06', '-1.25', '1.59', '9.59', '-2.18', '0.38', '0.68', '0.59', '0.21', '218502', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '9.38', '-46.06', '-1.25', '1.63', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '218541', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '9.38', '-46.06', '-1.25', '1.63', '9.59', '-2.18', '0.38', '0.68', '0.59', '0.21', '218580', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '10.56', '-46.81', '1.06', '1.63', '9.59', '-2.18', '0.38', '0.68', '0.59', '0.21', '218619', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '10.56', '-46.81', '1.06', '1.63', '9.59', '-2.18', '0.38', '0.68', '0.59', '0.21', '218659', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '10.56', '-46.81', '1.06', '1.63', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '218699', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '10.56', '-46.81', '1.06', '1.59', '9.59', '-2.21', '0.38', '0.68', '0.59', '0.21', '218739', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '10.56', '-46.81', '1.06', '1.59', '9.59', '-2.25', '0.38', '0.68', '0.59', '0.21', '218778', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '10.56', '-46.81', '1.06', '1.59', '9.59', '-2.25', '0.39', '0.68', '0.59', '0.21', '218817', '\r\n']
# ['', '-0.01', '-0.01', '-0.00', '10.56', '-46.81', '1.06', '1.63', '9.59', '-2.25', '0.39', '0.68', '0.59', '0.21', '218858', '\r\n']
# ['', '0.00', '0.00', '-0.00', '10.56', '-46.81', '1.06', '1.63', '9.59', '-2.25', '0.39', '0.68', '0.59', '0.21', '218898', '\r\n']
# ['', '0.00', '0.00', '-0.00', '10.56', '-46.81', '1.06', '1.63', '9.59', '-2.21', '0.39', '0.68', '0.59', '0.21', '218937', '\r\n']
# ['', '0.00', '0.00', '-0.00', '10.56', '-46.81', '1.06', '1.63', '9.59', '-2.21', '0.39', '0.68', '0.59', '0.21', '218975', '\r\n']
# ['', '0.00', '0.01', '-0.00', '10.56', '-46.81', '1.06', '1.63', '9.59', '-2.21', '0.39', '0.68', '0.59', '0.21', '219015', '\r\n']
# ['', '-0.01', '-0.01', '0.00', '10.56', '-46.81', '1.06', '1.63', '9.59', '-2.21', '0.39', '0.68', '0.59', '0.21', '219055', '\r\n']
# ['', '-0.01', '-0.01', '0.00', '10.56', '-46.81', '1.06', '1.63', '9.59', '-2.25', '0.39', '0.68', '0.59', '0.21', '219094', '\r\n']
# ['', '-0.01', '-0.01', '0.00', '10.56', '-46.81', '1.06', '1.63', '9.59', '-2.21', '0.39', '0.68', '0.59', '0.21', '219133', '\r\n']
# ['', '-0.01', '-0.01', '0.00', '10.56', '-46.81', '1.06', '1.59', '9.59', '-2.21', '0.39', '0.68', '0.59', '0.21', '219172', '\r\n']
# ['', '0.00', '0.00', '-0.00', '10.56', '-46.81', '1.06', '1.59', '9.59', '-2.21', '0.39', '0.68', '0.59', '0.21', '219211', '\r\n']
# ['', '-0.00', '0.00', '-0.00', '10.56', '-46.81', '1.06', '1.59', '9.59', '-2.21', '0.39', '0.68', '0.59', '0.21', '219250', '\r\n']
# ['', '-0.00', '0.00', '-0.00', '10.56', '-46.81', '1.06', '1.63', '9.59', '-2.21', '0.39', '0.68', '0.59', '0.21', '219289', '\r\n']
# ['', '-0.00', '0.00', '-0.00', '10.56', '-46.81', '1.06', '1.59', '9.59', '-2.25', '0.39', '0.68', '0.59', '0.21', '219327', '\r\n']
# ['', '-0.00', '-0.01', '-0.00', '10.56', '-46.81', '1.06', '1.59', '9.59', '-2.25', '0.39', '0.68', '0.59', '0.21', '219367', '\r\n']
# ['', '0.00', '0.01', '0.00', '10.56', '-46.81', '1.06', '1.59', '9.59', '-2.25', '0.39', '0.68', '0.59', '0.21', '219408', '\r\n']
# ['', '0.00', '0.01', '0.00', '10.56', '-46.81', '1.06', '1.63', '9.59', '-2.21', '0.39', '0.68', '0.59', '0.21', '219447', '\r\n']
# ['', '0.00', '0.01', '0.00', '10.56', '-46.81', '1.06', '1.63', '9.59', '-2.25', '0.39', '0.68', '0.59', '0.21', '219487', '\r\n']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 388>()
#     411     TT=5
#     412     while(tt<=TT):
# --> 413         data = serialPort.readline().decode('utf-8', 'ignore')
#     414     #     data2 = serialPort2.readline().decode('utf-8')
#     415 #         print(data)
#     416     #     print(data2)
#     417         data=data.split(',')
#
# File ~\anaconda3\lib\site-packages\serial\serialwin32.py:288, in Serial.read(self, size)
#     286 if not read_ok and win32.GetLastError() not in (win32.ERROR_SUCCESS, win32.ERROR_IO_PENDING):
#     287     raise SerialException("ReadFile failed ({!r})".format(ctypes.WinError()))
# --> 288 result_ok = win32.GetOverlappedResult(
#     289     self._port_handle,
#     290     ctypes.byref(self._overlapped_read),
#     291     ctypes.byref(rc),
#     292     True)
#     293 if not result_ok:
#     294     if win32.GetLastError() != win32.ERROR_OPERATION_ABORTED:
#
# KeyboardInterrupt:

# %%
pip install pyserial
