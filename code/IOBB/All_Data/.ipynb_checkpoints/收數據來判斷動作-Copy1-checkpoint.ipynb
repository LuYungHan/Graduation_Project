# %%
import serial
import csv
import time
import pandas as pd
from datetime import datetime, timedelta
from time import sleep
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import math
from scipy import signal
from PIL import Image

np.random.seed(202205456)

data0506 = [
            "../0506data/手2022-05-06 114900-4.csv",
            "../0506data/手2022-05-06 113600-4.csv",
            "../0506data/手2022-05-06 115200-2.csv",
            "../0506data/腳2022-05-06 120000-4.csv",
            "../0506data/腳2022-05-06 120300-3.csv",
            "../0506data/腳2022-05-06 120500-4.csv",
            "../腳_1.csv"]
                                                    
data0510 = [
            "../0510data/手腳2022-05-10 104600.csv", #0
            "../0510data/手腳2022-05-10 104400.csv",#
            "../0510data/手腳2022-05-10 104800.csv",
            "../0510data/手腳2022-05-10 104000.csv",
            "../0510data/手2022-05-10 103600.csv",
            "../0510data/手2022-05-10 103800.csv",
            "../0510data/手2022-05-10 104000.csv",
            "../0510data/手2022-05-10 103600優化.csv",#7
            "../0510data/手2022-05-10 103800優化.csv",#8
            "../0510data/手2022-05-10 104000優化.csv",#9
            "../0510data/腳2022-05-10 103600優化.csv",#10
            "../0510data/腳2022-05-10 103800優化.csv",#11
            "../0510data/腳2022-05-10 104000優化.csv",#12
            "../0510data/腳2022-05-10 104000.csv"]

def RF(data):
    data = np.array(pd.read_csv(data))
    add = []
    fs_start = 8
    fs_end = len(data[:,1])-17 + 8 
    for i in range(len(data[:,1])-17):
        add.append([])
#     data = np.array(pd.read_csv(data))
    f, t, fft_gx = signal.stft(data[:,1],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    f1, t1, fft_gy = signal.stft(data[:,2],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    f2, t2, fft_gz = signal.stft(data[:,3],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    f3, t3, fft_ax = signal.stft(data[:,7],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    f4, t4, fft_ay = signal.stft(data[:,8],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    f5, t5, fft_az = signal.stft(data[:,9],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
    #fft_gx
    for i in range (len(fft_gx[100,:])):
        add[i].append(math.atan2((fft_gx[100,i].real),(fft_gx[100,i].imag)))
        add[i].append(math.atan2((fft_gx[600,i].real),(fft_gx[600,i].imag)))
        add[i].append(math.atan2((fft_gx[800,i].real),(fft_gx[800,i].imag)))
        
    #fft_gy
    for i in range (len(fft_gy[100,:])):
        add[i].append(math.atan2((fft_gy[100,i].real),(fft_gy[100,i].imag)))
        add[i].append(math.atan2((fft_gy[600,i].real),(fft_gy[600,i].imag)))
        add[i].append(math.atan2((fft_gy[800,i].real),(fft_gy[800,i].imag)))
    #fft_gz
    for i in range (len(fft_gz[100,:])):
        add[i].append(math.atan2((fft_gz[100,i].real),(fft_gz[100,i].imag)))
        add[i].append(math.atan2((fft_gz[600,i].real),(fft_gz[600,i].imag)))
        add[i].append(math.atan2((fft_gz[800,i].real),(fft_gz[800,i].imag)))
    #fft_ax
    for i in range (len(fft_ax[100,:])):
        add[i].append(math.atan2((fft_ax[100,i].real),(fft_ax[100,i].imag)))
        add[i].append(math.atan2((fft_ax[600,i].real),(fft_ax[600,i].imag)))
        add[i].append(math.atan2((fft_ax[800,i].real),(fft_ax[800,i].imag)))
    #fft_ay
    for i in range (len(fft_ay[100,:])):
        add[i].append(math.atan2((fft_ay[100,i].real),(fft_ay[100,i].imag)))
        add[i].append(math.atan2((fft_ay[600,i].real),(fft_ay[600,i].imag)))
        add[i].append(math.atan2((fft_ay[800,i].real),(fft_ay[800,i].imag)))
    #fft_az
    for i in range (len(fft_az[100,:])):
        add[i].append(math.atan2((fft_az[100,i].real),(fft_az[100,i].imag)))
        add[i].append(math.atan2((fft_az[600,i].real),(fft_az[600,i].imag)))
        add[i].append(math.atan2((fft_az[800,i].real),(fft_az[800,i].imag)))
    
    data = np.append(data[fs_start:fs_end,:], add , axis=1)
    
#     pandasData={"Xg":data[:,1],"Yg":data[:,2],"Zg":data[:,3],"Xm":data[:,4],"Ym":data[:,5],"Zm":data[:,6],"Xa":data[:,7],"Ya":data[:,8],"Za":data[:,9],"Xq":data[:,10],"Yq":data[:,11],"Zq":data[:,12],"Direction":data[:,13],"SensorTime":data[:,14],"Time":data[:,15],"Label":data[:,16],"Fft_gx1":data[:,17],"Fft_gx2":data[:,18],"Fft_gx3":data[:,19],"Fft_gy1":data[:,20],"Fft_gy2":data[:,21],"Fft_gy3":data[:,22],"Fft_gz1":data[:,23],"Fft_gz2":data[:,24],"Fft_gz3":data[:,25]}
    pandasData={"Xg":data[:,1],"Yg":data[:,2],"Zg":data[:,3],"Xm":data[:,4],"Ym":data[:,5],"Zm":data[:,6],"Xa":data[:,7],"Ya":data[:,8],"Za":data[:,9],"Xq":data[:,10],"Yq":data[:,11],"Zq":data[:,12],"Direction":data[:,13],"SensorTime":data[:,14],"Time":data[:,15],"Label":data[:,16],"Fft_gx":data[:,17],"Fft_gy":data[:,20],"Fft_gz":data[:,23],"Fft_ax":data[:,26],"Fft_ay":data[:,29],"Fft_az":data[:,32]}
   
    df = pd.DataFrame(pandasData)
    df.to_csv('../Add_fft_features_data/AfterFft_fft_arctan_40_Hand'+'.csv')
# for i in range(1):
#     print("")
#     RF(data0510[i+9])
count = 2
# data0506 = [
#             "../All_Data/new_data/手2022-05-06 114900-4.csv",
#             "../All_Data/new_data/手2022-05-06 113600-4.csv",
#             "../All_Data/new_data/手2022-05-06 115200-2.csv",
#             "../All_Data/new_data/腳2022-05-06 120000-4.csv",
#             "../All_Data/new_data/腳2022-05-06 120300-3.csv",
#             "../All_Data/new_data/腳2022-05-06 120500-4.csv",
#             "./腳_2.csv"]
                                                    
data0510 = [
            "../All_Data/0510data/手2022-05-10 103600.csv",
            "../All_Data/0510data/手2022-05-10 103800.csv",
            "../All_Data/0510data/手2022-05-10 104000.csv",
            "../All_Data/0510data/腳2022-05-10 103600.csv",
            "../All_Data/0510data/腳2022-05-10 103800.csv",
            "../All_Data/0510data/腳2022-05-10 104000.csv"]


dataFft = ["../Add_fft_features_data/AfterFft_36_Foot.csv",#0
          "../Add_fft_features_data/AfterFft_38_Foot.csv",#1
          "../Add_fft_features_data/AfterFft_40_Foot.csv",#2
          "../Add_fft_features_data/AfterFft_36_Hand.csv",#3
          "../Add_fft_features_data/AfterFft_38_Hand.csv",#4
          "../Add_fft_features_data/AfterFft_40_Hand.csv",#5
          "../Add_fft_features_data/AfterFft_陀螺儀_36_Hand.csv",#6
          "../Add_fft_features_data/AfterFft_陀螺儀_38_Hand.csv",#7
          "../Add_fft_features_data/AfterFft_陀螺儀_40_Hand.csv",#8
          "../Add_fft_features_data/AfterFft_陀螺儀_36_Foot.csv",#9
          "../Add_fft_features_data/AfterFft_陀螺儀_38_Foot.csv",#10
          "../Add_fft_features_data/AfterFft_陀螺儀_40_Foot.csv",#11
           "../Add_fft_features_data/AfterFft_fft_all_36_Hand.csv",#12
          "../Add_fft_features_data/AfterFft_fft_all_38_Hand.csv",#13
          "../Add_fft_features_data/AfterFft_fft_all_40_Hand.csv",#14
          "../Add_fft_features_data/AfterFft_fft_all_36_Foot.csv",#15
          "../Add_fft_features_data/AfterFft_fft_all_38_Foot.csv",#16
           "../Add_fft_features_data/AfterFft_fft_all_40_Foot.csv",#17
           "../Add_fft_features_data/AfterFft_fft_arctan_36_Hand.csv",#18
          "../Add_fft_features_data/AfterFft_fft_arctan_38_Hand.csv",#19
          "../Add_fft_features_data/AfterFft_fft_arctan_40_Hand.csv",#20
          "../../../Add_fft_features_data/AfterFft_fft_arctan_36_Foot.csv",#21
          "../../../Add_fft_features_data/AfterFft_fft_arctan_38_Foot.csv",#22
           "../../../Add_fft_features_data/AfterFft_fft_arctan_40_Foot.csv",#23
           "../Add_fft_features_data/AfterFft_fft_sqrt_arctan_36_Hand.csv",#24
          "../Add_fft_features_data/AfterFft_fft_sqrt_arctan_38_Hand.csv",#25
          "../Add_fft_features_data/AfterFft_fft_sqrt_arctan_40_Hand.csv",#26
          "../../../Add_fft_features_data/AfterFft_fft_sqrt_arctan_36_Foot.csv",#27
          "../../../Add_fft_features_data/AfterFft_fft_sqrt_arctan_38_Foot.csv",#28
           "../../../Add_fft_features_data/AfterFft_fft_sqrt_arctan_40_Foot.csv",#29
          "./腳_fft"+".csv"#30
          ]
num = 1
num2 = 1

# add_arctan
def add_arctan(data):
    data = np.array(pd.read_csv(data))
    add = []
    global num2
    global parameter
    if num2 == 1:
        fs_start = 8
        parameter = len(data[:,1])
        f, t, fft_gx = signal.stft(data[:,1],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f1, t1, fft_gy = signal.stft(data[:,2],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f2, t2, fft_gz = signal.stft(data[:,3],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f3, t3, fft_ax = signal.stft(data[:,7],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f4, t4, fft_ay = signal.stft(data[:,8],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f5, t5, fft_az = signal.stft(data[:,9],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        for i in range(len(data[:,1])-17):
            add.append([])
    else :
        fs_start = 0
        data1 = np.array(pd.read_csv(dataFft[30]))
        parameter = len(data1[:,1])   
#         print(parameter)
        f, t, fft_gx = signal.stft(data[parameter-17:,1],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f1, t1, fft_gy = signal.stft(data[parameter-17:,2],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f2, t2, fft_gz = signal.stft(data[parameter-17:,3],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f3, t3, fft_ax = signal.stft(data[parameter-17:,7],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f4, t4, fft_ay = signal.stft(data[parameter-17:,8],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        f5, t5, fft_az = signal.stft(data[parameter-17:,9],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
        for i in range(len(data[:,1])-len(data1[:,1])):
            add.append([])
#         print(len(fft_az[100,:]))#143
#         print(len(data[:,1])-len(data1[:,1]))#126
    

    fs_end = len(data[:,1])-17 + 8 
#     print(fft_az)
    
    
#     data = np.array(pd.read_csv(data))
#     print(fft_gx[100,:])
    #fft_gx
    for i in range (len(fft_gx[100,:])):
        add[i].append(math.atan2((fft_gx[100,i].real),(fft_gx[100,i].imag)))
        add[i].append(math.atan2((fft_gx[600,i].real),(fft_gx[600,i].imag)))
        add[i].append(math.atan2((fft_gx[800,i].real),(fft_gx[800,i].imag)))
        
    #fft_gy
    for i in range (len(fft_gy[100,:])):
        add[i].append(math.atan2((fft_gy[100,i].real),(fft_gy[100,i].imag)))
        add[i].append(math.atan2((fft_gy[600,i].real),(fft_gy[600,i].imag)))
        add[i].append(math.atan2((fft_gy[800,i].real),(fft_gy[800,i].imag)))
    #fft_gz
    for i in range (len(fft_gz[100,:])):
        add[i].append(math.atan2((fft_gz[100,i].real),(fft_gz[100,i].imag)))
        add[i].append(math.atan2((fft_gz[600,i].real),(fft_gz[600,i].imag)))
        add[i].append(math.atan2((fft_gz[800,i].real),(fft_gz[800,i].imag)))
    #fft_ax
    for i in range (len(fft_ax[100,:])):
        add[i].append(math.atan2((fft_ax[100,i].real),(fft_ax[100,i].imag)))
        add[i].append(math.atan2((fft_ax[600,i].real),(fft_ax[600,i].imag)))
        add[i].append(math.atan2((fft_ax[800,i].real),(fft_ax[800,i].imag)))
    #fft_ay
    for i in range (len(fft_ay[100,:])):
        add[i].append(math.atan2((fft_ay[100,i].real),(fft_ay[100,i].imag)))
        add[i].append(math.atan2((fft_ay[600,i].real),(fft_ay[600,i].imag)))
        add[i].append(math.atan2((fft_ay[800,i].real),(fft_ay[800,i].imag)))
    #fft_az
    for i in range (len(fft_az[100,:])):
        add[i].append(math.atan2((fft_az[100,i].real),(fft_az[100,i].imag)))
        add[i].append(math.atan2((fft_az[600,i].real),(fft_az[600,i].imag)))
        add[i].append(math.atan2((fft_az[800,i].real),(fft_az[800,i].imag)))
#     print(np.shape(add))
    add2 = add
    add = np.array(add)
#     print(np.shape(add))#(143,18)
#     add = add.T
    if num2 == 1:
#         pandasData={"Xg":data[:,1],"Yg":data[:,2],"Zg":data[:,3],"Xm":data[:,4],"Ym":data[:,5],"Zm":data[:,6],"Xa":data[:,7],"Ya":data[:,8],"Za":data[:,9],"Xq":data[:,10],"Yq":data[:,11],"Zq":data[:,12],"Direction":data[:,13],"SensorTime":data[:,14],"Time":data[:,15],"Label":data[:,16],"Fft_gx1":data[:,17],"Fft_gx2":data[:,18],"Fft_gx3":data[:,19],"Fft_gy1":data[:,20],"Fft_gy2":data[:,21],"Fft_gy3":data[:,22],"Fft_gz1":data[:,23],"Fft_gz2":data[:,24],"Fft_gz3":data[:,25]}
        pandasData={"Fft_gx":add[:,0],"Fft_gy":add[:,3],"Fft_gz":add[:,6],"Fft_ax":add[:,9],"Fft_ay":add[:,12],"Fft_az":add[:,15]}
#         pandasData={"Fft_gx":add[0],"Fft_gy":add[3],"Fft_gz":add[6],"Fft_ax":add[9],"Fft_ay":add[12],"Fft_az":add[15]}
        df = pd.DataFrame(pandasData)
        df
        df.to_csv("./腳_fft"+".csv")
    else :
        data1 = np.array(pd.read_csv(dataFft[30]))
#         data1 = np.row_stack((data1, add))
#         add2 = add2.T
#         print(add2)
#         print("123")
#         add1 =[add2]
#         print(add1)
#         print("456")
#         add2 = np.array(add2)
#         print(add2)
#         print("789")
#         print(add[:,0])
#         print(add[:,3])
        add_tra1 = np.array([add[:,0]]).T
        add_tra2 = np.array([add[:,3]]).T
        add_tra3 = np.array([add[:,6]]).T
        add_tra4 = np.array([add[:,9]]).T
        add_tra5 = np.array([add[:,12]]).T
        add_tra6 = np.array([add[:,15]]).T
#         temp_arr = []
#         for i in range(len(add)):
#             temp_arr.append([])
#         temp_arr = np.append(temp_arr,add[:,0],axis = 1)
#         temp_arr = np.append(temp_arr,add[:,3],axis = 1)
#         print(temp_arr)
#         temp_arr = np.append(temp_arr,add[:,6],axis = 1)
#         temp_arr = np.append(temp_arr,add[:,9],axis = 1)
#         temp_arr = np.append(temp_arr,add[:,12],axis = 1)
#         temp_arr = np.append(temp_arr,add[:,15],axis = 1)
        temp_arr = np.append(add_tra1,add_tra2,axis = 1)
#         print(temp_arr)
        temp_arr = np.append(temp_arr,add_tra3,axis = 1)
        temp_arr = np.append(temp_arr,add_tra4,axis = 1)
        temp_arr = np.append(temp_arr,add_tra5,axis = 1)
        temp_arr = np.append(temp_arr,add_tra6,axis = 1)
        data1 = np.append(data1[:,1:], temp_arr , axis=0)
        data1 = np.array(data1)
#         pandasData={"Xg":data[:,1],"Yg":data[:,2],"Zg":data[:,3],"Xm":data[:,4],"Ym":data[:,5],"Zm":data[:,6],"Xa":data[:,7],"Ya":data[:,8],"Za":data[:,9],"Xq":data[:,10],"Yq":data[:,11],"Zq":data[:,12],"Direction":data[:,13],"SensorTime":data[:,14],"Time":data[:,15],"Label":data[:,16],"Fft_gx1":data[:,17],"Fft_gx2":data[:,18],"Fft_gx3":data[:,19],"Fft_gy1":data[:,20],"Fft_gy2":data[:,21],"Fft_gy3":data[:,22],"Fft_gz1":data[:,23],"Fft_gz2":data[:,24],"Fft_gz3":data[:,25]}
        pandasData={"Fft_gx":data1[:,0],"Fft_gy":data1[:,1],"Fft_gz":data1[:,2],"Fft_ax":data1[:,3],"Fft_ay":data1[:,4],"Fft_az":data1[:,5]}
        df = pd.DataFrame(pandasData)
        
        df.to_csv("./腳_fft"+".csv")
    num2 =num2 + 1
#     return parameter

        
num1=1
def RF(data,data1,data2):
    global num1
    fft = []
    fft1 = []
    amp = 2 * np.sqrt(2)
    
    # read csv
    # data : labeled ,data1 : real-time data ,data2 :fft_arctan
    data = np.array(pd.read_csv(data))
    data1 = np.array(pd.read_csv(data1))
    data2 = np.array(pd.read_csv(data2))
    
    
    
    data_len = len(data[:,1])
    labelSeries = data[:,16]
    # 加速度 陀螺儀 fft_arctan
    dataSeries = np.append(data[:,1:4], data[:,7:10] , axis=1)
    
#     dataSeries = np.append(dataSeries, data[1:data_len-16,17:23] , axis=1)
    dataSeries = np.append(dataSeries, data[:,17:23] , axis=1)

    if num1 <= 2:
        
        dataSeries1 = np.append(data1[17:,1:4], data1[17:,7:10] , axis=1)
    #     dataSeries1 = np.append(dataSeries1, data1[1:data_len1-16,17:23] , axis=1)
        dataSeries1 = np.append(dataSeries1, data2[:,1:7] , axis=1)
    else: 
        num_fft = parameter
        dataSeries1 = np.append(data1[num_fft:,1:4], data1[num_fft:,7:10] , axis=1)
    #     dataSeries1 = np.append(dataSeries1, data1[1:data_len1-16,17:23] , axis=1)
        dataSeries1 = np.append(dataSeries1, data2[num_fft:,1:7] , axis=1)
    dataSeries = np.array(dataSeries)
    dataSeries1 = np.array(dataSeries1)
#     print(dataSeries1)
#     print(dataSeries)
    num1 = num1 + 1
#     for i in range(data_len-17):
#         fft.append([])
#     for i in range(data_len1-17):
#         fft1.append([])
#     f, t, Zxx = signal.stft(data[:,3],fs=1,noverlap=17,nperseg=18,nfft=1000,return_onesided= False,padded=True,detrend=False,boundary=None)
#     f1, t1, Zxx1 = signal.stft(data1[:,3],fs=1,noverlap=17,nperseg=18,nfft=1000,return_onesided= False,padded=True,detrend=False,boundary=None)
#     for i in range (len(Zxx[100,:])):
#         fft[i].append(Zxx[100,i].real)
#         fft[i].append(Zxx[600,i].real)
#         fft[i].append(Zxx[800,i].real)
#         #add[i].append((Zxx[100,i].conjugate()*Zxx[100,i]).real)
#         #add[i].append((Zxx[600,i].conjugate()*Zxx[600,i]).real)
#         #add[i].append((Zxx[800,i].conjugate()*Zxx[800,i]).real)
#     for i in range (len(Zxx1[100,:])):
#         #add1[i].append((Zxx1[100,i].conjugate()*Zxx1[100,i]).real)
#         #add1[i].append((Zxx1[600,i].conjugate()*Zxx1[600,i]).real)
#         #add1[i].append((Zxx1[800,i].conjugate()*Zxx1[800,i]).real)
#         fft1[i].append(Zxx1[100,i].real)
#         fft1[i].append(Zxx1[600,i].real)
#         fft1[i].append(Zxx1[800,i].real)
#     dataSeries = np.append(dataSeries, fft , axis=1)
#     dataSeries1 = np.append(dataSeries1,fft1, axis=1)
    randomForestModel = RandomForestClassifier(
        random_state=1111,
        oob_score= True,
        n_estimators=100,
        max_depth=3,
        min_samples_split=5,
        min_samples_leaf = 50,
        criterion = 'entropy',
        max_features = 0.2,
        )
    randomForestModel.fit(dataSeries, labelSeries)
    predict = randomForestModel.predict(dataSeries1)
    return predict

def RFF(data,data1):
    
    data = np.array(pd.read_csv(data))
    labelSeries = data[:,16]
    dataSeries = data[:,1:3]+data[:,7:9] #加速度儀和陀螺儀
    #x_train, x_test, y_train, y_test = train_test_split(dataSeries, labelSeries,test_size=0.2, random_state=222)
#     data1 = np.array(pd.read_csv(data1))
    dataSeries1 = data1[:,1:3]+data1[:,7:9] #加速度儀和陀螺儀
    #x_train1, x_test1, y_train1, y_test1 = train_test_split(dataSeries1, labelSeries1,test_size=0.2, random_state=222)

    randomForestModel = RandomForestClassifier(random_state=1,n_estimators=60 , max_depth=1 ,min_samples_split=70)
    # 使用訓練資料訓練模型
    #x_train=x_train.astype('int')
    #y_train=y_train.astype('str')
    #x_test=x_test.astype('int')
    #y_test=y_test.astype('str')
    randomForestModel.fit(dataSeries, labelSeries)
    # 使用訓練資料預測
    predict = randomForestModel.predict(dataSeries1)
#     RF_score = randomForestModel.score(dataSeries1,labelSeries1)
#     print(classification_report(labelSeries1,predict))
    return predict

serialPort = serial.Serial(port='COM3', baudrate=38400, timeout=2, parity=serial.PARITY_EVEN, stopbits=1)#HC-05-1
#serialPort2 = serial.Serial(port='COM70', baudrate=38400, timeout=2, parity=serial.PARITY_EVEN, stopbits=1)#HC-05-2
#115200 esp32

while(1):
    global num
    count = datetime.now().strftime('%Y-%m-%d %H%M%S')
    data0506 = [
            "../All_Data/new_data/手2022-05-06 114900-4.csv",
            "../All_Data/new_data/手2022-05-06 113600-4.csv",
            "../All_Data/new_data/手2022-05-06 115200-2.csv",
            "../All_Data/new_data/腳2022-05-06 120000-4.csv",
            "../All_Data/new_data/腳2022-05-06 120300-3.csv",
            "../All_Data/new_data/腳2022-05-06 120500-4.csv",
            "../../../Add_fft_features_data/AfterFft_fft_arctan_36_Foot.csv",#21
            "../../../Add_fft_features_data/AfterFft_fft_arctan_38_Foot.csv",#22
            "../../../Add_fft_features_data/AfterFft_fft_arctan_40_Foot.csv",#23
            "./腳_"+".csv",
            "./腳_fft"+".csv"]#10
    
    print("hello")
    #/dev/cu.name
    size = 1024
    xg,yg,zg,mx,my,mz,xa,ya,za,xq,yq,zq,direc,mytime =[],[],[],[],[],[],[],[],[],[],[],[],[],[]
    #xg2,yg2,zg2,mx2,my2,mz2,xa2,ya2,za2,xq2,yq2,zq2,direc2,mytime2 =[],[],[],[],[],[],[],[],[],[],[],[],[],[]
    Ttime=str(datetime.now())
    print(Ttime)
    print(Ttime[17::])
    tt=0
    TT=5
    while(tt<=TT):
        data = serialPort.readline().decode('utf-8', 'ignore')
    #     data2 = serialPort2.readline().decode('utf-8')
#         print(data)
    #     print(data2)
        data=data.split(',')
        print(data)
    #     tempData = data
    #     tempData = pd.DataFrame(tempData)
    #     print(len(tempData))
#         if len(data)==16:
#             print("Hello")
#             print("Hand:",RFF(data0506[0],data))

    #     data2=data2.split(',')
    #     print(len(data),len(data2))
    #     print(float(str(datetime.now())[17::]))
        if (float(str(datetime.now())[17::])< float(Ttime[17::])):      
            tt = float(Ttime[17::])+60-float(str(datetime.now())[17::] )
            if tt>=TT:
                break
        else:
            tt = -float(Ttime[17::])+float(str(datetime.now())[17::] )
            if tt>=TT:
                break
        if len(data)==16:
            xg.append(data[1])
            yg.append(data[2])
            zg.append(data[3])
            mx.append(data[4])
            my.append(data[5])
            mz.append(data[6])
            xa.append(data[7])
            ya.append(data[8])
            za.append(data[9])
            xq.append(data[10])
            yq.append(data[11])
            zq.append(data[12])
            direc.append(data[13])
            mytime.append(data[14])
    #         pandasData1={"Xg":data[1],"Yg":data[2],"Zg":data[3],"Xm":data[4],"Ym":data[5],"Zm":data[6],"Xa":data[7],"Ya":data[8],"Za":data[9],"Xq":data[10],"Yq":data[11],"Zq":data[12],"Direction":data[13],"Time":data[14]}
    #         df1 = pd.DataFrame(pandasData1)
    #         df1.to_csv('腳_2'+'.csv')
    #         print("Hand:",RF(data0506[3],data0506[6]))
    #     if len(data2)==16:
    #         xg2.append(data2[1])
    #         yg2.append(data2[2])
    #         zg2.append(data2[3])
    #         mx2.append(data2[4])
    #         my2.append(data2[5])
    #         mz2.append(data2[6])
    #         xa2.append(data2[7])
    #         ya2.append(data2[8])
    #         za2.append(data2[9])
    #         xq2.append(data2[10])
    #         yq2.append(data2[11])
    #         zq2.append(data2[12])
    #         direc2.append(data2[13])
    #         mytime2.append(data2[14])
    if num == 1:
        
        pandasData={"Xg":xg,"Yg":yg,"Zg":zg,"Xm":mx,"Ym":my,"Zm":mz,"Xa":xa,"Ya":ya,"Za":za,"Xq":xq,"Yq":yq,"Zq":zq,"Direction":direc,"Time":mytime}
        # pandasData1={xg,yg,zg,mx,my,mz,xa,ya,za,xq,yq,zq,direc,mytime}
        # pandasData2={"Xg":xg2,"Yg":yg2,"Zg":zg2,"Xm":mx2,"Ym":my2,"Zm":mz2,"Xa":xa2,"Ya":ya2,"Za":za2,"Xq":xq2,"Yq":yq2,"Zq":zq2,"Direction":direc2,"Time":mytime2}
        df = pd.DataFrame(pandasData)
        #df2= pd.DataFrame(pandasData2)
        print(df)
        #print(df2)
        transform_fftArctan = 0
        df.to_csv('腳_'+'.csv')
    else:
        data1 = np.array(pd.read_csv(data0506[9]))
        xg = [xg]
        yg = [yg]
        zg = [zg]
        mx = [mx]
        my = [my]
        mz = [mz]
        xa = [xa]
        ya = [ya]
        za = [za]
        xq = [xq]
        yq = [yq]
        zq = [zq]
        direc = [direc]
        mytime = [mytime]
        
        temp1 = np.append(xg,yg,axis=0)
        temp1 = np.append(temp1,zg,axis=0)
        temp1 = np.append(temp1,mx,axis=0)
        temp1 = np.append(temp1,my,axis=0)
        temp1 = np.append(temp1,mz,axis=0)
        temp1 = np.append(temp1,xa,axis=0)
        temp1 = np.append(temp1,ya,axis=0)
        temp1 = np.append(temp1,za,axis=0)
        temp1 = np.append(temp1,xq,axis=0)
        temp1 = np.append(temp1,yq,axis=0)
        temp1 = np.append(temp1,zq,axis=0)
        temp1 = np.append(temp1,direc,axis=0)
        temp1 = np.append(temp1,mytime,axis=0).T
        
#         print(temp1)
        data1 = np.append(data1[:,1:15], temp1[:,0:14] , axis=0)
#         data1 = np.row_stack((data1[:,1:15], data[:,1:15] ))
#         pandasData={"Xg":data1[:,1],"Yg":data1[:,2],"Zg":data1[:,3],"Xm":data1[:,4],"Ym":data1[:,5],"Zm":data1[:,6],"Xa":data1[:,7],"Ya":data1[:,8],"Za":data1[:,9],"Xq":data1[:,10],"Yq":data1[:,11],"Zq":data1[:,12],"Direction":data1[:,13],"SensorTime":data1[:,14]}
        pandasData={"Xg":data1[:,0],"Yg":data1[:,1],"Zg":data1[:,2],"Xm":data1[:,3],"Ym":data1[:,4],"Zm":data1[:,5],"Xa":data1[:,6],"Ya":data1[:,7],"Za":data1[:,8],"Xq":data1[:,9],"Yq":data1[:,10],"Zq":data1[:,11],"Direction":data1[:,12],"SensorTime":data1[:,13]}
#         pandasData={"Fft_gx":data1[:,1],"Fft_gy":data1[:,2],"Fft_gz":data1[:,3],"Fft_ax":data1[:,4],"Fft_ay":data1[:,5],"Fft_az":data1[:,6]}
        df = pd.DataFrame(pandasData)
        df.to_csv("腳_"+".csv")
        
    num = num + 1
    #df2.to_csv('手'+datetime.now().strftime('%Y-%m-%d %H%M%S')+'.csv')
    print("--------------------------------\nRandomForest\n-------------------------------")
    #for i in range(len(data0506)//2):
    add_arctan(data0506[9])
    for i in range(1):
        print("Hand:",RF(data0506[6],data0506[9],data0506[10]))
        print("")
        dff = pd.DataFrame(RF(data0506[6],data0506[9],data0506[10]))
    #     print("Foot:",RF(data0506[i+2],data0506[i+3]))
    #     print("________________________________________________________")
    dff.to_csv('label_'+count+'.csv')
    
serialPort.close()
#serialPort2.close()
# Out:
# hello
# 2022-08-04 21:50:02.532925
# 02.532925
# ,-0.02,-0.02,-0.09,15.81,-53.63,6.94,2.85,9.29,-2.79,0.04,0.81,0.58,0.06,8369,
#
# ,-0.02,-0.03,-0.04,15.81,-53.63,6.94,2.85,9.29,-2.79,0.04,0.81,0.58,0.06,8408,
#
# ,-0.02,-0.03,-0.04,15.81,-53.63,6.94,2.73,9.29,-2.41,0.04,0.81,0.58,0.06,8446,
#
# ,-0.02,-0.03,-0.04,15.81,-53.63,6.94,2.66,9.32,-2.41,0.04,0.81,0.58,0.06,8484,
#
# ,-0.13,-0.09,-0.07,15.81,-53.63,6.94,2.66,9.32,-2.41,0.04,0.81,0.58,0.06,8524,
#
# ,-0.13,-0.10,-0.12,15.81,-53.63,6.94,2.66,9.32,-2.41,0.04,0.81,0.58,0.06,8564,
#
# ,-0.13,-0.10,-0.12,15.81,-53.63,6.94,2.62,9.36,-2.33,0.04,0.81,0.58,0.06,8602,
#
# ,-0.13,-0.10,-0.12,15.81,-53.63,6.94,2.58,9.36,-2.29,0.04,0.81,0.58,0.06,8640,
#
# ,-0.13,-0.10,-0.12,15.81,-53.63,6.94,2.47,9.48,-2.02,0.04,0.81,0.58,0.06,8678,
#
# ,-0.13,-0.06,-0.22,15.81,-53.63,6.94,2.47,9.48,-2.02,0.04,0.81,0.58,0.06,8718,
#
# ,-0.16,0.03,-0.25,15.81,-53.63,6.94,2.47,9.48,-2.02,0.04,0.81,0.58,0.06,8756,
#
# ,-0.16,0.03,-0.25,15.81,-53.63,6.94,2.05,9.63,-1.83,0.04,0.81,0.58,0.06,8795,
#
# ,-0.16,0.03,-0.25,15.81,-53.63,6.94,2.28,9.52,-2.06,0.04,0.81,0.58,0.06,8832,
#
# ,-0.07,0.19,-0.24,15.81,-53.63,6.94,2.28,9.52,-2.06,0.04,0.81,0.58,0.06,8870,
#
# ,-0.54,-0.41,-0.38,15.81,-53.63,6.94,2.28,9.52,-2.06,0.04,0.81,0.58,0.06,8909,
#
# ,-0.54,-0.41,-0.38,15.81,-53.63,6.94,2.16,9.52,-2.37,0.04,0.81,0.58,0.06,8947,
#
# ,-0.54,-0.41,-0.38,15.81,-53.63,6.94,1.74,9.79,-1.83,0.04,0.81,0.58,0.06,8985,
#
# ,-0.64,-0.35,-0.54,15.81,-53.63,6.94,1.74,9.79,-1.83,0.04,0.81,0.58,0.06,9025,
#
# ,-0.67,-0.23,-0.68,15.81,-53.63,6.94,1.74,9.79,-1.83,0.04,0.81,0.58,0.06,9065,
#
# ,-0.67,-0.23,-0.68,15.81,-53.63,6.94,1.43,10.82,-1.30,0.04,0.81,0.58,0.06,9104,
#
# ,-0.67,-0.23,-0.68,15.81,-53.63,6.94,2.20,10.24,-1.91,0.04,0.81,0.58,0.06,9144,
#
# ,-0.67,-0.23,-0.68,15.81,-53.63,6.94,2.05,11.24,-0.45,0.04,0.81,0.58,0.06,9182,
#
# ,-1.21,-4.29,0.49,15.81,-53.63,6.94,2.05,11.24,-0.45,0.04,0.81,0.58,0.06,9221,
#
# ,0.67,2.62,1.02,15.81,-53.63,6.94,2.05,11.24,-0.45,0.04,0.81,0.58,0.06,9260,
#
# ,0.67,2.62,1.02,15.81,-53.63,6.94,-1.17,10.59,1.27,0.04,0.81,0.58,0.06,9297,
#
# ,0.67,2.62,1.02,15.81,-53.63,6.94,-2.63,9.63,3.53,0.04,0.81,0.58,0.06,9334,
#
# ,-0.95,-0.63,1.00,15.81,-53.63,6.94,-2.63,9.63,3.53,0.04,0.81,0.58,0.06,9373,
#
# ,-0.41,-2.47,0.74,15.81,-53.63,6.94,-2.63,9.63,3.53,0.04,0.81,0.58,0.06,9412,
#
# ,-0.41,-2.47,0.74,15.81,-53.63,6.94,1.66,10.86,-0.03,0.04,0.81,0.58,0.06,9450,
#
# ,-0.41,-2.47,0.74,15.81,-53.63,6.94,1.43,10.28,2.92,0.04,0.81,0.58,0.06,9489,
#
# ,-0.41,-2.47,0.74,9.00,-52.38,-9.56,1.43,10.28,2.92,0.04,0.81,0.58,0.06,9527,
#
# ,-0.47,-0.95,0.61,9.00,-52.38,-9.56,1.43,10.28,2.92,0.04,0.81,0.58,0.06,9566,
#
# ,-0.47,-0.95,0.61,9.00,-52.38,-9.56,3.16,9.29,1.04,0.04,0.81,0.58,0.06,9605,
#
# ,-0.47,-0.95,0.61,9.00,-52.38,-9.56,2.24,9.05,1.39,0.04,0.81,0.58,0.06,9645,
#
# ,-0.47,-0.95,0.61,9.00,-52.38,-9.56,1.59,8.18,0.85,0.04,0.81,0.58,0.06,9681,
#
# ,0.10,-0.60,0.13,9.00,-52.38,-9.56,1.59,8.18,0.85,0.04,0.81,0.58,0.06,9719,
#
# ,0.47,-0.38,-0.13,9.00,-52.38,-9.56,1.59,8.18,0.85,0.04,0.81,0.58,0.06,9757,
#
# ,0.47,-0.38,-0.13,9.00,-52.38,-9.56,2.47,8.71,1.00,0.04,0.81,0.58,0.06,9796,
#
# ,0.47,-0.38,-0.13,9.00,-52.38,-9.56,2.39,8.90,1.27,0.04,0.81,0.58,0.06,9833,
#
# ,0.65,-0.37,-0.46,9.00,-52.38,-9.56,2.39,8.90,1.27,0.04,0.81,0.58,0.06,9871,
#
# ,0.73,-0.27,-0.60,9.00,-52.38,-9.56,2.39,8.90,1.27,0.04,0.81,0.58,0.06,9909,
#
# ,0.73,-0.27,-0.60,9.00,-52.38,-9.56,4.11,9.40,-0.03,0.04,0.81,0.58,0.06,9948,
#
# ,0.73,-0.27,-0.60,9.00,-52.38,-9.56,3.89,9.63,-0.15,0.04,0.81,0.58,0.06,9985,
#
# ,1.01,0.45,-0.51,9.00,-52.38,-9.56,3.89,9.63,-0.15,0.04,0.81,0.58,0.06,10024,
#
# ,1.18,1.34,-0.72,9.00,-52.38,-9.56,3.89,9.63,-0.15,0.04,0.81,0.58,0.06,10063,
#
# ,1.18,1.34,-0.72,9.00,-52.38,-9.56,6.41,13.54,3.72,0.04,0.81,0.58,0.06,10102,
#
# ,1.18,1.34,-0.72,9.00,-52.38,-9.56,6.41,13.54,3.72,0.04,0.81,0.58,0.06,10398,
#
# ,1.18,1.34,-0.72,9.00,-52.38,-9.56,6.41,13.54,3.72,0.04,0.81,0.58,0.06,12236,
#
#
#        Xg     Yg     Zg     Xm      Ym     Zm     Xa     Ya     Za    Xq  \
# 0   -0.02  -0.02  -0.09  15.81  -53.63   6.94   2.85   9.29  -2.79  0.04
# 1   -0.02  -0.03  -0.04  15.81  -53.63   6.94   2.85   9.29  -2.79  0.04
# 2   -0.02  -0.03  -0.04  15.81  -53.63   6.94   2.73   9.29  -2.41  0.04
# 3   -0.02  -0.03  -0.04  15.81  -53.63   6.94   2.66   9.32  -2.41  0.04
# 4   -0.13  -0.09  -0.07  15.81  -53.63   6.94   2.66   9.32  -2.41  0.04
# 5   -0.13  -0.10  -0.12  15.81  -53.63   6.94   2.66   9.32  -2.41  0.04
# 6   -0.13  -0.10  -0.12  15.81  -53.63   6.94   2.62   9.36  -2.33  0.04
# 7   -0.13  -0.10  -0.12  15.81  -53.63   6.94   2.58   9.36  -2.29  0.04
# 8   -0.13  -0.10  -0.12  15.81  -53.63   6.94   2.47   9.48  -2.02  0.04
# 9   -0.13  -0.06  -0.22  15.81  -53.63   6.94   2.47   9.48  -2.02  0.04
# 10  -0.16   0.03  -0.25  15.81  -53.63   6.94   2.47   9.48  -2.02  0.04
# 11  -0.16   0.03  -0.25  15.81  -53.63   6.94   2.05   9.63  -1.83  0.04
# 12  -0.16   0.03  -0.25  15.81  -53.63   6.94   2.28   9.52  -2.06  0.04
# 13  -0.07   0.19  -0.24  15.81  -53.63   6.94   2.28   9.52  -2.06  0.04
# 14  -0.54  -0.41  -0.38  15.81  -53.63   6.94   2.28   9.52  -2.06  0.04
# 15  -0.54  -0.41  -0.38  15.81  -53.63   6.94   2.16   9.52  -2.37  0.04
# 16  -0.54  -0.41  -0.38  15.81  -53.63   6.94   1.74   9.79  -1.83  0.04
# 17  -0.64  -0.35  -0.54  15.81  -53.63   6.94   1.74   9.79  -1.83  0.04
# 18  -0.67  -0.23  -0.68  15.81  -53.63   6.94   1.74   9.79  -1.83  0.04
# 19  -0.67  -0.23  -0.68  15.81  -53.63   6.94   1.43  10.82  -1.30  0.04
# 20  -0.67  -0.23  -0.68  15.81  -53.63   6.94   2.20  10.24  -1.91  0.04
# 21  -0.67  -0.23  -0.68  15.81  -53.63   6.94   2.05  11.24  -0.45  0.04
# 22  -1.21  -4.29   0.49  15.81  -53.63   6.94   2.05  11.24  -0.45  0.04
# 23   0.67   2.62   1.02  15.81  -53.63   6.94   2.05  11.24  -0.45  0.04
# 24   0.67   2.62   1.02  15.81  -53.63   6.94  -1.17  10.59   1.27  0.04
# 25   0.67   2.62   1.02  15.81  -53.63   6.94  -2.63   9.63   3.53  0.04
# 26  -0.95  -0.63   1.00  15.81  -53.63   6.94  -2.63   9.63   3.53  0.04
# 27  -0.41  -2.47   0.74  15.81  -53.63   6.94  -2.63   9.63   3.53  0.04
# 28  -0.41  -2.47   0.74  15.81  -53.63   6.94   1.66  10.86  -0.03  0.04
# 29  -0.41  -2.47   0.74  15.81  -53.63   6.94   1.43  10.28   2.92  0.04
# 30  -0.41  -2.47   0.74   9.00  -52.38  -9.56   1.43  10.28   2.92  0.04
# 31  -0.47  -0.95   0.61   9.00  -52.38  -9.56   1.43  10.28   2.92  0.04
# 32  -0.47  -0.95   0.61   9.00  -52.38  -9.56   3.16   9.29   1.04  0.04
# 33  -0.47  -0.95   0.61   9.00  -52.38  -9.56   2.24   9.05   1.39  0.04
# 34  -0.47  -0.95   0.61   9.00  -52.38  -9.56   1.59   8.18   0.85  0.04
# 35   0.10  -0.60   0.13   9.00  -52.38  -9.56   1.59   8.18   0.85  0.04
# 36   0.47  -0.38  -0.13   9.00  -52.38  -9.56   1.59   8.18   0.85  0.04
# 37   0.47  -0.38  -0.13   9.00  -52.38  -9.56   2.47   8.71   1.00  0.04
# 38   0.47  -0.38  -0.13   9.00  -52.38  -9.56   2.39   8.90   1.27  0.04
# 39   0.65  -0.37  -0.46   9.00  -52.38  -9.56   2.39   8.90   1.27  0.04
# 40   0.73  -0.27  -0.60   9.00  -52.38  -9.56   2.39   8.90   1.27  0.04
# 41   0.73  -0.27  -0.60   9.00  -52.38  -9.56   4.11   9.40  -0.03  0.04
# 42   0.73  -0.27  -0.60   9.00  -52.38  -9.56   3.89   9.63  -0.15  0.04
# 43   1.01   0.45  -0.51   9.00  -52.38  -9.56   3.89   9.63  -0.15  0.04
# 44   1.18   1.34  -0.72   9.00  -52.38  -9.56   3.89   9.63  -0.15  0.04
# 45   1.18   1.34  -0.72   9.00  -52.38  -9.56   6.41  13.54   3.72  0.04
# 46   1.18   1.34  -0.72   9.00  -52.38  -9.56   6.41  13.54   3.72  0.04
# 47   1.18   1.34  -0.72   9.00  -52.38  -9.56   6.41  13.54   3.72  0.04
#
#       Yq    Zq Direction   Time
# 0   0.81  0.58      0.06   8369
# 1   0.81  0.58      0.06   8408
# 2   0.81  0.58      0.06   8446
# 3   0.81  0.58      0.06   8484
# 4   0.81  0.58      0.06   8524
# 5   0.81  0.58      0.06   8564
# 6   0.81  0.58      0.06   8602
# 7   0.81  0.58      0.06   8640
# 8   0.81  0.58      0.06   8678
# 9   0.81  0.58      0.06   8718
# 10  0.81  0.58      0.06   8756
# 11  0.81  0.58      0.06   8795
# 12  0.81  0.58      0.06   8832
# 13  0.81  0.58      0.06   8870
# 14  0.81  0.58      0.06   8909
# 15  0.81  0.58      0.06   8947
# 16  0.81  0.58      0.06   8985
# 17  0.81  0.58      0.06   9025
# 18  0.81  0.58      0.06   9065
# 19  0.81  0.58      0.06   9104
# 20  0.81  0.58      0.06   9144
# 21  0.81  0.58      0.06   9182
# 22  0.81  0.58      0.06   9221
# 23  0.81  0.58      0.06   9260
# 24  0.81  0.58      0.06   9297
# 25  0.81  0.58      0.06   9334
# 26  0.81  0.58      0.06   9373
# 27  0.81  0.58      0.06   9412
# 28  0.81  0.58      0.06   9450
# 29  0.81  0.58      0.06   9489
# 30  0.81  0.58      0.06   9527
# 31  0.81  0.58      0.06   9566
# 32  0.81  0.58      0.06   9605
# 33  0.81  0.58      0.06   9645
# 34  0.81  0.58      0.06   9681
# 35  0.81  0.58      0.06   9719
# 36  0.81  0.58      0.06   9757
# 37  0.81  0.58      0.06   9796
# 38  0.81  0.58      0.06   9833
# 39  0.81  0.58      0.06   9871
# 40  0.81  0.58      0.06   9909
# 41  0.81  0.58      0.06   9948
# 42  0.81  0.58      0.06   9985
# 43  0.81  0.58      0.06  10024
# 44  0.81  0.58      0.06  10063
# 45  0.81  0.58      0.06  10102
# 46  0.81  0.58      0.06  10398
# 47  0.81  0.58      0.06  12236
# --------------------------------
# RandomForest
# -------------------------------
# (31, 18)
# [[-6.40000000e-01 -3.50000000e-01 -5.40000000e-01  1.74000000e+00
#    9.79000000e+00 -1.83000000e+00 -2.46945856e+00  8.01203781e-01
#   -2.67844634e+00 -5.32597156e-01 -3.28994353e-01  2.58733764e+00]
#  [-6.70000000e-01 -2.30000000e-01 -6.80000000e-01  1.74000000e+00
#    9.79000000e+00 -1.83000000e+00 -1.82661102e+00 -1.34142865e-01
#   -2.72893947e+00 -5.28412515e-01 -3.34314879e-01  2.68443784e+00]
#  [-6.70000000e-01 -2.30000000e-01 -6.80000000e-01  1.43000000e+00
#    1.08200000e+01 -1.30000000e+00 -1.84141210e+00 -8.90267230e-01
#   -2.72692495e+00 -5.21487014e-01 -3.39116940e-01  2.78659419e+00]
#  [-6.70000000e-01 -2.30000000e-01 -6.80000000e-01  2.20000000e+00
#    1.02400000e+01 -1.91000000e+00 -2.01400921e+00 -1.47490850e+00
#   -2.65929902e+00 -5.33526586e-01 -3.39299054e-01  2.83133727e+00]
#  [-6.70000000e-01 -2.30000000e-01 -6.80000000e-01  2.05000000e+00
#    1.12400000e+01 -4.50000000e-01 -2.23014350e+00 -1.96697504e+00
#   -2.56898676e+00 -5.76524189e-01 -3.30591390e-01  2.80864270e+00]
#  [-1.21000000e+00 -4.29000000e+00  4.90000000e-01  2.05000000e+00
#    1.12400000e+01 -4.50000000e-01 -2.45501619e+00 -2.36852992e+00
#   -2.54249657e+00 -6.39644331e-01 -3.10811712e-01  2.74023655e+00]
#  [ 6.70000000e-01  2.62000000e+00  1.02000000e+00  2.05000000e+00
#    1.12400000e+01 -4.50000000e-01 -2.66559978e+00 -2.59829753e+00
#   -2.65584926e+00 -6.95174306e-01 -2.79920453e-01  2.64107857e+00]
#  [ 6.70000000e-01  2.62000000e+00  1.02000000e+00 -1.17000000e+00
#    1.05900000e+01  1.27000000e+00 -2.86851179e+00 -2.59065944e+00
#   -2.90122167e+00 -6.76704078e-01 -2.41690461e-01  2.52511855e+00]
#  [ 6.70000000e-01  2.62000000e+00  1.02000000e+00 -2.63000000e+00
#    9.63000000e+00  3.53000000e+00 -3.08978791e+00 -2.66183194e+00
#    3.05211844e+00 -5.13460777e-01 -2.05197109e-01  2.41071379e+00]
#  [-9.50000000e-01 -6.30000000e-01  1.00000000e+00 -2.63000000e+00
#    9.63000000e+00  3.53000000e+00  2.92150958e+00 -2.99130809e+00
#    2.67730685e+00 -3.61263396e-01 -1.85225589e-01  2.29925666e+00]
#  [-4.10000000e-01 -2.47000000e+00  7.40000000e-01 -2.63000000e+00
#    9.63000000e+00  3.53000000e+00  2.59123962e+00  2.82433868e+00
#    2.28018267e+00 -4.17031764e-01 -1.94813406e-01  2.16544372e+00]
#  [-4.10000000e-01 -2.47000000e+00  7.40000000e-01  1.66000000e+00
#    1.08600000e+01 -3.00000000e-02  2.21024190e+00  2.27303835e+00
#    1.87317859e+00 -6.49971863e-01 -2.37598783e-01  1.97097053e+00]
#  [-4.10000000e-01 -2.47000000e+00  7.40000000e-01  1.43000000e+00
#    1.02800000e+01  2.92000000e+00  1.78034167e+00  1.64452119e+00
#    1.46503054e+00 -9.92434461e-01 -3.05419485e-01  1.70783446e+00]
#  [-4.10000000e-01 -2.47000000e+00  7.40000000e-01  1.43000000e+00
#    1.02800000e+01  2.92000000e+00  1.29161858e+00  9.43857244e-01
#    1.06234477e+00 -1.40679231e+00 -3.82037684e-01  1.39964948e+00]
#  [-4.70000000e-01 -9.50000000e-01  6.10000000e-01  1.43000000e+00
#    1.02800000e+01  2.92000000e+00  7.14581337e-01  2.11440744e-01
#    6.70565186e-01 -1.87997717e+00 -4.47846993e-01  1.06859956e+00]
#  [-4.70000000e-01 -9.50000000e-01  6.10000000e-01  3.16000000e+00
#    9.29000000e+00  1.04000000e+00  5.09393398e-03 -4.93122062e-01
#    2.95877600e-01 -2.41060201e+00 -4.81552544e-01  7.30910698e-01]
#  [-4.70000000e-01 -9.50000000e-01  6.10000000e-01  2.24000000e+00
#    9.05000000e+00  1.39000000e+00 -8.16350894e-01 -1.13754220e+00
#   -5.30752748e-02 -2.99323925e+00 -4.67904940e-01  3.98805417e-01]
#  [-4.70000000e-01 -9.50000000e-01  6.10000000e-01  1.59000000e+00
#    8.18000000e+00  8.50000000e-01 -1.58713071e+00 -1.72327962e+00
#   -3.64096205e-01  2.67932156e+00 -4.15725883e-01  8.40467834e-02]
#  [ 1.00000000e-01 -6.00000000e-01  1.30000000e-01  1.59000000e+00
#    8.18000000e+00  8.50000000e-01 -2.21025182e+00 -2.26377324e+00
#   -6.13564195e-01  2.07918943e+00 -3.65682072e-01 -2.02095855e-01]
#  [ 4.70000000e-01 -3.80000000e-01 -1.30000000e-01  1.59000000e+00
#    8.18000000e+00  8.50000000e-01 -2.71213039e+00 -2.77029614e+00
#   -7.60243869e-01  1.52228798e+00 -3.57268433e-01 -4.49326205e-01]
#  [ 4.70000000e-01 -3.80000000e-01 -1.30000000e-01  2.47000000e+00
#    8.71000000e+00  1.00000000e+00 -3.12594619e+00  3.03538904e+00
#   -7.81572795e-01  1.02377467e+00 -3.98437774e-01 -6.55438825e-01]
#  [ 4.70000000e-01 -3.80000000e-01 -1.30000000e-01  2.39000000e+00
#    8.90000000e+00  1.27000000e+00  2.81276556e+00  2.58889216e+00
#   -7.63034566e-01  5.86682708e-01 -4.72450669e-01 -8.31817621e-01]
#  [ 6.50000000e-01 -3.70000000e-01 -4.60000000e-01  2.39000000e+00
#    8.90000000e+00  1.27000000e+00  2.51847631e+00  2.18535412e+00
#   -8.18907906e-01  2.12612936e-01 -5.53447899e-01 -1.00195937e+00]
#  [ 7.30000000e-01 -2.70000000e-01 -6.00000000e-01  2.39000000e+00
#    8.90000000e+00  1.27000000e+00  2.23444659e+00  1.84070002e+00
#   -9.58831693e-01 -8.87816732e-02 -6.14219191e-01 -1.19101468e+00]
#  [ 7.30000000e-01 -2.70000000e-01 -6.00000000e-01  4.11000000e+00
#    9.40000000e+00 -3.00000000e-02  1.92901391e+00  1.57587814e+00
#   -1.15633116e+00 -3.02023826e-01 -6.27599427e-01 -1.39589296e+00]
#  [ 7.30000000e-01 -2.70000000e-01 -6.00000000e-01  3.89000000e+00
#    9.63000000e+00 -1.50000000e-01  1.60571032e+00  1.42556465e+00
#   -1.38876718e+00 -3.88211079e-01 -5.74566032e-01 -1.56097851e+00]
#  [ 1.01000000e+00  4.50000000e-01 -5.10000000e-01  3.89000000e+00
#    9.63000000e+00 -1.50000000e-01  1.27851783e+00  1.40051005e+00
#   -1.64050562e+00 -2.45154164e-01 -4.63126320e-01 -1.46729779e+00]
#  [ 1.18000000e+00  1.34000000e+00 -7.20000000e-01  3.89000000e+00
#    9.63000000e+00 -1.50000000e-01  9.69594184e-01  1.51258944e+00
#   -1.89987110e+00  1.55856229e-01 -3.39071334e-01 -6.91343086e-01]
#  [ 1.18000000e+00  1.34000000e+00 -7.20000000e-01  6.41000000e+00
#    1.35400000e+01  3.72000000e+00  7.00265289e-01  1.78318603e+00
#   -2.15614380e+00  4.53207002e-01 -2.53784052e-01 -5.19746768e-01]
#  [ 1.18000000e+00  1.34000000e+00 -7.20000000e-01  6.41000000e+00
#    1.35400000e+01  3.72000000e+00  4.92708746e-01  2.02758869e+00
#   -2.39914675e+00  5.32757589e-01 -2.13857637e-01 -8.02193633e-01]
#  [ 1.18000000e+00  1.34000000e+00 -7.20000000e-01  6.41000000e+00
#    1.35400000e+01  3.72000000e+00  3.69389177e-01  2.04276392e+00
#   -2.61873471e+00  5.22466501e-01 -1.85698438e-01 -1.28069786e+00]]
# [[0.39 -0.24 0.31 ... 2.8701729254697432 -1.6383085196066258
#   -1.43108113374788]
#  [0.35 -1.76 3.13 ... 2.8230586741062504 -2.0974099620305666
#   -1.585898795847097]
#  [0.35 -1.76 3.13 ... 2.7163860907285224 -2.52382888595899
#   -1.4251936203829931]
#  ...
#  [2.09 0.14 -0.37 ... 3.111343588737971 1.280273368134874
#   1.0439163489575884]
#  [3.36 1.13 -1.01 ... 3.125610228720183 0.7522979606374693
#   0.5587253367078756]
#  [3.36 1.13 -1.01 ... 3.042443755977623 0.182387345942386
#   0.0950642049152436]]
# Hand: ['W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W']
#
# [[-6.40000000e-01 -3.50000000e-01 -5.40000000e-01  1.74000000e+00
#    9.79000000e+00 -1.83000000e+00 -2.46945856e+00  8.01203781e-01
#   -2.67844634e+00 -5.32597156e-01 -3.28994353e-01  2.58733764e+00]
#  [-6.70000000e-01 -2.30000000e-01 -6.80000000e-01  1.74000000e+00
#    9.79000000e+00 -1.83000000e+00 -1.82661102e+00 -1.34142865e-01
#   -2.72893947e+00 -5.28412515e-01 -3.34314879e-01  2.68443784e+00]
#  [-6.70000000e-01 -2.30000000e-01 -6.80000000e-01  1.43000000e+00
#    1.08200000e+01 -1.30000000e+00 -1.84141210e+00 -8.90267230e-01
#   -2.72692495e+00 -5.21487014e-01 -3.39116940e-01  2.78659419e+00]
#  [-6.70000000e-01 -2.30000000e-01 -6.80000000e-01  2.20000000e+00
#    1.02400000e+01 -1.91000000e+00 -2.01400921e+00 -1.47490850e+00
#   -2.65929902e+00 -5.33526586e-01 -3.39299054e-01  2.83133727e+00]
#  [-6.70000000e-01 -2.30000000e-01 -6.80000000e-01  2.05000000e+00
#    1.12400000e+01 -4.50000000e-01 -2.23014350e+00 -1.96697504e+00
#   -2.56898676e+00 -5.76524189e-01 -3.30591390e-01  2.80864270e+00]
#  [-1.21000000e+00 -4.29000000e+00  4.90000000e-01  2.05000000e+00
#    1.12400000e+01 -4.50000000e-01 -2.45501619e+00 -2.36852992e+00
#   -2.54249657e+00 -6.39644331e-01 -3.10811712e-01  2.74023655e+00]
#  [ 6.70000000e-01  2.62000000e+00  1.02000000e+00  2.05000000e+00
#    1.12400000e+01 -4.50000000e-01 -2.66559978e+00 -2.59829753e+00
#   -2.65584926e+00 -6.95174306e-01 -2.79920453e-01  2.64107857e+00]
#  [ 6.70000000e-01  2.62000000e+00  1.02000000e+00 -1.17000000e+00
#    1.05900000e+01  1.27000000e+00 -2.86851179e+00 -2.59065944e+00
#   -2.90122167e+00 -6.76704078e-01 -2.41690461e-01  2.52511855e+00]
#  [ 6.70000000e-01  2.62000000e+00  1.02000000e+00 -2.63000000e+00
#    9.63000000e+00  3.53000000e+00 -3.08978791e+00 -2.66183194e+00
#    3.05211844e+00 -5.13460777e-01 -2.05197109e-01  2.41071379e+00]
#  [-9.50000000e-01 -6.30000000e-01  1.00000000e+00 -2.63000000e+00
#    9.63000000e+00  3.53000000e+00  2.92150958e+00 -2.99130809e+00
#    2.67730685e+00 -3.61263396e-01 -1.85225589e-01  2.29925666e+00]
#  [-4.10000000e-01 -2.47000000e+00  7.40000000e-01 -2.63000000e+00
#    9.63000000e+00  3.53000000e+00  2.59123962e+00  2.82433868e+00
#    2.28018267e+00 -4.17031764e-01 -1.94813406e-01  2.16544372e+00]
#  [-4.10000000e-01 -2.47000000e+00  7.40000000e-01  1.66000000e+00
#    1.08600000e+01 -3.00000000e-02  2.21024190e+00  2.27303835e+00
#    1.87317859e+00 -6.49971863e-01 -2.37598783e-01  1.97097053e+00]
#  [-4.10000000e-01 -2.47000000e+00  7.40000000e-01  1.43000000e+00
#    1.02800000e+01  2.92000000e+00  1.78034167e+00  1.64452119e+00
#    1.46503054e+00 -9.92434461e-01 -3.05419485e-01  1.70783446e+00]
#  [-4.10000000e-01 -2.47000000e+00  7.40000000e-01  1.43000000e+00
#    1.02800000e+01  2.92000000e+00  1.29161858e+00  9.43857244e-01
#    1.06234477e+00 -1.40679231e+00 -3.82037684e-01  1.39964948e+00]
#  [-4.70000000e-01 -9.50000000e-01  6.10000000e-01  1.43000000e+00
#    1.02800000e+01  2.92000000e+00  7.14581337e-01  2.11440744e-01
#    6.70565186e-01 -1.87997717e+00 -4.47846993e-01  1.06859956e+00]
#  [-4.70000000e-01 -9.50000000e-01  6.10000000e-01  3.16000000e+00
#    9.29000000e+00  1.04000000e+00  5.09393398e-03 -4.93122062e-01
#    2.95877600e-01 -2.41060201e+00 -4.81552544e-01  7.30910698e-01]
#  [-4.70000000e-01 -9.50000000e-01  6.10000000e-01  2.24000000e+00
#    9.05000000e+00  1.39000000e+00 -8.16350894e-01 -1.13754220e+00
#   -5.30752748e-02 -2.99323925e+00 -4.67904940e-01  3.98805417e-01]
#  [-4.70000000e-01 -9.50000000e-01  6.10000000e-01  1.59000000e+00
#    8.18000000e+00  8.50000000e-01 -1.58713071e+00 -1.72327962e+00
#   -3.64096205e-01  2.67932156e+00 -4.15725883e-01  8.40467834e-02]
#  [ 1.00000000e-01 -6.00000000e-01  1.30000000e-01  1.59000000e+00
#    8.18000000e+00  8.50000000e-01 -2.21025182e+00 -2.26377324e+00
#   -6.13564195e-01  2.07918943e+00 -3.65682072e-01 -2.02095855e-01]
#  [ 4.70000000e-01 -3.80000000e-01 -1.30000000e-01  1.59000000e+00
#    8.18000000e+00  8.50000000e-01 -2.71213039e+00 -2.77029614e+00
#   -7.60243869e-01  1.52228798e+00 -3.57268433e-01 -4.49326205e-01]
#  [ 4.70000000e-01 -3.80000000e-01 -1.30000000e-01  2.47000000e+00
#    8.71000000e+00  1.00000000e+00 -3.12594619e+00  3.03538904e+00
#   -7.81572795e-01  1.02377467e+00 -3.98437774e-01 -6.55438825e-01]
#  [ 4.70000000e-01 -3.80000000e-01 -1.30000000e-01  2.39000000e+00
#    8.90000000e+00  1.27000000e+00  2.81276556e+00  2.58889216e+00
#   -7.63034566e-01  5.86682708e-01 -4.72450669e-01 -8.31817621e-01]
#  [ 6.50000000e-01 -3.70000000e-01 -4.60000000e-01  2.39000000e+00
#    8.90000000e+00  1.27000000e+00  2.51847631e+00  2.18535412e+00
#   -8.18907906e-01  2.12612936e-01 -5.53447899e-01 -1.00195937e+00]
#  [ 7.30000000e-01 -2.70000000e-01 -6.00000000e-01  2.39000000e+00
#    8.90000000e+00  1.27000000e+00  2.23444659e+00  1.84070002e+00
#   -9.58831693e-01 -8.87816732e-02 -6.14219191e-01 -1.19101468e+00]
#  [ 7.30000000e-01 -2.70000000e-01 -6.00000000e-01  4.11000000e+00
#    9.40000000e+00 -3.00000000e-02  1.92901391e+00  1.57587814e+00
#   -1.15633116e+00 -3.02023826e-01 -6.27599427e-01 -1.39589296e+00]
#  [ 7.30000000e-01 -2.70000000e-01 -6.00000000e-01  3.89000000e+00
#    9.63000000e+00 -1.50000000e-01  1.60571032e+00  1.42556465e+00
#   -1.38876718e+00 -3.88211079e-01 -5.74566032e-01 -1.56097851e+00]
#  [ 1.01000000e+00  4.50000000e-01 -5.10000000e-01  3.89000000e+00
#    9.63000000e+00 -1.50000000e-01  1.27851783e+00  1.40051005e+00
#   -1.64050562e+00 -2.45154164e-01 -4.63126320e-01 -1.46729779e+00]
#  [ 1.18000000e+00  1.34000000e+00 -7.20000000e-01  3.89000000e+00
#    9.63000000e+00 -1.50000000e-01  9.69594184e-01  1.51258944e+00
#   -1.89987110e+00  1.55856229e-01 -3.39071334e-01 -6.91343086e-01]
#  [ 1.18000000e+00  1.34000000e+00 -7.20000000e-01  6.41000000e+00
#    1.35400000e+01  3.72000000e+00  7.00265289e-01  1.78318603e+00
#   -2.15614380e+00  4.53207002e-01 -2.53784052e-01 -5.19746768e-01]
#  [ 1.18000000e+00  1.34000000e+00 -7.20000000e-01  6.41000000e+00
#    1.35400000e+01  3.72000000e+00  4.92708746e-01  2.02758869e+00
#   -2.39914675e+00  5.32757589e-01 -2.13857637e-01 -8.02193633e-01]
#  [ 1.18000000e+00  1.34000000e+00 -7.20000000e-01  6.41000000e+00
#    1.35400000e+01  3.72000000e+00  3.69389177e-01  2.04276392e+00
#   -2.61873471e+00  5.22466501e-01 -1.85698438e-01 -1.28069786e+00]]
# [[0.39 -0.24 0.31 ... 2.8701729254697432 -1.6383085196066258
#   -1.43108113374788]
#  [0.35 -1.76 3.13 ... 2.8230586741062504 -2.0974099620305666
#   -1.585898795847097]
#  [0.35 -1.76 3.13 ... 2.7163860907285224 -2.52382888595899
#   -1.4251936203829931]
#  ...
#  [2.09 0.14 -0.37 ... 3.111343588737971 1.280273368134874
#   1.0439163489575884]
#  [3.36 1.13 -1.01 ... 3.125610228720183 0.7522979606374693
#   0.5587253367078756]
#  [3.36 1.13 -1.01 ... 3.042443755977623 0.182387345942386
#   0.0950642049152436]]
# hello
# 2022-08-04 21:50:09.716603
# 09.716603
#
#
#
# []
# --------------------------------
# RandomForest
# -------------------------------
# (17, 18)
# [[ 0.71458134  0.21144074]
#  [ 0.00509393 -0.49312206]
#  [-0.81635089 -1.1375422 ]
#  [-1.58713071 -1.72327962]
#  [-2.21025182 -2.26377324]
#  [-2.71213039 -2.77029614]
#  [-3.12594619  3.03538904]
#  [ 2.81276556  2.58889216]
#  [ 2.51847631  2.18535412]
#  [ 2.23444659  1.84070002]
#  [ 1.92901391  1.57587814]
#  [ 1.60571032  1.42556465]
#  [ 1.27851783  1.40051005]
#  [ 0.96959418  1.51258944]
#  [ 0.70026529  1.78318603]
#  [ 0.49270875  2.02758869]
#  [ 0.36938918  2.04276392]]
# [[-4.70000000e-01 -9.50000000e-01  6.10000000e-01  1.43000000e+00
#    1.02800000e+01  2.92000000e+00  7.14581337e-01  2.11440744e-01
#    6.70565186e-01 -1.87997717e+00 -4.47846993e-01  1.06859956e+00]
#  [-4.70000000e-01 -9.50000000e-01  6.10000000e-01  3.16000000e+00
#    9.29000000e+00  1.04000000e+00  5.09393398e-03 -4.93122062e-01
#    2.95877600e-01 -2.41060201e+00 -4.81552544e-01  7.30910698e-01]
#  [-4.70000000e-01 -9.50000000e-01  6.10000000e-01  2.24000000e+00
#    9.05000000e+00  1.39000000e+00 -8.16350894e-01 -1.13754220e+00
#   -5.30752748e-02 -2.99323925e+00 -4.67904940e-01  3.98805417e-01]
#  [-4.70000000e-01 -9.50000000e-01  6.10000000e-01  1.59000000e+00
#    8.18000000e+00  8.50000000e-01 -1.58713071e+00 -1.72327962e+00
#   -3.64096205e-01  2.67932156e+00 -4.15725883e-01  8.40467834e-02]
#  [ 1.00000000e-01 -6.00000000e-01  1.30000000e-01  1.59000000e+00
#    8.18000000e+00  8.50000000e-01 -2.21025182e+00 -2.26377324e+00
#   -6.13564195e-01  2.07918943e+00 -3.65682072e-01 -2.02095855e-01]
#  [ 4.70000000e-01 -3.80000000e-01 -1.30000000e-01  1.59000000e+00
#    8.18000000e+00  8.50000000e-01 -2.71213039e+00 -2.77029614e+00
#   -7.60243869e-01  1.52228798e+00 -3.57268433e-01 -4.49326205e-01]
#  [ 4.70000000e-01 -3.80000000e-01 -1.30000000e-01  2.47000000e+00
#    8.71000000e+00  1.00000000e+00 -3.12594619e+00  3.03538904e+00
#   -7.81572795e-01  1.02377467e+00 -3.98437774e-01 -6.55438825e-01]
#  [ 4.70000000e-01 -3.80000000e-01 -1.30000000e-01  2.39000000e+00
#    8.90000000e+00  1.27000000e+00  2.81276556e+00  2.58889216e+00
#   -7.63034566e-01  5.86682708e-01 -4.72450669e-01 -8.31817621e-01]
#  [ 6.50000000e-01 -3.70000000e-01 -4.60000000e-01  2.39000000e+00
#    8.90000000e+00  1.27000000e+00  2.51847631e+00  2.18535412e+00
#   -8.18907906e-01  2.12612936e-01 -5.53447899e-01 -1.00195937e+00]
#  [ 7.30000000e-01 -2.70000000e-01 -6.00000000e-01  2.39000000e+00
#    8.90000000e+00  1.27000000e+00  2.23444659e+00  1.84070002e+00
#   -9.58831693e-01 -8.87816732e-02 -6.14219191e-01 -1.19101468e+00]
#  [ 7.30000000e-01 -2.70000000e-01 -6.00000000e-01  4.11000000e+00
#    9.40000000e+00 -3.00000000e-02  1.92901391e+00  1.57587814e+00
#   -1.15633116e+00 -3.02023826e-01 -6.27599427e-01 -1.39589296e+00]
#  [ 7.30000000e-01 -2.70000000e-01 -6.00000000e-01  3.89000000e+00
#    9.63000000e+00 -1.50000000e-01  1.60571032e+00  1.42556465e+00
#   -1.38876718e+00 -3.88211079e-01 -5.74566032e-01 -1.56097851e+00]
#  [ 1.01000000e+00  4.50000000e-01 -5.10000000e-01  3.89000000e+00
#    9.63000000e+00 -1.50000000e-01  1.27851783e+00  1.40051005e+00
#   -1.64050562e+00 -2.45154164e-01 -4.63126320e-01 -1.46729779e+00]
#  [ 1.18000000e+00  1.34000000e+00 -7.20000000e-01  3.89000000e+00
#    9.63000000e+00 -1.50000000e-01  9.69594184e-01  1.51258944e+00
#   -1.89987110e+00  1.55856229e-01 -3.39071334e-01 -6.91343086e-01]
#  [ 1.18000000e+00  1.34000000e+00 -7.20000000e-01  6.41000000e+00
#    1.35400000e+01  3.72000000e+00  7.00265289e-01  1.78318603e+00
#   -2.15614380e+00  4.53207002e-01 -2.53784052e-01 -5.19746768e-01]
#  [ 1.18000000e+00  1.34000000e+00 -7.20000000e-01  6.41000000e+00
#    1.35400000e+01  3.72000000e+00  4.92708746e-01  2.02758869e+00
#   -2.39914675e+00  5.32757589e-01 -2.13857637e-01 -8.02193633e-01]
#  [ 1.18000000e+00  1.34000000e+00 -7.20000000e-01  6.41000000e+00
#    1.35400000e+01  3.72000000e+00  3.69389177e-01  2.04276392e+00
#   -2.61873471e+00  5.22466501e-01 -1.85698438e-01 -1.28069786e+00]]
# [[0.39 -0.24 0.31 ... 2.8701729254697432 -1.6383085196066258
#   -1.43108113374788]
#  [0.35 -1.76 3.13 ... 2.8230586741062504 -2.0974099620305666
#   -1.585898795847097]
#  [0.35 -1.76 3.13 ... 2.7163860907285224 -2.52382888595899
#   -1.4251936203829931]
#  ...
#  [2.09 0.14 -0.37 ... 3.111343588737971 1.280273368134874
#   1.0439163489575884]
#  [3.36 1.13 -1.01 ... 3.125610228720183 0.7522979606374693
#   0.5587253367078756]
#  [3.36 1.13 -1.01 ... 3.042443755977623 0.182387345942386
#   0.0950642049152436]]
# Hand: ['W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W']
#
# [[-4.70000000e-01 -9.50000000e-01  6.10000000e-01  1.43000000e+00
#    1.02800000e+01  2.92000000e+00  7.14581337e-01  2.11440744e-01
#    6.70565186e-01 -1.87997717e+00 -4.47846993e-01  1.06859956e+00]
#  [-4.70000000e-01 -9.50000000e-01  6.10000000e-01  3.16000000e+00
#    9.29000000e+00  1.04000000e+00  5.09393398e-03 -4.93122062e-01
#    2.95877600e-01 -2.41060201e+00 -4.81552544e-01  7.30910698e-01]
#  [-4.70000000e-01 -9.50000000e-01  6.10000000e-01  2.24000000e+00
#    9.05000000e+00  1.39000000e+00 -8.16350894e-01 -1.13754220e+00
#   -5.30752748e-02 -2.99323925e+00 -4.67904940e-01  3.98805417e-01]
#  [-4.70000000e-01 -9.50000000e-01  6.10000000e-01  1.59000000e+00
#    8.18000000e+00  8.50000000e-01 -1.58713071e+00 -1.72327962e+00
#   -3.64096205e-01  2.67932156e+00 -4.15725883e-01  8.40467834e-02]
#  [ 1.00000000e-01 -6.00000000e-01  1.30000000e-01  1.59000000e+00
#    8.18000000e+00  8.50000000e-01 -2.21025182e+00 -2.26377324e+00
#   -6.13564195e-01  2.07918943e+00 -3.65682072e-01 -2.02095855e-01]
#  [ 4.70000000e-01 -3.80000000e-01 -1.30000000e-01  1.59000000e+00
#    8.18000000e+00  8.50000000e-01 -2.71213039e+00 -2.77029614e+00
#   -7.60243869e-01  1.52228798e+00 -3.57268433e-01 -4.49326205e-01]
#  [ 4.70000000e-01 -3.80000000e-01 -1.30000000e-01  2.47000000e+00
#    8.71000000e+00  1.00000000e+00 -3.12594619e+00  3.03538904e+00
#   -7.81572795e-01  1.02377467e+00 -3.98437774e-01 -6.55438825e-01]
#  [ 4.70000000e-01 -3.80000000e-01 -1.30000000e-01  2.39000000e+00
#    8.90000000e+00  1.27000000e+00  2.81276556e+00  2.58889216e+00
#   -7.63034566e-01  5.86682708e-01 -4.72450669e-01 -8.31817621e-01]
#  [ 6.50000000e-01 -3.70000000e-01 -4.60000000e-01  2.39000000e+00
#    8.90000000e+00  1.27000000e+00  2.51847631e+00  2.18535412e+00
#   -8.18907906e-01  2.12612936e-01 -5.53447899e-01 -1.00195937e+00]
#  [ 7.30000000e-01 -2.70000000e-01 -6.00000000e-01  2.39000000e+00
#    8.90000000e+00  1.27000000e+00  2.23444659e+00  1.84070002e+00
#   -9.58831693e-01 -8.87816732e-02 -6.14219191e-01 -1.19101468e+00]
#  [ 7.30000000e-01 -2.70000000e-01 -6.00000000e-01  4.11000000e+00
#    9.40000000e+00 -3.00000000e-02  1.92901391e+00  1.57587814e+00
#   -1.15633116e+00 -3.02023826e-01 -6.27599427e-01 -1.39589296e+00]
#  [ 7.30000000e-01 -2.70000000e-01 -6.00000000e-01  3.89000000e+00
#    9.63000000e+00 -1.50000000e-01  1.60571032e+00  1.42556465e+00
#   -1.38876718e+00 -3.88211079e-01 -5.74566032e-01 -1.56097851e+00]
#  [ 1.01000000e+00  4.50000000e-01 -5.10000000e-01  3.89000000e+00
#    9.63000000e+00 -1.50000000e-01  1.27851783e+00  1.40051005e+00
#   -1.64050562e+00 -2.45154164e-01 -4.63126320e-01 -1.46729779e+00]
#  [ 1.18000000e+00  1.34000000e+00 -7.20000000e-01  3.89000000e+00
#    9.63000000e+00 -1.50000000e-01  9.69594184e-01  1.51258944e+00
#   -1.89987110e+00  1.55856229e-01 -3.39071334e-01 -6.91343086e-01]
#  [ 1.18000000e+00  1.34000000e+00 -7.20000000e-01  6.41000000e+00
#    1.35400000e+01  3.72000000e+00  7.00265289e-01  1.78318603e+00
#   -2.15614380e+00  4.53207002e-01 -2.53784052e-01 -5.19746768e-01]
#  [ 1.18000000e+00  1.34000000e+00 -7.20000000e-01  6.41000000e+00
#    1.35400000e+01  3.72000000e+00  4.92708746e-01  2.02758869e+00
#   -2.39914675e+00  5.32757589e-01 -2.13857637e-01 -8.02193633e-01]
#  [ 1.18000000e+00  1.34000000e+00 -7.20000000e-01  6.41000000e+00
#    1.35400000e+01  3.72000000e+00  3.69389177e-01  2.04276392e+00
#   -2.61873471e+00  5.22466501e-01 -1.85698438e-01 -1.28069786e+00]]
# [[0.39 -0.24 0.31 ... 2.8701729254697432 -1.6383085196066258
#   -1.43108113374788]
#  [0.35 -1.76 3.13 ... 2.8230586741062504 -2.0974099620305666
#   -1.585898795847097]
#  [0.35 -1.76 3.13 ... 2.7163860907285224 -2.52382888595899
#   -1.4251936203829931]
#  ...
#  [2.09 0.14 -0.37 ... 3.111343588737971 1.280273368134874
#   1.0439163489575884]
#  [3.36 1.13 -1.01 ... 3.125610228720183 0.7522979606374693
#   0.5587253367078756]
#  [3.36 1.13 -1.01 ... 3.042443755977623 0.182387345942386
#   0.0950642049152436]]
# hello
# 2022-08-04 21:50:16.014227
# 16.014227
#
#
#
# []
# --------------------------------
# RandomForest
# -------------------------------
# C:\Users\ADMIN\anaconda3\lib\site-packages\scipy\signal\spectral.py:1964: UserWarning: nperseg = 18 is greater than input length  = 17, using nperseg = 17
#   warnings.warn('nperseg = {0:d} is greater than input length '
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [1], in <cell line: 388>()
#     524 print("--------------------------------\nRandomForest\n-------------------------------")
#     525 #for i in range(len(data0506)//2):
# --> 526 add_arctan(data0506[9])
#     527 for i in range(1):
#     528     print("Hand:",RF(data0506[6],data0506[9],data0506[10]))
#
# Input In [1], in add_arctan(data)
#     175         parameter = len(data1[:,1])
#     176 #         print(parameter)
# --> 177         f, t, fft_gx = signal.stft(data[parameter-17:,1],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
#     178         f1, t1, fft_gy = signal.stft(data[parameter-17:,2],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
#     179         f2, t2, fft_gz = signal.stft(data[parameter-17:,3],fs=1,noverlap=17,nperseg=18,nfft=1297,return_onesided= False,padded=True,detrend=False,boundary=None)
#
# File ~\anaconda3\lib\site-packages\scipy\signal\spectral.py:1174, in stft(x, fs, window, nperseg, noverlap, nfft, detrend, return_onesided, boundary, padded, axis)
#    1027 def stft(x, fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None,
#    1028          detrend=False, return_onesided=True, boundary='zeros', padded=True,
#    1029          axis=-1):
#    1030     r"""Compute the Short Time Fourier Transform (STFT).
#    1031
#    1032     STFTs can be used as a way of quantifying the change of a
#    (...)
#    1172
#    1173     """
# -> 1174     freqs, time, Zxx = _spectral_helper(x, x, fs, window, nperseg, noverlap,
#    1175                                         nfft, detrend, return_onesided,
#    1176                                         scaling='spectrum', axis=axis,
#    1177                                         mode='stft', boundary=boundary,
#    1178                                         padded=padded)
#    1180     return freqs, time, Zxx
#
# File ~\anaconda3\lib\site-packages\scipy\signal\spectral.py:1758, in _spectral_helper(x, y, fs, window, nperseg, noverlap, nfft, detrend, return_onesided, scaling, axis, mode, boundary, padded)
#    1756     noverlap = int(noverlap)
#    1757 if noverlap >= nperseg:
# -> 1758     raise ValueError('noverlap must be less than nperseg.')
#    1759 nstep = nperseg - noverlap
#    1761 # Padding occurs after boundary extension, so that the extended signal ends
#    1762 # in zeros, instead of introducing an impulse at the end.
#    1763 # I.e. if x = [..., 3, 2]
#    1764 # extend then pad -> [..., 3, 2, 2, 3, 0, 0, 0]
#    1765 # pad then extend -> [..., 3, 2, 0, 0, 0, 2, 3]
#
# ValueError: noverlap must be less than nperseg.

# %%
pip install pyserial
